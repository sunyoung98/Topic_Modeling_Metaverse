# %%
import re
import pandas as pd
from tqdm import tqdm
from konlpy.tag import Okt
from collections import Counter

# %%
zepeto=pd.read_csv("roblox_review_test_ko.csv")

# %%
zepeto = zepeto[zepeto['content'].notna()]
zepeto.isnull().sum()
# Out:
# Unnamed: 0                  23
# reviewId                     0
# userName                     0
# userImage                    0
# content                      0
# score                        0
# thumbsUpCount                0
# reviewCreatedVersion     41517
# at                           0
# replyContent            236220
# repliedAt               236220
# dtype: int64

# %%
zepeto=zepeto.drop_duplicates()
zepeto.duplicated().sum()
# Out:
# 0

# %%
zepeto = zepeto.reset_index(drop=True)

# %%
def extract_word(text):
    hangul = re.compile('[^가-힣]') 
    result = hangul.sub(' ', text) 
    return result

# %%
zepeto['content'] = zepeto['content'].apply(lambda x:extract_word(x))

# %%
from eunjeon import Mecab
import sys
import os

# %%
#mecab = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")
mecab = Mecab()
#def tokenize_kn(text):  # 한글 형태소분석
#    return " ".join([tok[0] for tok in mecab.pos(text)])

# %%
mecab.pos("안녕하세요 사용성 사용 했습니다 성사 월드")
# Out:
# [('안녕', 'NNG'),
#  ('하', 'XSV'),
#  ('세요', 'EP+EF'),
#  ('사용', 'NNG'),
#  ('성', 'XSN'),
#  ('사용', 'NNG'),
#  ('했', 'XSV+EP'),
#  ('습니다', 'EF'),
#  ('성사', 'NNG'),
#  ('월드', 'NNG')]

# %%
zepeto['content_phrases']=""
zepeto['content'][0]
# Out:
# '펫시뮬 제미있어요 다들 한번 해보세요'

# %%
zepeto['content_nouns']=zepeto['content'].apply(mecab.nouns)

# %%
#zepeto['content_phrases']=zepeto['content'].apply(tokenize_kn)

# %%
zepeto.to_csv('roblox_phrases.csv',sep=',',na_rep='NaN',index=True)

# %%
mystr=[]
for i in range(len(zepeto['content_nouns'])):
    mystr+=zepeto['content_nouns'][i]

# %%
mystr
# Out:
# ['펫',
#  '시',
#  '뮬',
#  '제미',
#  '이유',
#  '화면',
#  '버그',
#  '이걸',
#  '년',
#  '밸런스',
#  '파괴',
#  '배드',
#  '워즈',
#  '사람',
#  '사람',
#  '핵',
#  '요즘',
#  '배드',
#  '워즈',
#  '점프',
#  '맵',
#  '등등',
#  '밴',
#  '가지',
#  '이',
#  '개',
#  '유력',
#  '배드',
#  '워즈',
#  '저작',
#  '핵',
#  '배드',
#  '워즈',
#  '배드',
#  '워즈',
#  '삭제',
#  '해킹',
#  '계정',
#  '개사',
#  '현질',
#  '유도',
#  '금',
#  '유소',
#  '환불',
#  '요청',
#  '불가',
#  '신고',
#  '불가',
#  '개',
#  '안니',
#  '광고',
#  '렉',
#  '와이파이',
#  '질',
#  '데',
#  '렉',
#  '이점만',
#  '때',
#  '완벽',
#  '점',
#  '로블',
#  '록스',
#  '업데이트',
#  '제',
#  '로블',
#  '유저',
#  '도움',
#  '필요',
#  '게임',
#  '사기',
#  '핵',
#  '점',
#  '왕',
#  '잼',
#  '월래',
#  '문제',
#  '이제',
#  '집',
#  '똥',
#  '망',
#  '겜',
#  '단점',
#  '렉',
#  '단점',
#  '사람',
#  '게임',
#  '단점',
#  '검열',
#  '장점',
#  '가지',
#  '게임',
#  '수',
#  '단점',
#  '아바타',
#  '것',
#  '머리카락',
#  '옷',
#  '아바타',
#  '서버',
#  '버그',
#  '저',
#  '모바일',
#  '유저',
#  '화면',
#  '버그',
#  '고처',
#  '점',
#  '점',
#  '로블',
#  '넌',
#  '설치',
#  '재미',
#  '인터넷',
#  '접속',
#  '행',
#  '노',
#  '블록스',
#  '플',
#  '사람',
#  '플레이',
#  '노가다',
#  '만',
#  '버퍼링',
#  '터치',
#  '때',
#  '사기',
#  '닉',
#  '뿌림',
#  '께',
#  '게임',
#  '앱',
#  '자신',
#  '원',
#  '앱',
#  '수',
#  '그',
#  '데',
#  '제',
#  '천',
#  '원',
#  '사용',
#  '벅스',
#  '결재',
#  '돈',
#  '벅스',
#  '환불',
#  '벅스',
#  '게임',
#  '담',
#  '점',
#  '단점',
#  '재미',
#  '게임',
#  '다섯',
#  '개',
#  '줄',
#  '만하',
#  '내용',
#  '광고',
#  '어용',
#  '내',
#  '인생',
#  '최악',
#  '게임',
#  '님',
#  '배드',
#  '워즈',
#  '게',
#  '여',
#  '배드',
#  '워즈',
#  '개똥',
#  '겜',
#  '재미',
#  '사람',
#  '사람',
#  '존망',
#  '겜',
#  '배드',
#  '워즈',
#  '똥',
#  '망',
#  '겜',
#  '배드',
#  '워즈',
#  '풍선',
#  '데',
#  '똥',
#  '망',
#  '겜',
#  '증거',
#  '배드',
#  '워즈',
#  '똥',
#  '망',
#  '겜',
#  '보물선',
#  '셈',
#  '과금',
#  '소리',
#  '돈',
#  '게',
#  '뭐',
#  '제',
#  '로블',
#  '캐릭',
#  '게',
#  '제',
#  '유튜브',
#  '환불',
#  '법',
#  '일',
#  '점',
#  '안녕',
#  '로블',
#  '사람',
#  '잼',
#  '민',
#  '입양',
#  '재미',
#  '점프',
#  '맵',
#  '휴대폰',
#  '맵',
#  '이거',
#  '년',
#  '동안',
#  '저희',
#  '동생',
#  '개똥',
#  '망',
#  '겜',
#  '현질',
#  '수',
#  '벅스',
#  '부족',
#  '게임',
#  '쟈',
#  '엄마',
#  '뒤',
#  '엄마',
#  '뒤',
#  '저',
#  '바나나',
#  '킬러',
#  '하',
#  '버그',
#  '별',
#  '친구',
#  '추가',
#  '안',
#  '됀',
#  '사람',
#  '맵',
#  '피스',
#  '게임',
#  '원피스',
#  '관련',
#  '열매',
#  '친구',
#  '계정',
#  '열매',
#  '친구',
#  '추가',
#  '현질',
#  '과금',
#  '과금',
#  '쓰레기',
#  '취급',
#  '당신',
#  '게임',
#  '자격',
#  '굿',
#  '친구',
#  '게',
#  '로블',
#  '최고',
#  '렉',
#  '나',
#  '이거',
#  '개',
#  '앱',
#  '짱',
#  '가지',
#  '게임',
#  '수',
#  '이거',
#  '개꿀',
#  '잼',
#  '하나',
#  '게임',
#  '게임',
#  '수',
#  '요즘',
#  '업데이트',
#  '맵',
#  '때',
#  '불편',
#  '역시',
#  '남',
#  '플레이',
#  '사람',
#  '렉',
#  '서버',
#  '수',
#  '사람',
#  '확장',
#  '때',
#  '완벽',
#  '겜',
#  '것',
#  '버그',
#  '수',
#  '조',
#  '잼',
#  '자체',
#  '사람',
#  '이거',
#  '오',
#  '돈',
#  '징나',
#  '감사',
#  '님',
#  '블',
#  '미국인',
#  '한국어',
#  '안녕',
#  '저',
#  '년',
#  '블',
#  '유저',
#  '겜',
#  '의사소통',
#  '가능',
#  '게임',
#  '저',
#  '추천',
#  '랙',
#  '때',
#  '가지',
#  '앱',
#  '해킹',
#  '때문',
#  '추천',
#  '평점',
#  '데',
#  '핵',
#  '이상',
#  '만',
#  '원',
#  '충전',
#  '겜',
#  '로블',
#  '원임',
#  '내',
#  '게임',
#  '중',
#  '최고',
#  '게임',
#  '벅스',
#  '컴퓨터',
#  '맵',
#  '제작',
#  '수',
#  '게',
#  '광고',
#  '거레',
#  '가능',
#  '곰돌이',
#  '해킹',
#  '핵',
#  '핵',
#  '때',
#  '매',
#  '해킹',
#  '벅스',
#  '요즘',
#  '오류',
#  '짜증',
#  '아이템',
#  '클릭',
#  '버그',
#  '등',
#  '가지',
#  '버그',
#  '완벽',
#  '게임',
#  '게임',
#  '광고',
#  '게임',
#  '재미',
#  '게임',
#  '안',
#  '게임',
#  '버그만',
#  '거',
#  '재미',
#  '업데이트',
#  '이거',
#  '광고',
#  '캐릭터',
#  '수',
#  '게임',
#  '제',
#  '로블',
#  '이트',
#  '그레도',
#  '플레이',
#  '제',
#  '로블',
#  '지',
#  '때',
#  '부',
#  '정도',
#  '열',
#  '분',
#  '이거',
#  '강추',
#  '렉',
#  '거',
#  '핵',
#  '잼',
#  '로드',
#  '손',
#  '게임',
#  '게임',
#  '망',
#  '겜',
#  '임',
#  '사람',
#  '욕',
#  '저',
#  '게임',
#  '적극',
#  '추천',
#  '오류',
#  '서버',
#  '발',
#  '때',
#  '재미',
#  '플레이',
#  '점',
#  '광고',
#  '래이',
#  '어',
#  '맵',
#  '수',
#  '가지',
#  '맵',
#  '수',
#  '욘',
#  '디',
#  '펜더스',
#  '로봇',
#  '추천',
#  '때',
#  '게임',
#  '뭐',
#  '매일',
#  '광고',
#  '캐릭터',
#  '추천',
#  '버그',
#  '핵',
#  '사기',
#  '펫',
#  '험',
#  '저',
#  '막',
#  '블',
#  '초기',
#  '초기',
#  '말',
#  '게임',
#  '게임',
#  '안녕',
#  '저',
#  '블록스',
#  '년',
#  '년',
#  '정도',
#  '사람',
#  '겜',
#  '너',
#  '랙',
#  '개',
#  '꿀',
#  '잼',
#  '블록스',
#  '게임',
#  '미어',
#  '꿀',
#  '잼',
#  '광고',
#  '게임',
#  '게임',
#  '수',
#  '점',
#  '저',
#  '게임',
#  '중',
#  '블록스',
#  '게임',
#  '것',
#  '게임',
#  '안',
#  '장르',
#  '게임',
#  '점',
#  '자기',
#  '취향',
#  '게임',
#  '수',
#  '저번',
#  '블록스',
#  '서버',
#  '적',
#  '일',
#  '동안',
#  '블록스',
#  '그때',
#  '진짜',
#  '블록스',
#  '만',
#  '게임',
#  '걸',
#  '진짜',
#  '블록스',
#  '후회',
#  '오',
#  '꿀',
#  '잼',
#  '개발자',
#  '짱',
#  '럽',
#  '킴',
#  '취',
#  '인증',
#  '인증',
#  '로그인',
#  '버그',
#  '만아',
#  '버그',
#  '때문',
#  '점',
#  '제',
#  '저질',
#  '게임',
#  '이거',
#  '광고',
#  '사람',
#  '소통',
#  '친구',
#  '추가',
#  '기능',
#  '것',
#  '현실',
#  '친구',
#  '게임',
#  '수',
#  '단점',
#  '이거',
#  '폰',
#  '저장',
#  '공간',
#  '전',
#  '폰',
#  '폰',
#  '전',
#  '제',
#  '폰',
#  '옛날',
#  '폰',
#  '그때',
#  '거',
#  '포기',
#  '이거',
#  '제',
#  '주변',
#  '친구',
#  '저장',
#  '공간',
#  '때문',
#  '로블',
#  '게임',
#  '재미',
#  '개',
#  '폰',
#  '분',
#  '강추',
#  '대박',
#  '강추',
#  '로블',
#  '영원',
#  '솔',
#  '폰',
#  '로블',
#  '지울',
#  '생각',
#  '게임',
#  '추천',
#  '자연',
#  '드',
#  '민',
#  '게임',
#  '가지',
#  '게임',
#  '수',
#  '안녕',
#  '저',
#  '년',
#  '유저',
#  '버그',
#  '최고',
#  '신고',
#  '일',
#  '것',
#  '겜',
#  '감사',
#  '조시훈',
#  '잼',
#  '모바일',
#  '게임',
#  '수',
#  '면',
#  '대박',
#  '옛날',
#  '폰',
#  '렉',
#  '안녕',
#  '겜',
#  '년',
#  '반',
#  '유저',
#  '겜',
#  '안',
#  '가지',
#  '겜',
#  '사기',
#  '워',
#  '점',
#  '거',
#  '스토리',
#  '겜',
#  '단점',
#  '장점',
#  '거',
#  '저',
#  '추천',
#  '로블',
#  '겜',
#  '펫',
#  '시뮬레이터',
#  '배드',
#  '워즈',
#  '팻시',
#  '뮬',
#  '거시',
#  '게임',
#  '안',
#  '게임',
#  '와이파이',
#  '화면',
#  '현상',
#  '발생',
#  '글',
#  '단어',
#  '표시',
#  '거',
#  '제가',
#  '년',
#  '재이',
#  '게',
#  '추천',
#  '드립',
#  '당',
#  '게임',
#  '개',
#  '재미',
#  '꿀',
#  '젬',
#  '장점',
#  '게임',
#  '장점',
#  '친구',
#  '수',
#  '단점',
#  '최고',
#  '추천',
#  '겜',
#  '다섯',
#  '갠',
#  '기본',
#  '게임',
#  '것',
#  '안녕',
#  '로블',
#  '게임',
#  '년차',
#  '타워',
#  '디펜스',
#  '게',
#  '막',
#  '화면',
#  '때',
#  '화면',
#  '이점',
#  '거',
#  '핵',
#  '핵',
#  '감지',
#  '시스템',
#  '핵',
#  '게임',
#  '거',
#  '게',
#  '해킹',
#  '등',
#  '계정',
#  '계정',
#  '재한',
#  '상태',
#  '게임',
#  '리뷰',
#  '가지',
#  '게임',
#  '것',
#  '로블',
#  '록스',
#  '어린아이',
#  '쑤',
#  '블록스',
#  '잼',
#  '마니',
#  '점프',
#  '점프',
#  '거',
#  '불편',
#  '거',
#  '컴퓨터',
#  '년',
#  '유저',
#  '아바타',
#  '현질',
#  '게',
#  '불편',
#  '그것',
#  '이',
#  '임운',
#  '잼',
#  '민',
#  '챠',
#  '검열',
#  '편',
#  '잼',
#  '민',
#  '중간',
#  '멘탈',
#  '분',
#  '추천',
#  '않',
#  '전',
#  '편',
#  '수',
#  '잼',
#  '나용',
#  '친구',
#  '벅스',
#  '벅스',
#  '노력',
#  '저',
#  '노력',
#  '친구',
#  '벅스',
#  '저',
#  '벅스',
#  '일',
#  '그거',
#  '때문',
#  '친구',
#  '로벅',
#  '스나',
#  '안녕',
#  '이게',
#  '임',
#  '년',
#  '동안',
#  '유저',
#  '요즘',
#  '관련',
#  '문제',
#  '때문',
#  '별점',
#  '점',
#  '옛날',
#  '게임',
#  '바이브',
#  '것',
#  '이상',
#  '게임',
#  '잼',
#  '민이',
#  '패',
#  '드립',
#  '욕설',
#  '것',
#  '때문',
#  '잼',
#  '민',
#  '겜',
#  '생각',
#  '맵',
#  '중',
#  '과도',
#  '현질',
#  '유도',
#  '광기',
#  '맨',
#  '사기',
#  '저작',
#  '문제',
#  '이제',
#  '게임',
#  '수락',
#  '해커',
#  '버그',
#  '화면',
#  '버그',
#  '등등',
#  '것',
#  '중',
#  '것',
#  '장점',
#  '겜',
#  '벅스',
#  '카드',
#  '등등',
#  '것',
#  '감사',
#  '실화',
#  '판',
#  '기대',
#  '참고',
#  '저',
#  '최신',
#  '폰',
#  '랙',
#  '문제',
#  '때문',
#  '게임',
#  '그거',
#  '셧다운',
#  '블록스',
#  '입양',
#  '이걸로',
#  '그',
#  '해킹',
#  '얘',
#  '탱크',
#  '시뮬레이션',
#  '에이브람스',
#  '탱크',
#  '다음',
#  '그레이드',
#  '년',
#  '도',
#  '실수',
#  '폰',
#  '랙',
#  '꿀',
#  '잼',
#  '핵',
#  '잼',
#  '도리도리',
#  '핵',
#  '잼',
#  '벅스',
#  '아이템',
#  '아이템',
#  '않',
#  '벅스',
#  '벅스',
#  '정도',
#  '아이템',
#  '현실',
#  '머리',
#  '리뷰',
#  '수정',
#  '업데이트',
#  '업데이트',
#  '제',
#  '수정',
#  '게임',
#  '렉',
#  '버그',
#  '개',
#  '렉',
#  '버그',
#  '신경',
#  '사람',
#  '강추',
#  '추천',
#  '제작자',
#  '화이팅',
#  '별',
#  '분',
#  '제작자',
#  '몸',
#  '신고',
#  '정지',
#  '추방',
#  '추천',
#  '제',
#  '앱',
#  '게임',
#  '개',
#  '제',
#  '정지우',
#  '점',
#  '현질',
#  '아바타',
#  '수',
#  '플레이',
#  '수',
#  '게임',
#  '오류',
#  '건',
#  '불편',
#  '것',
#  '게임',
#  '단점',
#  '로블',
#  '입양',
#  '게임',
#  '한국',
#  '거래',
#  '서버',
#  '거',
#  '소문',
#  '데',
#  '블',
#  '입양',
#  '거',
#  '번',
#  '해킹',
#  '서버',
#  '만',
#  '원',
#  '현질',
#  '계정',
#  '그거',
#  '로그아웃',
#  '유튜브',
#  '시간',
#  '복귀',
#  '번',
#  '다양',
#  '게임',
#  '이상',
#  '게임',
#  '겜',
#  '해킹',
#  '겜',
#  '겜',
#  '등등',
#  '이상',
#  '게임',
#  '거',
#  '단점',
#  '캐릭터',
#  '수',
#  '현질',
#  '유도',
#  '걸',
#  '추천',
#  '때',
#  '친구',
#  '것',
#  '온라인',
#  '겜',
#  '이게',
#  '게임',
#  '추천',
#  '해요',
#  '블록스',
#  '게임',
#  '점프',
#  '맵',
#  '파',
#  '타워',
#  '오브',
#  '헬',
#  '겜',
#  '짜증',
#  '저',
#  '게임',
#  '말',
#  '현질',
#  '거',
#  '게임',
#  ...]

# %%
from collections import Counter

count_items=Counter(mystr)
count_items=sorted(count_items.items(),key=lambda pair : pair[1], reverse=True)

# %%
import csv
with open('roblox_count.csv','w',newline='') as csvfile:
    writer=csv.writer(csvfile)
    writer.writerows(count_items)
