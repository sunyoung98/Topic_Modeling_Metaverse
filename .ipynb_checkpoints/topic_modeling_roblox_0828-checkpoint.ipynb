# %%
from konlpy.tag import Okt
from tqdm import tqdm
import re
import pickle
import csv
import pandas as pd
from pandas import DataFrame 
import numpy as np
import warnings
from nltk.corpus import stopwords

warnings.filterwarnings(action='ignore')

# %%
title='roblox.csv'
word_list =set(['이','와우','여러가지','굿굿','서요','머','마','한마디','어','은','디','머','삼','앱','폰','게임','겜','개','저','요','제발','뭐','하나','그냥','해','데','못','때문','그것','게','지금','내','걸','나','위','로','캐','이안','고','처럼','밑','스','방금','제','다시','왜','안','갑자기','처음','전','줄','한번','오늘','아예','해도','원래','번','만','하라','때','그거','심해','가끔','피하','하나요','욤','튕기','뭘','약간','렉좀','인','옆','것','그','또','꼭','명','건','부분','자주','글','수가','분','곳','경우','바로','자꾸','용','여','터','오','튕겨','어쩌','더','수','조금','짱','음','등','해주시','함','등등','찍','일단','자기','생기','일리','후','뒤','이번','이후','가기','중이','오지','땜','응','장공','보고','너','듯','세','배','무엇','게속','안나','그레','전혀','다가','놀수','정말','별로','굿','벌','색','제패','토','새','쫌','염','것좀','강추','멩','정도','번','기','거의','살','달','좀','거','진짜','저기','밌','이나','주','안눌려','재','완전','최고','이건','임','애','막','슴','개도','주기도','여기','무','영','고요','니','영','아주','생각','생','맘','구','산','버','화가','혐기','주시','물','피','다른','리지','계속','무슨','잘못','뭔가','실망','욤','난','답','일이','자체','끼리','다음','습','계속','가요','보','최악','잠깐','이상','몇번','며칠','어디','가지','직접','눈','업','날','끝','뎅','하니','혹시','건가','네','요즘','도','를','이제','좋더','얼마','언제','대박','거기','된거','그대로','주심','예전','제대로','분명','시','로블록스', '꿀잼','핵꿀잼','님들','짱짱','노잼','개꿀','역시','여러분','점','님','님들','꾸르잼','셈','밋','재밋어','안해','살짝','전부','블록','처','바','가안','레','티','튕','런','쿤'])
word_list
# Out:
# {'가기',
#  '가끔',
#  '가안',
#  '가요',
#  '가지',
#  '갑자기',
#  '강추',
#  '개',
#  '개꿀',
#  '개도',
#  '거',
#  '거기',
#  '거의',
#  '건',
#  '건가',
#  '걸',
#  '것',
#  '것좀',
#  '게',
#  '게속',
#  '게임',
#  '겜',
#  '경우',
#  '계속',
#  '고',
#  '고요',
#  '곳',
#  '구',
#  '굿',
#  '굿굿',
#  '그',
#  '그거',
#  '그것',
#  '그냥',
#  '그대로',
#  '그레',
#  '글',
#  '기',
#  '꼭',
#  '꾸르잼',
#  '꿀잼',
#  '끝',
#  '끼리',
#  '나',
#  '난',
#  '날',
#  '내',
#  '너',
#  '네',
#  '노잼',
#  '놀수',
#  '눈',
#  '니',
#  '님',
#  '님들',
#  '다가',
#  '다른',
#  '다시',
#  '다음',
#  '달',
#  '답',
#  '대박',
#  '더',
#  '데',
#  '뎅',
#  '도',
#  '된거',
#  '뒤',
#  '듯',
#  '등',
#  '등등',
#  '디',
#  '때',
#  '때문',
#  '땜',
#  '또',
#  '런',
#  '레',
#  '렉좀',
#  '로',
#  '로블록스',
#  '를',
#  '리지',
#  '마',
#  '막',
#  '만',
#  '맘',
#  '머',
#  '멩',
#  '며칠',
#  '명',
#  '몇번',
#  '못',
#  '무',
#  '무슨',
#  '무엇',
#  '물',
#  '뭐',
#  '뭔가',
#  '뭘',
#  '밋',
#  '밌',
#  '밑',
#  '바',
#  '바로',
#  '방금',
#  '배',
#  '버',
#  '번',
#  '벌',
#  '별로',
#  '보',
#  '보고',
#  '부분',
#  '분',
#  '분명',
#  '블록',
#  '산',
#  '살',
#  '살짝',
#  '삼',
#  '새',
#  '색',
#  '생',
#  '생각',
#  '생기',
#  '서요',
#  '세',
#  '셈',
#  '수',
#  '수가',
#  '스',
#  '슴',
#  '습',
#  '시',
#  '실망',
#  '심해',
#  '아예',
#  '아주',
#  '안',
#  '안나',
#  '안눌려',
#  '안해',
#  '애',
#  '앱',
#  '약간',
#  '어',
#  '어디',
#  '어쩌',
#  '언제',
#  '얼마',
#  '업',
#  '여',
#  '여기',
#  '여러가지',
#  '여러분',
#  '역시',
#  '염',
#  '영',
#  '옆',
#  '예전',
#  '오',
#  '오늘',
#  '오지',
#  '와우',
#  '완전',
#  '왜',
#  '요',
#  '요즘',
#  '욤',
#  '용',
#  '원래',
#  '위',
#  '은',
#  '음',
#  '응',
#  '이',
#  '이건',
#  '이나',
#  '이번',
#  '이상',
#  '이안',
#  '이제',
#  '이후',
#  '인',
#  '일단',
#  '일리',
#  '일이',
#  '임',
#  '자기',
#  '자꾸',
#  '자주',
#  '자체',
#  '잘못',
#  '잠깐',
#  '장공',
#  '재',
#  '재밋어',
#  '저',
#  '저기',
#  '전',
#  '전부',
#  '전혀',
#  '점',
#  '정도',
#  '정말',
#  '제',
#  '제대로',
#  '제발',
#  '제패',
#  '조금',
#  '좀',
#  '좋더',
#  '주',
#  '주기도',
#  '주시',
#  '주심',
#  '줄',
#  '중이',
#  '지금',
#  '직접',
#  '진짜',
#  '짱',
#  '짱짱',
#  '쫌',
#  '찍',
#  '처',
#  '처럼',
#  '처음',
#  '최고',
#  '최악',
#  '캐',
#  '쿤',
#  '터',
#  '토',
#  '튕',
#  '튕겨',
#  '튕기',
#  '티',
#  '폰',
#  '피',
#  '피하',
#  '하나',
#  '하나요',
#  '하니',
#  '하라',
#  '한마디',
#  '한번',
#  '함',
#  '해',
#  '해도',
#  '해주시',
#  '핵꿀잼',
#  '혐기',
#  '혹시',
#  '화가',
#  '후'}

# %%
def clean_text(text):
    text = text.replace(".", "").strip()
    text = text.replace("·", " ").strip()
    pattern = '[^ ㄱ-ㅣ가-힣|0-9]+'
    text = re.sub(pattern=pattern, repl='', string=text)
    return text

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

# %%
def get_nouns(tokenizer, sentence):
    nouns=tokenizer.nouns(sentence)
    for word in word_list: 
        nouns=remove_values_from_list(nouns,word)
    return nouns

def tokenize(df):
    tokenizer = Okt()
    processed_data = [] 
    for sent in tqdm(df['content']):
        sentence = clean_text(str(sent).replace("\n", "").strip())
        processed_data.append(get_nouns(tokenizer, sentence))
    return processed_data

# %%
def save_processed_data(processed_data):
    with open("output/tokenized_data_"+title, 'w', newline="", encoding='utf-8') as f:
        writer = csv.writer(f)
        for data in processed_data:
            writer.writerow(data)
            
if __name__ == '__main__':
    tdf = pd.read_csv("data/roblox.csv")
    df=tdf[['userName','at','content','score','thumbsUpCount']]
    df.dropna(subset = ['content'])
    processed_data = tokenize(df)
    save_processed_data(processed_data)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 236320/236320 [15:11<00:00, 259.40it/s]

# %%
processed_data = [sent.strip().split(",") for sent in tqdm(open("output/tokenized_data_"+title,'r',encoding='utf-8').readlines())]
processed_data = DataFrame(processed_data)
processed_data[0] = processed_data[0].replace("", np.nan)
processed_data = processed_data[processed_data[0].notnull()]
processed_data = processed_data.values.tolist()
processed_data2=[]
for i in processed_data:
    i = list(filter(None, i))
    processed_data2.append(i)
processed_data = processed_data2
processed_data
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 236320/236320 [00:05<00:00, 45949.41it/s]
# [['펫시뮬'],
#  ['별',
#   '이유',
#   '화면',
#   '버그',
#   '데이',
#   '년',
#   '치질',
#   '밸런스',
#   '파괴',
#   '배드워즈',
#   '사람',
#   '사람',
#   '끼',
#   '핵',
#   '배드',
#   '워',
#   '점프',
#   '맵',
#   '가장',
#   '배드',
#   '워',
#   '저작권',
#   '핵',
#   '배드',
#   '워',
#   '배드',
#   '워',
#   '삭제'],
#  ['해킹', '계정', '개사'],
#  ['현질', '유도', '금', '유소', '환불', '요청', '불가', '신고', '불가', '섺'],
#  ['광고', '렉', '와이파이', '질', '렉', '이점'],
#  ['업데이트'],
#  ['로블', '유저', '로서', '도움', '사기꾼', '핵'],
#  ['왕꿀잼'],
#  ['월', '문제', '풀', '가래', '가집', '똥망겜'],
#  ['단점', '렉', '단점', '사람', '단점', '검열', '장점'],
#  ['단점', '아바타', '머리카락', '옷', '아바타', '서버', '버그'],
#  ['모바일', '유저', '화면', '버그'],
#  ['로블', '넌', '진짜캬'],
#  ['설치'],
#  ['재미', '인터넷', '접속'],
#  ['이서', '행', '이서', '노블', '록스'],
#  ['모', '사람'],
#  ['플레이'],
#  ['노가다', '다만', '버퍼링', '터치'],
#  ['사기꾼', '닉'],
#  ['임도', '무재'],
#  ['심지어', '자신', '사용', '벅스', '결재', '돈', '벅스', '환불', '벅스'],
#  ['지렬다', '담점', '단점', '어용', '별', '다섯', '만하', '내용', '광고'],
#  ['인생'],
#  ['마야',
#   '배드',
#   '워',
#   '배드',
#   '워',
#   '개똥겜',
#   '사람',
#   '만하',
#   '사람',
#   '존망',
#   '배드',
#   '워',
#   '똥망겜',
#   '배드',
#   '워',
#   '풍선',
#   '죽쥬',
#   '똥망겜',
#   '증거',
#   '배드',
#   '워',
#   '똥망겜',
#   '보물',
#   '선',
#   '만들기',
#   '무과',
#   '금은',
#   '소리',
#   '돈'],
#  ['로블', '캐릭', '사서', '유튜브', '환불', '법'],
#  ['로블', '사람', '맵'],
#  ['잼민'],
#  ['입양', '요가', '재미', '점프', '맵', '휴대폰', '맵'],
#  ['저희', '동생'],
#  ['개똥망겜', '현질', '벅스', '부족', '한게임'],
#  ['쟈밌다'],
#  ['엄마', '뒤저', '엄마', '뒤저'],
#  ['바나나', '킬러'],
#  ['버그'],
#  ['별',
#   '친구',
#   '추가',
#   '사람',
#   '맵',
#   '킹',
#   '피스',
#   '원피스',
#   '관련',
#   '열매',
#   '친구',
#   '계정',
#   '열매',
#   '친구',
#   '추가',
#   '현질',
#   '과금',
#   '무과',
#   '금은',
#   '쓰레기',
#   '취급',
#   '합',
#   '당신',
#   '자격'],
#  ['친구', '게젤', '로블최'],
#  ['렉'],
#  ['수도'],
#  ['개꿀잼'],
#  ['업데이트', '접프맵할때'],
#  ['로블', '플레이', '사람', '렉', '서버', '사람', '좀더', '확장'],
#  ['버그', '조'],
#  ['잼', '사람'],
#  ['거오', '돈', '징'],
#  ['로블', '미국인', '한국어'],
#  ['로블', '유저', '의사소통', '추천', '랙걸릴때', '여러', '해킹', '추천'],
#  ['평점', '핵'],
#  ['무제'],
#  ['충전', '로블'],
#  ['벅스', '컴퓨터', '로만', '맵', '제작'],
#  ['광고'],
#  ['거레', '곰돌이', '해킹', '핵', '핵', '때매', '해킹', '벅스'],
#  ['오류'],
#  ['튕김', '버그', '아이템', '클릭', '버그', '버그', '완벽', '한게임', '치', '화이팅'],
#  ['광고', '재미'],
#  ['가득'],
#  ['버그'],
#  ['데체', '재미', '업데이트'],
#  ['로블'],
#  ['광고', '도안', '캐릭터'],
#  ['로블', '트', '제밌', '플레이'],
#  ['로블', '부', '렉', '얼른', '얼른', '다운', '로드', '손해', '보지'],
#  ['망겜임', '사람', '욕'],
#  ['적극', '추천', '오류', '서버', '발', '플레이', '드'],
#  ['광고', '어가', '맵', '맵', '있어욘'],
#  ['디펜더', '로봇', '추천'],
#  ['매일'],
#  ['광고', '캐릭터', '추천'],
#  ['버그', '핵', '사기'],
#  ['펫', '채'],
#  ['로블', '초기', '초기', '말'],
#  ['사람', '랙', '별'],
#  ['재미'],
#  ['광고',
#   '로만',
#   '중',
#   '가장',
#   '여러',
#   '장르',
#   '취향',
#   '저번',
#   '서버',
#   '적',
#   '동안',
#   '그때',
#   '깨',
#   '후회'],
#  ['개발자'],
#  ['킴취'],
#  ['와잌'],
#  ['인증', '장창', '인증', '로그인', '교'],
#  ['버그'],
#  ['버그', '점주', '기도'],
#  ['제맜'],
#  ['질'],
#  ['광고',
#   '사람',
#   '소통',
#   '친구',
#   '추가',
#   '기능',
#   '현실',
#   '친구',
#   '친추',
#   '수도',
#   '단점',
#   '남지',
#   '옛날',
#   '그때',
#   '포기',
#   '거만',
#   '주변',
#   '친구',
#   '저장',
#   '공간',
#   '로블',
#   '재미',
#   '별',
#   '로블',
#   '솔',
#   '로블'],
#  ['추천'],
#  ['자연', '어드민', '어드민'],
#  ['신고', '일'],
#  ['훈'],
#  ['모바일'],
#  ['옛날', '렉'],
#  ['동한',
#   '유저',
#   '사기',
#   '태러',
#   '워',
#   '스토리',
#   '단점',
#   '장점',
#   '저가',
#   '추천',
#   '로블겜',
#   '펫',
#   '시뮬레이터',
#   '배드',
#   '워',
#   '팻시뮬',
#   '거시'],
#  ['다만', '와이파이', '화면', '현상', '발생', '단어', '표시'],
#  ['가로', '븍', '록스', '추천'],
#  ['서골', '재미'],
#  ['꿀젬'],
#  ['장점', '장점', '친구', '단점'],
#  ['강력', '추천'],
#  ['요별', '갠', '기본'],
#  ['로블', '타워', '디펜스', '화면', '화면', '튕김니', '이점', '핵', '핵', '감지', '시스템', '핵'],
#  ['해킹', '계정'],
#  ['계정', '상태', '리뷰'],
#  ['아이', '튕김', '점프', '점프'],
#  ['컴퓨터', '유저', '아바타', '현질'],
#  ['운', '잼민', '챠팅', '검열', '편이', '잼민', '중간', '멘탈', '추천', '채텡', '편이'],
#  ['친구',
#   '벅스',
#   '내가면',
#   '로벅',
#   '스주',
#   '려고',
#   '노력',
#   '노력',
#   '친구',
#   '벅스',
#   '벅스',
#   '친구',
#   '벅스'],
#  ['유저',
#   '관련',
#   '문제',
#   '옛날',
#   '바이브',
#   '잼민',
#   '이의',
#   '패',
#   '드립',
#   '욕설',
#   '잼민겜',
#   '맵',
#   '중',
#   '과도',
#   '현질',
#   '유도',
#   '광기',
#   '맨',
#   '사기',
#   '저작권',
#   '문제',
#   '수락',
#   '해커',
#   '버그',
#   '화면',
#   '버그',
#   '중',
#   '당장',
#   '장점',
#   '벅스',
#   '카드',
#   '실화',
#   '판',
#   '참고',
#   '최신',
#   '랙',
#   '문제',
#   '튕겼',
#   '자',
#   '아시',
#   '죵죵',
#   '셧다운',
#   '입양',
#   '어그',
#   '해킹',
#   '얘'],
#  ['탱크', '시뮬레이션', '에이', '브람스', '탱크', '그다음', '왜어', '그레이드'],
#  ['년도', '실수'],
#  ['랙', '검'],
#  ['핵잼', '도리', '도리', '핵잼', '라면'],
#  ['벅스', '아이템', '아이템', '벅스', '벅스', '아이템', '현실', '머리'],
#  ['리뷰',
#   '수정',
#   '업데이트',
#   '업데이트',
#   '수정',
#   '렉',
#   '버그',
#   '별개',
#   '렉',
#   '버그',
#   '신경',
#   '사람',
#   '추천',
#   '제작자',
#   '화이팅',
#   '별',
#   '제작자',
#   '몸',
#   '퐈이팅'],
#  ['신고', '정지', '뭐함', '추방'],
#  ['추천'],
#  ['무제'],
#  ['정지우'],
#  ['현질'],
#  ['아바타', '플레이', '오류'],
#  ['단점',
#   '먼저',
#   '로블',
#   '입양',
#   '한국',
#   '거래',
#   '서버',
#   '소문',
#   '로블',
#   '입양',
#   '두번째',
#   '해킹',
#   '서버',
#   '현질',
#   '계정',
#   '로그아웃',
#   '유튜브',
#   '겨우',
#   '겨우',
#   '복귀',
#   '세번',
#   '해킹',
#   '로벅',
#   '빨',
#   '별의별',
#   '매일',
#   '삭제',
#   '단점',
#   '캐릭터',
#   '현질',
#   '유도',
#   '추천'],
#  ['친구', '온라인', '제일', '추천'],
#  ['점프', '맵'],
#  ['됴혀', '파'],
#  ['타워',
#   '오브',
#   '헬',
#   '이지',
#   '말',
#   '현질',
#   '친추',
#   '입양',
#   '마찬가지',
#   '거래',
#   '영어',
#   '옛날',
#   '그때',
#   '사기',
#   '사칭',
#   '한적',
#   '도움',
#   '왜냐면',
#   '기분',
#   '업그레이드'],
#  ['웃기',
#   '실제',
#   '친구',
#   '날수',
#   '한가지',
#   '단점',
#   '욕설',
#   '말',
#   '조건',
#   '말',
#   '버그',
#   '버그',
#   '점프',
#   '버그',
#   '만능',
#   '평가',
#   '별',
#   '만점'],
#  ['잼'],
#  ['펫시뮬', '추천', '인터넷', '불만'],
#  ['로벅', '충전', '프리미엄', '리', '컴터'],
#  ['질리'],
#  ['재미'],
#  ['바이브', '잼민', '티톡충', '노절'],
#  ['로블', '유저', '한게임', '렉', '종종', '렉'],
#  ['사기', '사기', '현질', '유도', '무현', '대부분', '점프', '점도'],
#  ['킹', '피스', '제작자'],
#  ['로불',
#   '록스',
#   '동안',
#   '플레이',
#   '유저',
#   '로불',
#   '록스',
#   '캐릭터',
#   '벅스',
#   '자신',
#   '채팅',
#   '친구',
#   '요청',
#   '유트버들',
#   '듯이',
#   '인기',
#   '로불',
#   '록스',
#   '로불',
#   '록스',
#   '트기하',
#   '광고',
#   '마음',
#   '플레이',
#   '러',
#   '별'],
#  ['버그', '버그', '접속', '그럭해돼', '추천'],
#  ['광고', '자신', '꿈', '체험'],
#  ['랙'],
#  ['로벅', '무료', '시스템', '추가'],
#  ['랙'],
#  ['곱'],
#  ['망겜', '농락', '욕', '검열', '망겜', '직원', '해킹', '직원', '대우', '모양'],
#  ['옛날', '로블'],
#  ['응애'],
#  ['벅스',
#   '현질',
#   '티셔츠',
#   '바지',
#   '기본',
#   '청',
#   '자켓',
#   '기본',
#   '머리스타일',
#   '요로',
#   '벅스',
#   '사람',
#   '죕',
#   '로벅'],
#  ['아바타',
#   '점프',
#   '맵',
#   '입양',
#   '공포',
#   '단점',
#   '벅스',
#   '현질',
#   '과금',
#   '유저',
#   '여서',
#   '개조',
#   '금',
#   '벅스',
#   '무료',
#   '단점'],
#  ['해킹', '당'],
#  ['입양', '업데이트'],
#  ['강'],
#  ['장', '하윤'],
#  ['재미'],
#  ['랙', '입양', '맵', '버그', '하얀색', '문'],
#  ['재미'],
#  ['베리'],
#  ['러거', '륵후'],
#  ['로블', '벅스'],
#  ['모바일', '랙', '단점', '퀄리티', '작품', '로블', '덕질'],
#  ['늬'],
#  ['맵'],
#  ['가입'],
#  ['오디오'],
#  ['현질', '행서', '별', '줗구', '현질', '마음', '등짝', '조심', '몰래', '현질', '현질', '좋겄'],
#  ['로블', '점프', '버튼', '점프', '버그'],
#  ['랙', '튕긴하'],
#  ['친구', '광고'],
#  ['외이럿', '재미잏'],
#  ['핸드폰', '맵', '만드나', '컴퓨터', '핸드폰', '법'],
#  ['버그', '현질', '좀비'],
#  ['왕', '추천'],
#  ['재미'],
#  ['말'],
#  ['유저',
#   '렌',
#   '왓',
#   '코드',
#   '엄마',
#   '달라',
#   '헤',
#   '서적',
#   '줫',
#   '꾸중',
#   '끈겨',
#   '엄마',
#   '사람',
#   '노',
#   '면서',
#   '넷',
#   '요게',
#   '간',
#   '끈기'],
#  ['맵'],
#  ['빵', '삥', '뽕'],
#  ['타워', '스포', '주의', '입양', '홧팅'],
#  ['로블'],
#  ['닌자'],
#  ['상관',
#   '스프레이',
#   '맵',
#   '사기',
#   '어제',
#   '스트레스',
#   '스트레스',
#   '팍',
#   '말',
#   '킥',
#   '시간',
#   '최대',
#   '사건'],
#  ['입양'],
#  ['학년', '아바타', '버그', '법', '별'],
#  ['동생', '가족', '욕', '을해'],
#  ['종류'],
#  ['재미'],
#  ['종', '지우', '말고개', '허세'],
#  ['벅스', '결제', '지급', '벅스'],
#  ['재미'],
#  ['업데이트'],
#  ['핵', '이만'],
#  ['가족'],
#  ['중독', '캐릭터', '문제', '계정', '삭제'],
#  ['펫시물펫'],
#  ['개꿀잼'],
#  ['조', '친구', '추가', '사람', '지조', '렉'],
#  ['동안', '만하', '셍각하', '한가지', '점프', '아', '컴퓨터', '시가', '멍말'],
#  ['쏴레기'],
#  ['에서로블', '초'],
#  ['버그', '고치'],
#  ['맵'],
#  ['플레이어', '친추', '아바타', '현질', '아바타', '현질'],
#  ['종', '때매', '잼민'],
#  ['유저', '버그', '튕기고맵', '버그', '렉', '단점', '장점', '친구', '멀티'],
#  ['제밋다'],
#  ['버그', '고치'],
#  ['휴대폰', '버그'],
#  ['펫',
#   '공포',
#   '캐릭터',
#   '핸드폰',
#   '화면',
#   '저절로',
#   '점프',
#   '자동',
#   '컴퓨터',
#   '한국어',
#   '치면',
#   '자동',
#   '앞',
#   '숫자',
#   '샾이떠'],
#  ['광고'],
#  ['듬'],
#  ['밖'],
#  ['콘텐츠', '잘만'],
#  ['사랑'],
#  ['킹', '피스'],
#  ['재미'],
#  ['재미', '버그', '재발'],
#  ['대개'],
#  ['스트레스', '마음', '쏙'],
#  ['꿀꿀', '잼'],
#  ['로블', '유저', '해킹'],
#  ['업데이트', '업데이트', '여러'],
#  ['버그'],
#  ['리미',
#   '티드',
#   '야구모',
#   '구입',
#   '상품',
#   '판매',
#   '역',
#   '벅스',
#   '아바타',
#   '저장',
#   '작품',
#   '리미티드',
#   '돈'],
#  ['스를어', '잼민', '하하', '삭제', '후회'],
#  ['보안', '그림', '창', '보지', '그림', '버그'],
#  ['업데이트'],
#  ['재미'],
#  ['우웩', '핵'],
#  ['로딩', '중', '입양'],
#  ['외국인', '도하', '대화', '한국인', '사람', '친추', '도하', '대화', '도하'],
#  ['모바일', '렉', '릴리'],
#  ['어샵', '친구', '사실'],
#  ['티비'],
#  ['갖겜'],
#  ['고의', '아픔'],
#  ['문제', '렉', '핑', '버그', '버그', '리좀', '광고'],
#  ['체고'],
#  ['렉', '렉', '로얄', '하이', '아이스크림', '스테이지', '타워', '렉'],
#  ['요구', '버그'],
#  ['공포', '맵'],
#  ['광고'],
#  ['채밌습'],
#  ['벅스'],
#  ['화면', '불편', '단', '화면', '고치'],
#  ['중', '꽤'],
#  ['대기'],
#  ['요전',
#   '비밀번호',
#   '비번',
#   '비밀번호',
#   '비밀번호',
#   '설정',
#   '구가',
#   '면서',
#   '비번',
#   '로그아웃',
#   '로그아웃',
#   '어케',
#   '증발'],
#  ['김태경'],
#  ['현질'],
#  ['이유', '옄'],
#  ['배드워즈', '과금', '과금', '배드', '워'],
#  ['모범', '어린이', '약속', '돈', '현질'],
#  ['녹잼'],
#  ['메타', '버스', '신고', '대하'],
#  ['친구'],
#  ['현질', '흑우'],
#  ['재미'],
#  ['설정', '화면', '비밀번호', '표시', '닉네임', '집', '땐'],
#  ['렉', '스킬', '연결'],
#  ['추천'],
#  ['재미'],
#  ['신고', '소식', '신고', '사람', '재미'],
#  ['예', '최', '개임'],
#  ['잼잼'],
#  ['로블', '뉴비', '로블', '사기', '나무'],
#  ['화면'],
#  ['별하나', '주기'],
#  ['재밋구', '친구', '노', '형', '앞', '면'],
#  ['서버', '핵도드래', '추천'],
#  ['맵', '유튜브', '컨텐츠'],
#  ['버그', '연결', '어요'],
#  ['로블', '하루', '단점', '휴대폰', '화면', '버그'],
#  ['진짜재밋'],
#  ['즐겜러입니',
#   '핵',
#   '계정',
#   '해킹',
#   '사람',
#   '신고',
#   '신고',
#   '핵',
#   '해킹',
#   '러',
#   '핵강추',
#   '과금',
#   '유저',
#   '현질',
#   '템',
#   '이벤트',
#   '무료',
#   '현질',
#   '템'],
#  ['체험',
#   '광고',
#   '광고',
#   '적',
#   '캐릭터',
#   '무료',
#   '스토어',
#   '광고',
#   '광고',
#   '방법',
#   '친구',
#   '추가',
#   '돈',
#   '무료',
#   '혼자',
#   '비공개',
#   '서버',
#   '장점',
#   '단점',
#   '광고',
#   '회원',
#   '가입',
#   '로그인',
#   '벅스',
#   '현질',
#   '현질',
#   '각',
#   '벅스',
#   '아이템',
#   '아이템',
#   '현질',
#   '돈',
#   '현질',
#   '공간',
#   '차지',
#   '랙',
#   '금줄'],
#  ['개꿀잼'],
#  ['랙', '아이템', '두번째', '점프', '맵', '점프', '랙', '랙'],
#  ['점프', '버그', '벅스', '아바타', '현질', '현질', '금', '최애'],
#  ['무쉬'],
#  ['힛힛'],
#  ['틴', '랙'],
#  ['모'],
#  ['맵', '친구'],
#  ['벅스', '결제'],
#  ['잼믯'],
#  ['사람', '트', '말', '재발'],
#  ['티비', '이임'],
#  ['샾'],
#  ['잼', '이름', '벅스'],
#  ['로그인',
#   '화면',
#   '지고',
#   '랙',
#   '일',
#   '삭제',
#   '수학',
#   '스테이지',
#   '타워',
#   '세로',
#   '세로',
#   '타워',
#   '고장'],
#  ['로블', '유저', '주기', '문제', '리뷰', '부탁', '코로나', '조심'],
#  ['초보자', '스테이지', '타워', '타워', '점프', '맵등', '가추', '준', '이유', '스트레스', '만요'],
#  ['별', '사람', '양심', '감'],
#  ['맵', '업데이트', '오거', '플레이', '몸통', '버그', '수정'],
#  ['광고', '타워', '랙', '열'],
#  ['랙', '와이파이', '성능'],
#  ['강요'],
#  ['로그인', '비밀번호', '정보'],
#  ['로블러스'],
#  ['무제'],
#  ['유저', '놀'],
#  ['업데이트'],
#  ['타워'],
#  ['추', '추', '버그'],
#  ['무제', '또제'],
#  ['튕기거', '렉'],
#  ['렉', '렉', '법', '그대', '화면'],
#  ['오블', '화면', '버그', '점프', '버그', '방해', '버그', '수정'],
#  ['레이즈'],
#  ['아바타', '집', '사고', '월', '돈', '집', '파', '집'],
#  ['추천',
#   '버그',
#   '말',
#   '화면',
#   '여기저기',
#   '화면',
#   '이점',
#   '이름',
#   '버그',
#   '버그',
#   '이름',
#   '창',
#   '이름',
#   '계정',
#   '친구',
#   '추가'],
#  ['투입'],
#  ['친구', '서서'],
#  ['최', '해킹'],
#  ['결제', '한도', '남'],
#  ['나나', '마마마', '너머', '퉅마마맘맘므', '존시나'],
#  ['습니', '무조건', '잼민', '재미', '채', '활동', '잼민', '성인', '청소년', '종료'],
#  ['김민성'],
#  ['겐찬으', '셔', '겐차을겄'],
#  ['리뷰', '리뷰'],
#  ['사칭', '사칭', '거래', '평', '은로', '완해', '발부'],
#  ['신고', '과금', '팻', '시뮬레이터', '핵', '이점', '계정', '개월', '로벅'],
#  ['대신',
#   '버그',
#   '업데이트',
#   '겄',
#   '면',
#   '업데이트',
#   '버그',
#   '이점',
#   '사랑',
#   '업데이트',
#   '도제',
#   '맵',
#   '가로',
#   '무료',
#   '로벅',
#   '유저',
#   '항상',
#   '유저',
#   '도로',
#   '언니',
#   '동생',
#   '껄요로블',
#   '록스',
#   '평생',
#   '요로',
#   '덕분',
#   '맵',
#   '푹',
#   '서로',
#   '앞',
#   '발전',
#   '요로',
#   '스짱로블',
#   '록스',
#   '앞',
#   '사랑',
#   '요로',
#   '요로',
#   '대충',
#   '뜻임'],
#  ['데이터',
#   '그게',
#   '단점',
#   '단점',
#   '땐',
#   '먹통',
#   '친구',
#   '플레이',
#   '욕',
#   '도대체',
#   '벅스',
#   '현질',
#   '별',
#   '절대',
#   '현질'],
#  ['업데이트', '여유', '공간', '확보', '맵', '업데이트'],
#  ['개현', '나무', '과금'],
#  ['업데이트', '시간'],
#  ['친구', '추천', '고해', '타워', '젤'],
#  ['플레이', '한지', '유저', '장점', '재밎', '무료', '아바타', '뜻', '단점', '핵', '강', '추강', '추'],
#  ['또또'],
#  ['카메라', '이동', '점프', '사람', '겨우', '이정', '망겜', '길'],
#  ['랙', '점프', '맵', '타이', '입양', '친구', '옷', '랙을좀', '랙', '랙'],
#  ['맵'],
#  ['유저',
#   '메일',
#   '가장',
#   '단점',
#   '입양',
#   '거래',
#   '증',
#   '그게',
#   '별',
#   '도움',
#   '사기',
#   '거래',
#   '신분증',
#   '사용',
#   '아이템',
#   '거래',
#   '증'],
#  ['벅스',
#   '로벅',
#   '로벅',
#   '어차피',
#   '말',
#   '어차피',
#   '아씨',
#   '돈',
#   '돈',
#   '돈',
#   '인성',
#   '움',
#   '사람',
#   '시간',
#   '사실',
#   '뻥',
#   '현질',
#   '현질',
#   '로벅',
#   '안주',
#   '어카',
#   '어차피',
#   '외국인',
#   '쥬',
#   '망햇',
#   '에이'],
#  ['쫌로딩', '제작자', '로딩'],
#  ['업데이트', '갑자', '기안', '로블', '계정'],
#  ['재맜습니', '카트라이더', '과금', '로벅', '이벤트', '만약', '시간', '로벅', '이벤트'],
#  ['알징'],
#  ['광고', '혼자', '조정'],
#  ['무재'],
#  ['웈', '앜', '웈'],
#  ['벅스',
#   '시스템',
#   '관',
#   '불만',
#   '벅스',
#   '패스',
#   '사고',
#   '말',
#   '편리',
#   '대한',
#   '돈',
#   '지불',
#   '불만',
#   '불만',
#   '자신',
#   '유저',
#   '자유',
#   '무대',
#   '스텀',
#   '폭',
#   '무료',
#   '코스튬',
#   '좀더',
#   '베포',
#   '샾',
#   '처리',
#   '또한',
#   '요소',
#   '숫자궭',
#   '쌘등',
#   '한글',
#   '샾처리',
#   '숫자',
#   '일정',
#   '욕설',
#   '샾',
#   '처리',
#   '샾',
#   '처리',
#   '진행',
#   '예시',
#   '환생',
#   '지역',
#   '리',
#   '이요',
#   '확률',
#   '극악',
#   '몇퍼임',
#   '샾',
#   '처리',
#   '샾',
#   '처리',
#   '식',
#   '대화',
#   '진행'],
#  ['랙', '개인', '로블', '맵', '가장', '배드워즈', '제일'],
#  ['리뷰',
#   '뭡',
#   '현질',
#   '유도',
#   '입양',
#   '거래',
#   '사기',
#   '거래',
#   '입양',
#   '테스트',
#   '맵',
#   '입양',
#   '짝퉁',
#   '맵',
#   '벅스',
#   '유저',
#   '영어',
#   '얘기',
#   '한국',
#   '이모티콘',
#   '나라',
#   '이모티콘',
#   '욕',
#   '욕',
#   '숫자',
#   '다욕',
#   '욕',
#   '처리',
#   '유저',
#   '절대'],
#  ['업데이트', '굼굼해'],
#  ['여러'],
#  ['리뷰', '수정'],
#  ['이서', '나이'],
#  ['킹', '피스', '급니'],
#  ['로딩', '렉', '알', '비번', '가입', '아침'],
#  ['옷', '옷', '저장', '초기', '벅스', '헤어', '여러', '사서', '구글', '갑', '지기', '다해', '로벅'],
#  ['중간', '로딩'],
#  ['친구', '가족'],
#  ['로블', '화면', '버그', '빨', '리좀', '고치'],
#  ['부터'],
#  ['잼민'],
#  ['존잼잼'],
#  ['유저', '다른사람', '소통', '설정'],
#  ['무제', '겡'],
#  ['핸드폰',
#   '나이스',
#   '뭐냐면겔럭시',
#   '랙',
#   '도안',
#   '데왜',
#   '업데이트',
#   '핸드폰',
#   '이보',
#   '용량',
#   '어보',
#   '사용',
#   '왜도',
#   '데체왜안',
#   '어쩨',
#   '핸드폰',
#   '유뷰',
#   '버니',
#   '구독',
#   '이름',
#   '임준하',
#   '구독',
#   '꾹'],
#  ['유저', '해킹', '업데이트', '해킹', '별'],
#  ['해킹', '일', '관리'],
#  ['잼'],
#  ['학교', '그때', '검열', '일주일', '동안'],
#  ['광고',
#   '핸드폰',
#   '친구',
#   '먼저',
#   '말',
#   '앞',
#   '부탁',
#   '추천',
#   '타워',
#   '밀크',
#   '스테이지',
#   '타워',
#   '아보카도',
#   '스테이지',
#   '타워',
#   '짱구',
#   '타워',
#   '토피아',
#   '타워',
#   '타워',
#   '오브',
#   '헬',
#   '참고',
#   '장점',
#   '단점',
#   '말',
#   '단점',
#   '단점',
#   '단점',
#   '장점',
#   '뮬',
#   '입양',
#   '타워',
#   '타이',
#   '앞',
#   '플레이'],
#  ['옷', '아바타', '옷', '맵', '장착', '최근', '옷', '맵', '옷', '입지', '주전', '져지', '캐릭터'],
#  ['현대', '모빌리티', '어드벤처'],
#  ['초기', '초기'],
#  ['중',
#   '점프',
#   '맵',
#   '스테이지',
#   '타워',
#   '점프',
#   '길가',
#   '면서',
#   '점프',
#   '화면',
#   '위치',
#   '위로',
#   '칸',
#   '길가',
#   '점프',
#   '화면',
#   '위치',
#   '앞',
#   '네모',
#   '파트',
#   '틈',
#   '아이',
#   '틈',
#   '건너',
#   '쉬프트',
#   '락',
#   '인지',
#   '회',
#   '오리',
#   '점프',
#   '틈',
#   '틈',
#   '중간',
#   '스테이지',
#   '타워',
#   '점프',
#   '맵',
#   '빨강',
#   '칸',
#   '레고',
#   '사람',
#   '망',
#   '가트',
#   '려',
#   '스테이지',
#   '칸',
#   '화장실',
#   '타원',
#   '아이',
#   '칸',
#   '색깔',
#   '만큼',
#   '칸',
#   '칸'],
#  ['직업', '이애'],
#  ['와디', '게재', '밓어요틋', '키', '입양', '요별'],
#  ['핑', '닥터스', '트레인', '거래', '시간', '판', '핑때문', '짐', '보상', '핑', '업데이트'],
#  ['사용자', '날씨'],
#  ['나쯔'],
#  ['렉', '사랑', '렉', '고치', '렉', '개뺙치뉴'],
#  ['현질', '소리', '킹', '피스', '현질', '뜻임', '킹', '피스'],
#  ['스트레스', '해소', '올스타'],
#  ['배드', '워', '꿀젬'],
#  ['현질', '로블', '단점', '소리'],
#  ['안녕',
#   '허세',
#   '로블',
#   '개월',
#   '사람',
#   '오류',
#   '내일',
#   '아침',
#   '로블',
#   '접속',
#   '화면',
#   '다크',
#   '모드',
#   '로그인',
#   '창',
#   '로그인',
#   '오류',
#   '오류'],
#  ['랙'],
#  ['벅스', '현질', '외국', '돈', '아쉬움', '로블'],
#  ['유저', '현질', '과금', '사람', '무료', '아이템', '입양', '한국', '거래', '플레이'],
#  ['핸드폰', '랙', '로블', '저장', '공간', '차지'],
#  ['업데이트', '하래'],
#  ['담', '전이', '렉'],
#  ['님힘내새'],
#  ['아닠숫자', '채팅', '샵', '검열'],
#  ['비번', '이름', '로그', '봇', '난리'],
#  ['챠', '스태', '타워'],
#  ['버그'],
#  ['유저',
#   '로블로',
#   '이름',
#   '설정',
#   '로딩',
#   '제거',
#   '다운로드',
#   '사람',
#   '이름',
#   '영어',
#   '피기',
#   '입양',
#   '요로',
#   '이겄',
#   '버그',
#   '버그',
#   '버그',
#   '제거',
#   '라야',
#   '로딩'],
#  ['왜냐면', '캐릭터', '일수'],
#  ['로블', '업데이트', '어떡', '업데이트', '마다', '업데이트', '어이'],
#  ['병맛'],
#  ['추천'],
#  ['그동안'],
#  ['연결', '흰색', '화면', '키', '로그아웃', '버그'],
#  ['재미', '어요'],
#  ['펫', '시뮬레이터', '유저', '퀄리티'],
#  ['연결', '어찌', '운영자', '해결', '방안'],
#  ['잼'],
#  ['현질'],
#  ['재미'],
#  ['재미', '랙이많'],
#  ['입양', '답답'],
#  ['설명'],
#  ['랙대매죽잔'],
#  ['쿠르잼'],
#  ['샌쥬'],
#  ['말'],
#  ['벅스', '못었', '어서', '캐릭터', '벅스', '었나'],
#  ['안녕',
#   '우왕',
#   '무재',
#   '친구',
#   '오빠',
#   '동생',
#   '친추',
#   '근대',
#   '버그',
#   '랙욕',
#   '해시',
#   '친구',
#   '언니',
#   '사람',
#   '시비',
#   '털',
#   '요욕',
#   '마음',
#   '화',
#   '저가',
#   '검색',
#   '을해',
#   '유치원',
#   '학생',
#   '중고',
#   '오빠',
#   '오래오래',
#   '편',
#   '쉬',
#   '신나요',
#   '거중',
#   '둑',
#   '로블',
#   '거중',
#   '학교'],
#  ['버그', '해킹'],
#  ['매출', '위로', '이구', '쥬', '입양', '거래', '신고', '부탁', '찐쨔'],
#  ['광고', '해킹'],
#  ['저금', '통'],
#  ['게정', '삭제'],
#  ['업데이트', '렉'],
#  ['핵잼', '킹', '피스', '젬'],
#  ['최겜'],
#  ['단점',
#   '장점',
#   '장점',
#   '캐릭터',
#   '마음대로',
#   '장점',
#   '집',
#   '마음대로',
#   '장점',
#   '현질',
#   '아이템',
#   '단점',
#   '현질',
#   '현질',
#   '사람',
#   '단점',
#   '렉',
#   '단점',
#   '사람',
#   '언어',
#   '소통',
#   '어렴',
#   '외국인'],
#  ['초딩',
#   '유',
#   '튜버',
#   '현질',
#   '아바타',
#   '현질',
#   '초딩',
#   '현질',
#   '관리',
#   '펫',
#   '물레',
#   '사기',
#   '신고',
#   '정지'],
#  ['점도', '주기', '배드워즈', '로벅', '구매', '벅스', '망겜'],
#  ['업뎃'],
#  ['재미', '핵', '패', '신고', '로블', '오이오이'],
#  ['랙'],
#  ['해킹', '당하', '술'],
#  ['도움'],
#  ['친구', '별'],
#  ['업데이트'],
#  ['금로',
#   '단점',
#   '비밀번호',
#   '장안',
#   '비번',
#   '계정',
#   '어제',
#   '계정',
#   '계정',
#   '현질',
#   '만총',
#   '비번',
#   '계정',
#   '시스템'],
#  ['굉'],
#  ['버그',
#   '있겐',
#   '실화',
#   '장점',
#   '배드워즈',
#   '무료',
#   '키트',
#   '유지',
#   '나왔스',
#   '과금',
#   '현질',
#   '부문',
#   '장점',
#   '좋스'],
#  ['로블',
#   '차',
#   '초',
#   '가장',
#   '즐겜',
#   '동생',
#   '살때',
#   '언니',
#   '초',
#   '먼저',
#   '장점',
#   '말',
#   '멀리',
#   '사람',
#   '대화',
#   '가능',
#   '친구',
#   '중독',
#   '단점',
#   '말',
#   '렉',
#   '무걸',
#   '린다',
#   '사기',
#   '버그',
#   '즐겜',
#   '사람',
#   '욕',
#   '별',
#   '앞',
#   '화이팅'],
#  ['업데이트'],
#  ['렉', '감점'],
#  ['계정',
#   '몇',
#   '접속',
#   '로그인',
#   '연결',
#   '문제',
#   '하루',
#   '회원',
#   '가입',
#   '와이파이',
#   '괜',
#   '네트워크',
#   '문제'],
#  ['화면', '버그'],
#  ['업데이트'],
#  ['찐젬'],
#  ['열매', '랩업'],
#  ['화면', '버그', '렉', '벅스', '현질', '벅스', '벅스', '가격'],
#  ['라가', '추천'],
#  ['유튜브', '로블'],
#  ['평소', '렉', '접속', '렉', '맵', '렉', '맵'],
#  ['을', '왜안', '현질', '왜안'],
#  ['재미'],
#  ['업데이트', '하래', '주일'],
#  ['계정', '천국'],
#  ['로블', '왜옷', '입채', '옛날'],
#  ['팁비'],
#  ['벅스', '충전', '화남'],
#  ['맵', '도하', '버그', '추천'],
#  ['장점', '광고', '장점', '단점', '와이파이'],
#  ['젇말', '즇', '플레이', '친구', '한가지', '아이템', '아바타', '위해', '선', '벅스', '돈', '그게'],
#  ['요안', '제작자', '현질', '맵', '로벅'],
#  ['당', '당장', '움'],
#  ['사람', '소통'],
#  ['데용'],
#  ['전쟁', '개임', '개임'],
#  ['로블', '현질', '유저', '저가', '실수', '구어', '웃', '로블', '트라우마', '밥', '계정'],
#  ['최애', '추천'],
#  ['화면',
#   '화면',
#   '위로',
#   '드',
#   '래그',
#   '인칭',
#   '이면',
#   '버그',
#   '문제',
#   '해결',
#   '버그',
#   '때매',
#   '개월일'],
#  ['유저', '별', '준', '이유', '킹', '피스', '제작자', '거좀', '킹', '피스'],
#  ['햇', '맜', '핵'],
#  ['대신', '의견', '업뎃', '거좀'],
#  ['아닠', '제작자', '욀캐잘만듬'],
#  ['고학', '넌', '도해'],
#  ['근대', '주모', '출석', '라면', '로벅'],
#  ['플레이',
#   '초딩',
#   '유저',
#   '아바타',
#   '아이템',
#   '사려',
#   '벅스',
#   '벅스',
#   '사려',
#   '현질',
#   '현질',
#   '유저',
#   '아바타',
#   '채팅',
#   '칠',
#   '욕설',
#   '숫자일',
#   '반적',
#   '단어',
#   '검열',
#   '처리',
#   '플레이',
#   '입양',
#   '아바타',
#   '속',
#   '아바타'],
#  ['추천', '단점', '입양', '사기', '신고', '네온', '사기', '주의', '욧'],
#  ['전로블'],
#  ['버그', '핵'],
#  ['맵'],
#  ['입양', '벅스'],
#  ['세상', '탄생', '배드', '워'],
#  ['입양', '요가', '제일'],
#  ['옷', '버그', '로벅', '구매', '버그', '설치', '추천'],
#  ['서버', '저번', '몇개', '월', '어이'],
#  ['서버', '연결', '와이파이', '칸', '다차', '서버', '연결'],
#  ['버그', '고치시', '드가자'],
#  ['사람', '사람'],
#  ['랙', '이심'],
#  ['넵', '검색', '누구', '로고', '시간', '재미', '사진', '았', '소리', '음막', '소리', '누구', '슬거'],
#  ['재밋'],
#  ['유저', '실수', '로그아웃', '비밀번호', '현질', '입양', '거래', '레전더', '리가', '동생', '계정'],
#  ['음저', '현질', '무과', '금도', '캐릭터', '광고', '벅스', '별', '무한'],
#  ['움',
#   '입양',
#   '사기',
#   '느낌',
#   '화남',
#   '신고',
#   '네펫',
#   '사람',
#   '정지',
#   '먹이',
#   '네이버',
#   '인스타그램',
#   '틱톡',
#   '유튜브',
#   '삭제',
#   '사기',
#   '펫',
#   '다이야',
#   '몬드',
#   '드래곤',
#   '타펫임',
#   '돈',
#   '감',
#   '유튜브',
#   '입양',
#   '큰소리',
#   '동영상',
#   '올린다',
#   '박제',
#   '쓰레기',
#   '브턴',
#   '사기',
#   '입양',
#   '이름',
#   '백일',
#   '접속',
#   '현질',
#   '사기',
#   '입',
#   '사기',
#   '돈',
#   '만원',
#   '실으',
#   '마셈'],
#  ['컴퓨터', '유저', '컴퓨터', '한글', '버그', '맨', '영어', '버그', '버그', '추천'],
#  ['오레', '유저', '업댓', '창'],
#  ['단어', '용어', '숫자'],
#  ['휴대폰', '로딩', '기기', '잼민', '이성', '욕설'],
#  ['사람', '로그인', '해킹', '보그', '로그인'],
#  ['점프', '맵'],
#  ['쫭'],
#  ['아바타', '비용'],
#  ['점프', '맵'],
#  ['핵', '이유', '이유', '신고', '고생', '신경', '신고', '플레이어', '기록'],
#  ['렉', '현질', '내용'],
#  ['선', '가짐'],
#  ['벅스',
#   '환불',
#   '펫',
#   '시뮬',
#   '아이템',
#   '번더',
#   '아이템',
#   '벅스',
#   '확인',
#   '벅스',
#   '아이',
#   '테이',
#   '확인',
#   '아이템',
#   '벅스',
#   '환불',
#   '법'],
#  ['사람',
#   '현질',
#   '유도',
#   '무료',
#   '아이템',
#   '현질',
#   '여러',
#   '아이템',
#   '스킨',
#   '입양',
#   '맵',
#   '이용',
#   '잠수',
#   '지나',
#   '강제',
#   '버그',
#   '별',
#   '준',
#   '이유',
#   '아이템',
#   '플레이',
#   '현상',
#   '점도',
#   '플레이'],
#  ['여러'],
#  ['해킹', '짜증', '해킹', '조심', '계정', '저장', '유저', '스킨', '살수', '벅스'],
#  ['사람과', '소통'],
#  ['중', '전세계', '사람', '질겨', '이로', '사람', '추천', '추천', '추천'],
#  ['왜냐면', '결제', '햇', '환불', '환불', '절'],
#  ['너무잼밋음', '친구', '가치', '가치', '오타'],
#  ['럭스', '제작자'],
#  ['광고'],
#  ['유저', '펫', '공포', '점프', '버그', '점프', '버그', '화면', '버그', '점도', '신고', '신고'],
#  ['광고', '매일'],
#  ['아바타',
#   '아바타',
#   '떼',
#   '벅스',
#   '돈',
#   '로벅',
#   '살수',
#   '돈',
#   '공자',
#   '로벅',
#   '돈',
#   '마찬가지',
#   '돈',
#   '만원',
#   '천원',
#   '말',
#   '외국',
#   '한국',
#   '한국',
#   '만원',
#   '이면',
#   '만원',
#   '벅스',
#   '별',
#   '로벅',
#   '고치'],
#  ['챠', '제작자', '친구', '버그', '버그', '화면', '버그', '친구', '버그', '요로', '제작자', '말'],
#  ['재밋', '무료', '단점', '현질', '유도', '렉', '버그', '서버', '핵'],
#  ['로벅'],
#  ['타워', '신고', '신고', '기도', '입양', '거래', '사기', '장점', '친추', '요청', '맵', '윗쪽', '이유'],
#  ['로블굿'],
#  ['그닏겆', '늡'],
#  ['현질', '유도', '신고', '캐릭터', '나머지', '플레이'],
#  ['축구'],
#  ['기계', '버그', '여러', '종', '유의'],
#  ['화면', '버그', '화면', '버그'],
#  ['광고'],
#  ['송',
#   '신고',
#   '다른사람',
#   '태',
#   '욕',
#   '신고',
#   '사람',
#   '신고',
#   '계정',
#   '삭제',
#   '삭제',
#   '신고',
#   '도하',
#   '눈가',
#   '려',
#   '버그',
#   '버그',
#   '이해',
#   '화면',
#   '버그',
#   '점프',
#   '버그',
#   '화면',
#   '버그',
#   '확대',
#   '버그',
#   '치면',
#   '다섯'],
#  ['요로', '유저', '첫째', '숫자', '검열', '처리', '둘째', '별거', '검열', '처리'],
#  ['유저', '광고', '친구'],
#  ['맵', '이재', '채팅', '더욱'],
#  ['갓'],
#  ['말'],
#  ['점프',
#   '맵',
#   '현실',
#   '롤플레이',
#   '기타',
#   '추천',
#   '르',
#   '장점',
#   '광고',
#   '맵',
#   '단점',
#   '벅스',
#   '캐릭터',
#   '도로',
#   '벅스',
#   '캐릭터',
#   '하루'],
#  ['오류', '업데이트'],
#  ['버그',
#   '만남',
#   '여로',
#   '캐릭',
#   '고모',
#   '전설',
#   '일반도',
#   '엄대이트',
#   '쩜프',
#   '맴',
#   '한국인',
#   '타워',
#   '초딩',
#   '타워',
#   '초딩',
#   '고처',
#   '그다음',
#   '한국인',
#   '타워',
#   '거도',
#   '우리나라',
#   '실',
#   '바보',
#   '타워',
#   '한국인',
#   '타워',
#   '봥',
#   '바보',
#   '타위',
#   '것쫌',
#   '재발',
#   '싹싹',
#   '부탁'],
#  ['유튜버',
#   '민준',
#   '영상',
#   '콘텐츠',
#   '버그',
#   '법',
#   '화면',
#   '버그',
#   '조이스틱',
#   '화면',
#   '버그',
#   '왼쪽',
#   '상단',
#   '로고',
#   '클릭',
#   '조이스틱',
#   '클래식',
#   '러시',
#   '무한',
#   '점프',
#   '버그',
#   '점프',
#   '버그',
#   '로고',
#   '클릭'],
#  ['잛', '리뷰', '점맵', '입양'],
#  ['표'],
#  ['해킹'],
#  ['광고'],
#  ['플레이',
#   '개인',
#   '플레이',
#   '후회',
#   '벅스',
#   '돈',
#   '현질',
#   '구매',
#   '무과',
#   '금은',
#   '현질',
#   '시간',
#   '이점',
#   '감사'],
#  ['현질', '현질', '한도'],
#  ['엄청돟음'],
#  ['깨임'],
#  ['연결'],
#  ['가해', '제일'],
#  ['렉', '버그', '그게'],
#  ['업데이트', '업데이트', '종종', '화면', '버그', '버그', '검열', '금'],
#  ['채팅', '컴퓨터', '치', '버그'],
#  ['요로'],
#  ['중독', '잼'],
#  ['재미'],
#  ['렉', '즐거움', '빠져듬별', '개보'],
#  ['좋아욘', '추천'],
#  ['랙'],
#  ['유저',
#   '무과',
#   '금은',
#   '벅스',
#   '현질',
#   '차이',
#   '무과',
#   '금도',
#   '벅스',
#   '이용',
#   '스킨',
#   '패스',
#   '현질',
#   '유도',
#   '욕',
#   '영어',
#   '붙이',
#   '검열',
#   '예'],
#  ['여러'],
#  ['벅스'],
#  ['유저', '현질', '현질', '유도', '가격'],
#  ['추천'],
#  ['휴대폰', '맴', '꽤', '휴대폰', '입양', '피스', '평가', '이정', '대신', '인물'],
#  ['무료', '로벅', '로벅', '로벅'],
#  ['모드',
#   '아바타',
#   '패스',
#   '가격',
#   '스킨',
#   '가격',
#   '욕설',
#   '위해',
#   '채팅',
#   '검열',
#   '이해',
#   '말',
#   '처리',
#   '채팅',
#   '검열',
#   '어쨌든',
#   '강'],
#  ['소리'],
#  ['강윤'],
#  ['업데이트', '안햇', '면'],
#  ['안년', '유저', '별', '이유', '단점', '사람', '시비', '욕', '그게', '욕', '자제', '줫으', '별'],
#  ['뮤'],
#  ['추천'],
#  ['재밋다'],
#  ['단점', '렉', '옷', '타워', '만들기', '벅스', '장점', '친추'],
#  ['동안', '사용', '유저', '맵', '단점', '현질', '캐릭터', '벅스', '어덯', '현질'],
#  ['핵킹', '핵핵꿀잼'],
#  ['로블'],
#  ['재미'],
#  ['현질', '차이', '베드워즈', '벅스', '배틀', '패스', '키트', '미션', '일정량', '벅스', '낫다'],
#  ['재민'],
#  ['제작자', '왜케', '버그', '수정', '화면', '버그', '핵', '신고'],
#  ['망겜임', '라임'],
#  ['학년', '로블', '로벅', '깜짝', '로벅', '바이'],
#  ['친구', '재미', '버그'],
#  ['나무', '머슨'],
#  ['광고',
#   '따봉스',
#   '점프',
#   '맴',
#   '공포',
#   '그림',
#   '그리기',
#   '뮬',
#   '레이테',
#   '업데이트',
#   '이구',
#   '케릭',
#   '뿌',
#   '밀수',
#   '대신',
#   '벅스',
#   '로벅',
#   '실제',
#   '돈',
#   '온',
#   '입다',
#   '한국인',
#   '일본인',
#   '외국인',
#   '모두',
#   '로블로',
#   '항상'],
#  ['영어', '영어', '재미', '한국'],
#  ['서버'],
#  ['게임광', '고도'],
#  ['계정'],
#  ['개발자', '업데이트', '금', '소원'],
#  ['부터', '유저', '요새', '추천'],
#  ['친구', '친구', '아보', '친구', '적극', '추천', '욧'],
#  ['렉'],
#  ['연결'],
#  ['렉', '안성맞춤', '루삥뽕'],
#  ['나우'],
#  ['맵', '사실', '노가다', '제밌는', '절때', '광고', '추천'],
#  ['거래', '한도', '도달', '거래', '완료', '거래', '한도', '현질', '문제'],
#  ['광고', '해킹', '사람'],
#  ['재미'],
#  ['버그', '엄마', '말'],
#  ['판정'],
#  ['요추'],
#  ['재미'],
#  ['부느븐'],
#  ['추천'],
#  ['로불', '유저', '친구', '괭', '관고', '맵', '맵'],
#  ['최진'],
#  ['맛'],
#  ['플레이',
#   '맵',
#   '맵',
#   '맵',
#   '배드',
#   '워',
#   '추천',
#   '테',
#   '입양',
#   '요도',
#   '추천',
#   '펫',
#   '시뮬레이터',
#   '추천',
#   '플레이',
#   '리뷰',
#   '채팅',
#   '가능',
#   '캐릭터',
#   '광고'],
#  ['버그', '버그', '클릭', '화면', '회전', '점프', '버튼', '클릭', '점프', '버튼', '다운로드'],
#  ['단점',
#   '얘기',
#   '단점',
#   '이름',
#   '언어',
#   '점프',
#   '만하',
#   '버그',
#   '점프',
#   '버그',
#   '채팅',
#   '숫자',
#   '삐',
#   '처리',
#   '이름',
#   '언어',
#   '아바타',
#   '만들기',
#   '위해',
#   '선',
#   '현질'],
#  ['점프', '맵', '맵', '광고'],
#  ['유저', '테', '개인', '모바일', '이예', '동생', '동생', '인터넷', '짜증', '단점'],
#  ['갓', '속', '맵', '제작자', '현질', '돈', '만요', '현질', '사람'],
#  ['제작자', '화면', '버그', '킹', '피스', '업뎃좀'],
#  ['재미'],
#  ['사기',
#   '패',
#   '드림',
#   '욕',
#   '해킹',
#   '렉',
#   '핸드폰',
#   '던',
#   '저서',
#   '핸드폰',
#   '박살',
#   '컨트롤',
#   '그렉',
#   '피해',
#   '르',
#   '서로',
#   '답변'],
#  ['로블',
#   '유저',
#   '렉',
#   '비거',
#   '사람',
#   '로블',
#   '사람',
#   '사람과',
#   '친추',
#   '제일',
#   '만전',
#   '로블',
#   '제일'],
#  ['플레이',
#   '광고',
#   '긍정',
#   '기분',
#   '플레이',
#   '옛날',
#   '업데이트',
#   '논란',
#   '인기',
#   '맵',
#   '현질',
#   '맵',
#   '논란',
#   '삭제',
#   '옛날',
#   '웟던',
#   '뉴비',
#   '스킨',
#   '레고',
#   '스킨',
#   '스킨',
#   '중국',
#   '짝퉁',
#   '리뷰',
#   '제작자',
#   '무시',
#   '로블',
#   '제작자',
#   '외국인',
#   '셔',
#   '한국어',
#   '영어',
#   '무시',
#   '한국어',
#   '로블',
#   '논란',
#   '설명',
#   '손',
#   '지문'],
#  ['업데이트'],
#  ['업데이트'],
#  ['노블', '록스', '재미'],
#  ['업데이트', '맵'],
#  ['숫자', '샵', '처리'],
#  ['전세계', '초등학생', '검열', '버그', '옷', '고생', '수고', '화이팅'],
#  ['제작자', '열매', '전설', '로블가즈'],
#  ['버그', '핵', '핵', '용해도'],
#  ['나쁜사람', '초보', '하루', '종일', '항상'],
#  ['잼'],
#  ['얼마나',
#   '한지',
#   '유저',
#   '아바타',
#   '마음대로',
#   '친구',
#   '장점',
#   '모바일',
#   '유저',
#   '인지',
#   '렉',
#   '화면',
#   '돌리지',
#   '제멋대로',
#   '화면',
#   '화면',
#   '적도',
#   '선',
#   '저작권'],
#  ['제거', '캐릭터'],
#  ['무제'],
#  ['로벅', '사람'],
#  ['별'],
#  ['로블', '업데이트'],
#  ['로블',
#   '유저',
#   '블',
#   '상황',
#   '뉴튜북',
#   '타워',
#   '오브',
#   '헬',
#   '회원',
#   '가입',
#   '뉴튜북',
#   '로블',
#   '제작자',
#   '딴사람',
#   '블'],
#  ['버그'],
#  ['컨텐츠', '만하', '버터', '지고', '업데이트', '업데이트', '왜함', '상향', '업데이트'],
#  ['요로', '유저', '친구', '신의', '아바타', '접속', '추천'],
#  ['섯살', '부터', '블럭', '개임'],
#  ['설치'],
#  ['엄좋아',
#   '장단점',
#   '장점',
#   '서버',
#   '캐릭터',
#   '친구',
#   '추가',
#   '크루',
#   '단점',
#   '캐릭터',
#   '벅스',
#   '현질',
#   '록',
#   '벅스',
#   '필요',
#   '로벅',
#   '단점',
#   '욕',
#   '욕',
#   '채팅',
#   '샾',
#   '욕',
#   '사이',
#   '샾',
#   '욕',
#   '샾',
#   '뜰때',
#   '장점',
#   '단점',
#   '이구',
#   '현',
#   '분만'],
#  ['봉'],
#  ['초딩', '어른', '모두', '푹'],
#  ['점프', '맵', '마인크래프트', '마크', '입양', '요도'],
#  ['그림'],
#  ['엄마', '젓', '꼭지'],
#  ['건만'],
#  ['친구', '블럭'],
#  ['재미', '해커', '계정', '킹', '비번'],
#  ['저는로블', '고딩', '컴퓨터', '컴퓨터', '리그', '럼', '랙', '죽', '떼', '최애'],
#  ['배드', '워', '꿀젬'],
#  ['유저', '현질'],
#  ['광고', '또제'],
#  ['록', '블럭'],
#  ['벅스'],
#  ['여러'],
#  ['로블',
#   '유저',
#   '매일',
#   '화면',
#   '버그',
#   '현질',
#   '유저',
#   '로서',
#   '바이브',
#   '스킨',
#   '관련',
#   '삭제',
#   '보통',
#   '욕',
#   '먹기',
#   '스킨',
#   '그닥'],
#  ['조음'],
#  ['업데이트', '벅스', '돈'],
#  ['졸라', '조음', '추천'],
#  ['버그', '유명', '한게임', '핵', '다야', '컨테츠', '친구', '대화', '겜임', '친구', '친구', '교환'],
#  ['학생', '현질', '출석', '체크', '란걸', '접속', '매일', '로벅', '접속', '벅스', '인기', '겄'],
#  ['업데이트'],
#  ['늘'],
#  ['로블로',
#   '유저',
#   '화면',
#   '버그',
#   '렉',
#   '컴퓨터',
#   '컴퓨터',
#   '사람',
#   '대충',
#   '실수',
#   '지역',
#   '갓',
#   '심심',
#   '벅스',
#   '하루',
#   '벅스',
#   '현질',
#   '위해'],
#  ['유저', '점점'],
#  ['갓'],
#  ['무조건',
#   '한진',
#   '제일',
#   '추천',
#   '입양',
#   '요랑',
#   '각종',
#   '점프',
#   '맵',
#   '초등학생',
#   '맵',
#   '사람',
#   '친구',
#   '동시',
#   '접속',
#   '플레이',
#   '더욱',
#   '친구',
#   '추가',
#   '채팅',
#   '소통',
#   '후회',
#   '벅스',
#   '가격',
#   '벅스',
#   '사면',
#   '플레이',
#   '유저',
#   '마지막',
#   '꼭꼭',
#   '플레이'],
#  ['블럭',
#   '사람',
#   '회원',
#   '가입',
#   '로그인',
#   '경험',
#   '캐릭터',
#   '옷',
#   '벅스',
#   '동전',
#   '친구',
#   '추가',
#   '제한',
#   '친구',
#   '추가',
#   '무한',
#   '추천',
#   '로벅',
#   '슬',
#   '동전',
#   '었으려',
#   '돈',
#   '이름',
#   '검색',
#   '영어',
#   '영어',
#   '사람',
#   '한국어'],
#  ['광고'],
#  ['추천'],
#  ['노홓', '쇼', '며', '챠', '코', '묘', '리', '술', '혀', '흐', '노', '텨'],
#  ['맵', '아바타', '버그', '화면', '혼자', '화면', '버그', '추가', '튕길'],
#  ['로그인', '아웃'],
#  ['타워', '재미', '강', '추강', '추'],
#  ['점거'],
#  ['노래', '코드', '버그', '노래', '코드'],
#  ['렉', '해커', '점주'],
#  ['랙', '고치'],
#  ['브로스'],
#  ['봉'],
#  ['옴'],
#  ['뻥', '강'],
#  ['과금', '유저', '캐릭터', '아이템', '과금', '유저'],
#  ['답변'],
#  ['친구', '숫자', '샵', '욕', '을해', '샵', '안뜰'],
#  ['현질', '광고'],
#  ['하루'],
#  ['업뎃잇'],
#  ['리얼', '서버', '환상'],
#  ['말',
#   '샵',
#   '랙',
#   '사람',
#   '시간',
#   '보넬',
#   '버그',
#   '감사',
#   '앞',
#   '친구',
#   '수도',
#   '한지',
#   '점프',
#   '맵',
#   '추천',
#   '중독',
#   '개월',
#   '주신',
#   '감사'],
#  ['블럭', '광고'],
#  ['킹', '피스', '배드', '워'],
#  ['모바일', '화면', '버그', '남매', '뉴점', '리스', '톤', '사망'],
#  ['시작',
#   '한지',
#   '아이',
#   '유튜브',
#   '광고',
#   '아바타',
#   '현질',
#   '옷',
#   '점프',
#   '맵',
#   '거래',
#   '아이',
#   '가장',
#   '입양',
#   '입양',
#   '현질',
#   '입양',
#   '맵',
#   '공짜',
#   '옷',
#   '시간',
#   '아이',
#   '휴대폰',
#   '게임상',
#   '친구',
#   '명가',
#   '추천'],
#  ['엄첨', '젬'],
#  ['김주하'],
#  ['체팅검열'],
#  ['친구', '평점'],
#  ['킹', '피스', '입양'],
#  ['현질', '로벅'],
#  ['블리', '록스', '운영자', '벅스', '벅스', '여서', '블랙', '아홀로틀', '드', '요부', '벅스', '부탁'],
#  ['업데이트', '업데이트', '일', '몼', '대요'],
#  ['아이템', '음미'],
#  ['버그', '해킹', '사', '근', '해킹'],
#  ['로블',
#   '배드',
#   '핵',
#   '펫시뮬',
#   '핵',
#   '배드',
#   '제작',
#   '펫시뮬',
#   '제작자',
#   '평가',
#   '로블',
#   '유튜',
#   '로블',
#   '캐릭터',
#   '미기',
#   '로벅',
#   '무과',
#   '금은',
#   '로블',
#   '친구',
#   '유튜브',
#   '영상',
#   '유튜브',
#   '을',
#   '해킹',
#   '사기',
#   '사칭'],
#  ['컴', '컴', '크롬'],
#  ['로블망해'],
#  ['오류', '렉핵'],
#  ['로블'],
#  ['신고',
#   '안돼욤',
#   '사기꾼',
#   '많아욤',
#   '사기',
#   '날타',
#   '유니',
#   '젠',
#   '거래',
#   '사기',
#   '대부분',
#   '패턴',
#   '사기꾼',
#   '먼저',
#   '좋은펫',
#   '입양',
#   '유저',
#   '먼저',
#   '사기꾼',
#   '속마음',
#   '계획',
#   '하하',
#   '입양',
#   '유저',
#   '사기꾼',
#   '사기',
#   '사기',
#   '사기꾼',
#   '유튜브',
#   '상황',
#   '사기꾼',
#   '상황',
#   '난후',
#   '사기꾼',
#   '사기',
#   '사실',
#   '사기꾼',
#   '빠',
#   '거래',
#   '창',
#   '거래',
#   '거절'],
#  ['시스탬', '사기꾼', '렉'],
#  ['업데이트',
#   '계정',
#   '로그아웃',
#   '스킨',
#   '성적',
#   '말',
#   '성적',
#   '옷',
#   '신고',
#   '신고',
#   '피나',
#   '성적',
#   '옷',
#   '삭제'],
#  ['벅스', '기프트카드', '결제', '오류', '라며', '결제'],
#  ['핵', '뻬'],
#  ['한가지', '체험'],
#  ['해킹', '버그'],
#  ['핵'],
#  ['로벅', '로벅'],
#  ['광고', '랙없음'],
#  ['여러', '맴', '질리', '근대', '과금'],
#  ['재미', '가', '인기', '재미'],
#  ['로블'],
#  ['입양', '거래', '가능'],
#  ['잼민겜'],
#  ['성별', '무료', '남자', '여자', '케릭', '무료', '캐릭터', '벌써', '느낌', '느낌'],
#  ['재밎어'],
#  ['유저', '렉', '현질', '렉', '점프', '렉', '기도', '해킹', '현질', '아바타'],
#  ['실친', '친구'],
#  ['학실', '버그'],
#  ['렉',
#   '플레이',
#   '지장',
#   '타워',
#   '점프',
#   '맵',
#   '탈출',
#   '오비',
#   '시뮬레이터',
#   '포함',
#   '게다가',
#   '광고',
#   '아이디',
#   '비번',
#   '기억',
#   '플레이',
#   '데이터',
#   '플레이'],
#  ['졔'],
#  ['렉', '잼민', '이용', '어린이', '장난감', '수준'],
#  ['로블', '유저', '광고', '친구', '추천'],
#  ['결제', '한도', '자녀보호', '자유권', '침해'],
#  ['랩'],
#  ['여행'],
#  ['친구'],
#  ['업데이트'],
#  ['재미', '었'],
#  ['망'],
#  ['젤로', '저가', '엄마', '현질', '그다음', '계정', '사라', '추천', '금은', '플레이', '겜친', '사기'],
#  ['그때',
#   '유저',
#   '요하',
#   '버그',
#   '핵',
#   '잼민',
#   '패드',
#   '립하',
#   '잼민',
#   '구걸',
#   '충',
#   '시비',
#   '충',
#   '테러',
#   '충',
#   '다운',
#   '욕',
#   '읍니'],
#  ['최애'],
#  ['엣날', '뻔', '단점', '사기', '문제'],
#  ['화면', '버그', '방법'],
#  ['핵', '핵', '추방'],
#  ['한가지', '재미', '없을탠데', '오빠', '엄마', '사이', '칭찬', '사랑', '하트'],
#  ['친구', '임도', '렉', '건만'],
#  ['키유'],
#  ['리뷰', '짜미'],
#  ['블럭', '유저', '블럭', '블럭', '설치'],
#  ['퀄리티', '강', '강력', '추천'],
#  ['로블', '록스', '스타일', '빠', '이염'],
#  ['로블', '사람', '로벅', '현질'],
#  ['중', '자신', '스타일', '장르', '추천'],
#  ['요로', '블', '재밋', '바이브', '핵', '겁', '참고', '핵'],
#  ['세금', '계산서'],
#  ['유저', '닌자', '레전드', '벅스', '초기', '회사', '환불', '요청', '환불'],
#  ['얀'],
#  ['망겜', '나라', '핑좋게함'],
#  ['안닝', '계정', '캐릭'],
#  ['튕겨별'],
#  ['친구', '버그', '때매', '친구', '최대'],
#  ['유저', '정민', '추천', '병원', '입원'],
#  ['앤'],
#  ['스꿀잼'],
#  ['띠'],
#  ['인생', '제일'],
#  ['업데이트', '듭니'],
#  ['개꿀잼'],
#  ['차', '설명', '항상', '타워', '입양', '댓글', '댓글', '상대방', '말', '오해', '소통', '항상'],
#  ['광고', '과금', '캐릭터'],
#  ['벅스', '거래', '도주'],
#  ['렉', '버그', '사랑', '버그', '채팅', '버그', '안움', '지기', '버그', '화면', '버그', '화이팅'],
#  ['아이', '딸', '아이템', '난리', '울', '버그', '수정'],
#  ['업뎃'],
#  ['채팅', '검열', '세계'],
#  ['벅스', '결제', '수단', '계정'],
#  ['행복', '느', '개임', '별', '로만'],
#  ['맵', '친구'],
#  ['아바타', '친구'],
#  ['재밋내'],
#  ['벅스', '에', '금', '을지', '불하'],
#  ['광고', '외', '조'],
#  ['재밋'],
#  ['기도'],
#  ['잼'],
#  ['맵', '점프', '맵', '스토리', '맵', '현질', '헤헤', '로그인'],
#  ['로블', '먼저', '실력', '아스널', '실력', '연습'],
#  ['거래', '별'],
#  ['업데이트'],
#  ['블럭', '랙때문', '퉝', '블럭', '것밖'],
#  ['친구', '플레이', '버그', '영어', '어쨌든'],
#  ['재미', '그대', '해지'],
#  ['재미'],
#  ['당장', '다우', '론드'],
#  ['유저', '벅스'],
#  ['벅스', '돈', '분도', '다른사람', '리뷰', '안함'],
#  ['자신', '플레이', '거나', '버그', '화면', '플레이', '해결', '고치'],
#  ['주제'],
#  ['버그', '스테이지', '타워', '타워', '오프', '헬'],
#  ['배드', '워즈', '무료', '키트'],
#  ['인터넷', '연결', '잘만', '인터넷', '연결'],
#  ['친구', '젠'],
#  ['종류', '중', '가장', '블피', '피스'],
#  ['업데이트', '좋으닙다'],
#  ['여러'],
#  ['랙', '말', '샾뜨네'],
#  ['재미'],
#  ['블럭', '입양'],
#  ['미가'],
#  ['역대'],
#  ['펫좀', '었는'],
#  ['꿀쟇'],
#  ['랙', '재밋', '스리', '딜'],
#  ['제작자', '서버', '종', '레벨', '계정', '귀', '신고', '버터', '지게'],
#  ['점프', '맵'],
#  ['한글', '숫자', '하는챗팅', '알람', '더욱'],
#  ['컴', '로그인', '비밀번호', '뜸'],
#  ['로블', '환불'],
#  ['입양', '전설펫', '떼문', '로블'],
#  ['단', '한가지', '문제', '채팅', '이지', '단어', '단어', '단어', '문제', '계선', '별', '평가'],
#  ['현질'],
#  ['개발자', '핵', '서버', '플레이어', '핵', '정지'],
#  ['친구', '강력', '추쳔'],
#  ['버그', '망겜', '렉', '망겜', '킹', '업데이트'],
#  ['학년',
#   '쭉',
#   '유저',
#   '추천',
#   '사람',
#   '이유',
#   '광고',
#   '랙',
#   '싹',
#   '계정',
#   '비밀번호',
#   '아이디',
#   '기억',
#   '휴대폰',
#   '계정',
#   '쭉',
#   '결과',
#   '만큼',
#   '가치',
#   '간다'],
#  ['잼', '로그인', '하래', '로그', '계정'],
#  ['자신',
#   '의미',
#   '유저',
#   '맵',
#   '장점',
#   '사람',
#   '점프',
#   '맵',
#   '채',
#   '포인트',
#   '유저',
#   '유저',
#   '말',
#   '말'],
#  ['시비', '페', '드립', '도하', '욕또', '기분'],
#  ['플레이어', '게임장르', '버그', '스킨', '벅스', '로사', '스킨'],
#  ['해킹'],
#  ['우선', '돈', '맵', '현딜', '무과금러'],
#  ['활동', '나용'],
#  ['랙'],
#  ['재미', '지다'],
#  ['알'],
#  ['버그', '망겜'],
#  ['망겜'],
#  ['무제',
#   '떼문',
#   '아무',
#   '쪼',
#   '금욕',
#   '썻',
#   '신고',
#   '리',
#   '그림',
#   '그리기',
#   '엡',
#   '다른사람',
#   '고해',
#   '기분'],
#  ['화면', '버그', '컴퓨터', '모바일', '키', '화면', '컨트롤러', '거만', '일'],
#  ['제작자',
#   '즐겨찾기',
#   '킹',
#   '레거시',
#   '입양',
#   '배드',
#   '워',
#   '기능',
#   '추가',
#   '즐겨찾기',
#   '보기',
#   '킹',
#   '피스',
#   '그게',
#   '소원'],
#  ['버그'],
#  ['정시우'],
#  ['뮤', '낮', '이전', '킹', '피스', '류', '렉때메', '얼마나'],
#  ['강', '이유', '입양', '입양', '별', '강'],
#  ['재미'],
#  ['확률', '똥', '렉민', '레벨', '도나', '형', '올름', '데몬', '소울', '조작', '돈', '확률', '똥임'],
#  ['옛날', '티셔츠', '실제', '옛날', '옷', '평점', '별', '실제', '옛날', '옷', '실제', '그림', '옷'],
#  ['존잼'],
#  ['광고'],
#  ['핵', '버그', '그게', '단점', '결점'],
#  ['쓰래', '기씨'],
#  ['개발자',
#   '드릴',
#   '말씀',
#   '동안',
#   '플레이',
#   '사람',
#   '무척',
#   '몇개',
#   '월',
#   '벅스',
#   '옷',
#   '몇개',
#   '옷',
#   '옷',
#   '벚',
#   '돈',
#   '벅스',
#   '옷',
#   '개발자',
#   '답변'],
#  ['신고', '패', '드립', '별', '애가', '욕', '패', '드립', '신고', '상대', '말', '신고'],
#  ['가로',
#   '블르',
#   '해거드',
#   '친구',
#   '쪼그',
#   '로블',
#   '롤스',
#   '니키',
#   '운기',
#   '드',
#   '별',
#   '블',
#   '로블',
#   '롤스',
#   '사랑'],
#  ['핵', '사기', '현질', '유도', '컴퓨터', '모바일', '스킬', '사용', '럭블럭', '검', '프라', '이프'],
#  ['유저',
#   '창',
#   '신하',
#   '맵',
#   '장점',
#   '단점',
#   '말',
#   '장점',
#   '친구',
#   '명도',
#   '궐수',
#   '채팅',
#   '통화',
#   '료',
#   '친구',
#   '메세지',
#   '단점',
#   '다툼',
#   '사람',
#   '민폐',
#   '행위',
#   '금',
#   '말',
#   '혐오',
#   '감',
#   '행동',
#   '채팅',
#   '치',
#   '마음',
#   '상처',
#   '흑역사',
#   '발생',
#   '채팅',
#   '단점',
#   '아무',
#   '맵',
#   '어린이',
#   '프로필',
#   '귀신',
#   '사진',
#   '어린이',
#   '사진',
#   '잠',
#   '사진',
#   '맵',
#   '개인',
#   '의견'],
#  ['접프맵', '타워', '오징어', '공포', '렉', '오류', '점주', '제작자', '렉', '오류', '홧팅'],
#  ['프리미엄', '로벅', '버그', '라면', '계정', '벅스'],
#  ['고수', '설명', '맵', '스포츠', '맵', '광고', '사람', '참가', '사람', '사용', '사람', '사용'],
#  ['꿀잼빅잼'],
#  ['로블', '록스', '고추', '달라', '뵨태', '현질', '유도', '변태'],
#  ['게게', '표', '퍄', '표'],
#  ['광고'],
#  ['서버', '핵', '다행'],
#  ['전체', '이용', '가로'],
#  ['좋앜'],
#  ['강', '도안', '벅스'],
#  ['리뷰',
#   '엄마',
#   '답니',
#   '장점',
#   '말',
#   '자신',
#   '맵',
#   '장점',
#   '과금',
#   '스킨',
#   '문제',
#   '단점',
#   '말',
#   '핵',
#   '신고',
#   '조취',
#   '현질',
#   '유도',
#   '과금',
#   '벅스',
#   '벅스',
#   '실감',
#   '겨우',
#   '벅스',
#   '꼴',
#   '마지막',
#   '해커',
#   '서버',
#   '플랫폼',
#   '사람',
#   '사람',
#   '조취',
#   '취하',
#   '일반',
#   '유저',
#   '플레이',
#   '플랫폼',
#   '글자',
#   '제한',
#   '남지',
#   '마피',
#   '주관',
#   '바탕',
#   '작성'],
#  ['사이트', '말'],
#  ['로드'],
#  ['몰래', '랐'],
#  ['로블', '솨람', '버그', '컴퓨터', '노트북', '로블하', '렉'],
#  ['친구',
#   '체험',
#   '맵',
#   '저희',
#   '유트버',
#   '찍기',
#   '별',
#   '스트레스',
#   '욕설',
#   '다른사람',
#   '이야기',
#   '친구',
#   '기분',
#   '입양',
#   '렉',
#   '벅스',
#   '방법',
#   '현질'],
#  ['로블', '현질', '얼마나'],
#  ['친구'],
#  ['시기', '시기', '새긱'],
#  ['프로필', '알림', '버그'],
#  ['렉', '별'],
#  ['시작', '데이터', '겁', '제작사', '입양', '데이터', '모두', '데이터', '복귀'],
#  ['친구', '소개', '추천', '펫', '시뮬레이터', '세계', '가즈'],
#  ['데이지', '별'],
#  ['이점',
#   '신고',
#   '신고',
#   '신고',
#   '계정',
#   '정지',
#   '입양',
#   '요도',
#   '신고',
#   '아이템',
#   '현질',
#   '사람',
#   '현질',
#   '사람',
#   '옷',
#   '벅스',
#   '말',
#   '옷',
#   '무료',
#   '체험',
#   '업데이트',
#   '업데이트',
#   '옷',
#   '무료',
#   '체험',
#   '숫자',
#   '사람',
#   '나이',
#   '숫자',
#   '입력',
#   '샾',
#   '그게',
#   '문제',
#   '숫자',
#   '만요',
#   '벅스',
#   '사람',
#   '현질',
#   '벅스',
#   '과금',
#   '얻지',
#   '벅스',
#   '무료',
#   '비밀번호',
#   '말',
#   '종류',
#   '보상',
#   '벅스',
#   '벅스',
#   '이점',
#   '플레이어',
#   '화이팅',
#   '나이',
#   '설정',
#   '업데이트',
#   '불편'],
#  ['친구'],
#  ['우웩', '진짲별정', '도주', '기도', '공포', '렉', '인테넷', '렉', '무현', '욕', '현질', '맵'],
#  ['삭제'],
#  ['장난', '겁', '캐릭터'],
#  ['그레픽'],
#  ['유저',
#   '플레이',
#   '장점',
#   '단점',
#   '이야기',
#   '장점',
#   '여러',
#   '장르',
#   '친구',
#   '캐릭터',
#   '마음대로',
#   '벅스',
#   '사면',
#   '단점',
#   '잼민',
#   '욕설',
#   '사람',
#   '폭력',
#   '거나'],
#  ['거너', '무재', '단점', '기절', '잘만', '드', '추', '전이', '고별'],
#  ['즐거움'],
#  ['유저', '스앱', '점주'],
#  ['슬레이어', '타이'],
#  ['브'],
#  ['시도', '서버'],
#  ['재미', '땅'],
#  ['로블',
#   '사람',
#   '헤어',
#   '겹치기',
#   '디자인',
#   '캐릭터',
#   '업데이트',
#   '사람',
#   '일반',
#   '아이템',
#   '자켓',
#   '사람',
#   '형태',
#   '깝습',
#   '헤어',
#   '겹치',
#   '프로',
#   '나머지',
#   '프로',
#   '헤어',
#   '겹치기',
#   '이기',
#   '프로',
#   '나머지',
#   '프로',
#   '리뷰',
#   '프로'],
#  ['군침', '싹', '넼'],
#  ['무넝', '랻', '라듀', '노트북', '럼녀'],
#  ['디테', '일도'],
#  ['로그인'],
#  ['핑'],
#  ['친추', '동생', '단점', '벅스', '현질', '현질', '동생', '로서', '캐릭터', '핵'],
#  ['점프', '맵', '입양', '점프', '맵', '회', '오리', '힐링', '거만'],
#  ['진'],
#  ['유저',
#   '강',
#   '서버',
#   '랙',
#   '해킹',
#   '계정',
#   '해킹',
#   '적도',
#   '현질',
#   '캐릭터',
#   '차별',
#   '옷',
#   '유료',
#   '무료',
#   '버그',
#   '화면',
#   '설정',
#   '점프',
#   '설정',
#   '장점',
#   '캐릭터',
#   '단점',
#   '현질',
#   '캐릭터'],
#  ['듣보잡'],
#  ['입양', '제일', '제밌는', '입양'],
#  ['재미', '친구', '날수'],
#  ['무제'],
#  ['에러', '립'],
#  ['컴퓨터', '유저', '단점', '신고', '악용', '악용', '신고', '문제', '해결'],
#  ['금'],
#  ['고수', '뉴비', '차별', '합'],
#  ['모바일', '버그', '플레이', '문제', '서버', '별'],
#  ['맵'],
#  ['플레이어',
#   '다만',
#   '채팅',
#   '창',
#   '욕설',
#   '불만',
#   '숫자',
#   '욕설',
#   '관련',
#   '단어',
#   '옛날',
#   '채팅',
#   '창',
#   '채팅',
#   '창',
#   '추가',
#   '겨우',
#   '이모티콘',
#   '속',
#   '사람',
#   '테러',
#   '거나',
#   '해킹',
#   '핵',
#   '신고',
#   '기능',
#   '신고',
#   '핵',
#   '테러',
#   '제작자',
#   '처리',
#   '잘압니',
#   '처리',
#   '노력',
#   '마련',
#   '사랑',
#   '제작자',
#   '신경',
#   '사랑',
#   '방치',
#   '신경',
#   '제작자',
#   '인기',
#   '신경',
#   '나머진',
#   '제작자',
#   '화이팅'],
#  ['업데이트'],
#  ['엘리베이터', '설치'],
#  ['파가', '로블', '수듄'],
#  ['전유', '튜', '버파', '멍', '이임'],
#  ['유저',
#   '로써',
#   '장점',
#   '단점',
#   '장점',
#   '라면',
#   '친구',
#   '가능',
#   '장점',
#   '단점',
#   '스임',
#   '단점',
#   '라면',
#   '모바일',
#   '만들기',
#   '불가능',
#   '버전',
#   '가능',
#   '화면',
#   '버그',
#   '화면',
#   '버그',
#   '과도',
#   '현질',
#   '유도',
#   '과금',
#   '매우',
#   '현',
#   '몇몇',
#   '출석',
#   '체크',
#   '벅스',
#   '지급',
#   '부',
#   '계정',
#   '사실',
#   '도입',
#   '불가능',
#   '연애',
#   '보기',
#   '움',
#   '시비',
#   '욕함',
#   '챗',
#   '검열',
#   '마구잡이',
#   '검열',
#   '매우',
#   '숫자',
#   '검열',
#   '말',
#   '검열',
#   '욕',
#   '검열',
#   '바람',
#   '한영키',
#   '버그',
#   '챗',
#   '한글',
#   '캐릭터',
#   '급발진',
#   '앞',
#   '돌진',
#   '저작권',
#   '킹',
#   '피스',
#   '이점'],
#  ['개쿨재'],
#  ['랙'],
#  ['계정', '비밀번호', '입력'],
#  ['주의', '사항'],
#  ['친구', '추천', '년', '유저', '네트워크', '연결', '점심'],
#  ['방법', '찿았습니'],
#  ['유저',
#   '벅스',
#   '게임화',
#   '폐가',
#   '사지',
#   '종종',
#   '해커',
#   '해킹',
#   '본적',
#   '비밀번호',
#   '마지막',
#   '욕설',
#   '처리',
#   '채팅',
#   '종종',
#   '유저',
#   '대화',
#   '수정',
#   '렉',
#   '버그',
#   '핵등',
#   '포함',
#   '유저'],
#  ['임균영', '승리', '이름', '닌자', '레전드', '미가'],
#  ['러블',
#   '유저',
#   '캐릭터',
#   '맵',
#   '단점',
#   '화면',
#   '버그',
#   '전투',
#   '벅스',
#   '전투',
#   '현질',
#   '읗',
#   '차이',
#   '벅스',
#   '점프',
#   '맵',
#   '벅스',
#   '이용',
#   '악용',
#   '해킹',
#   '종종',
#   '제작자',
#   '미국인',
#   '시라',
#   '벅스',
#   '무료',
#   '나눔',
#   '이글'],
#  ['로블'],
#  ['기묘', '이유'],
#  ['우선', '다만', '회원', '가입', '최신', '고생'],
#  ['재밋음'],
#  ['렉', '테블렛', '쪼꼼'],
#  ['별',
#   '로블',
#   '욕',
#   '로블',
#   '신고',
#   '버튼',
#   '신고',
#   '게졍',
#   '삭제',
#   '지지도',
#   '굳이',
#   '이유',
#   '뭐임',
#   '사람',
#   '사기',
#   '현질',
#   '템',
#   '사기',
#   '차라리',
#   '로블',
#   '채팅',
#   '껏',
#   '사람',
#   '욕'],
#  ['팻', '시뮬레이터', '해킹', '환불'],
#  ['렉때', '뮨에쩌', '증', '망겜'],
#  ['상의', '바지', '상의', '바지'],
#  ['업데이트'],
#  ['랙'],
#  ['별', '재미', '문제', '튕기는'],
#  ['스태', '이지오'],
#  ['맵', '좋구욤', '입양', '요가'],
#  ['여러', '맵', '질', '기면', '캐릭터', '재미'],
#  ['장점',
#   '단점',
#   '장점',
#   '사람',
#   '친구',
#   '이해',
#   '용량',
#   '단점',
#   '액',
#   '제한',
#   '친구',
#   '제한',
#   '액',
#   '숫자',
#   '입력',
#   '플래',
#   '동안',
#   '집중',
#   '별'],
#  ['킹피꿀잼'],
#  ['매일', '추천'],
#  ['개인', '입양', '잼민', '나은', '어차피', '제작자', '이해', '전체', '나은'],
#  ['필',
#   '레이어',
#   '단점',
#   '장저',
#   '을',
#   '장점',
#   '맵',
#   '플레이',
#   '캐릭터',
#   '아이템',
#   '상의',
#   '하의',
#   '모자',
#   '가지가지',
#   '종류',
#   '단점',
#   '랙',
#   '맵',
#   '인기',
#   '마는',
#   '재시',
#   '도중',
#   '나가야'],
#  ['거꿀잼임'],
#  ['아바타', '현질', '앞', '화이팅'],
#  ['짜증'],
#  ['갓'],
#  ['연결', '짜증', '입양', '거래'],
#  ['수도', '회원', '가입', '스프레이', '페인트', '서버', '강제', '퇴장', '버그', '수도', '은제'],
#  ['렉', '틈'],
#  ['망겡'],
#  ['재미', '사람', '덯'],
#  ['친구', '멀티플레이', '밌는게임', '샘', '로블'],
#  ['현질', '유도'],
#  ['버그'],
#  ['해킹', '해킹', '당하'],
#  ['로블', '유저', '로써', '로블', '후대', '렉', '인터넷', '렉'],
#  ['유휘', '이이이이이'],
#  ['휴대폰', '스룰', '그게'],
#  ['아바타', '맵'],
#  ['펫', '시뮬레이터'],
#  ['입양', '근대', '렉'],
#  ['로블', '동생', '얘', '로블', '대요', '로블', '로블'],
#  ['추천'],
#  ['그룹', '무료', '한글', '숫자', '검열'],
#  ['장점',
#   '여러',
#   '플레이',
#   '단점',
#   '최근',
#   '업데이트',
#   '음원',
#   '싹',
#   '삭제',
#   '패스',
#   '라디오',
#   '음원',
#   '삭제',
#   '현질',
#   '유저',
#   '현질',
#   '유도',
#   '로블',
#   '현질',
#   '유도',
#   '유도',
#   '뜻',
#   '말',
#   '로블',
#   '현질',
#   '광고',
#   '거나',
#   '현질',
#   '패키지',
#   '화면'],
#  ['점프',
#   '달리기',
#   '초보자',
#   '익',
#   '단점',
#   '중간',
#   '중간',
#   '랙',
#   '장점',
#   '플레이',
#   '맵',
#   '플레이',
#   '중독'],
#  ['킹', '피스', '결재', '아이템', '확인', '벅스'],
#  ['케', '평점'],
#  ['현질', '유도'],
#  ['재미', '감동', '가짐', '로그아웃'],
#  ['블럭', '별', '이유', '버그', '핑', '별'],
#  ['펫', '시뮬레이터', '갓'],
#  ['스굿', '광고'],
#  ['갓'],
#  ['선',
#   '배드',
#   '워',
#   '로블',
#   '저작권',
#   '상관',
#   '근대',
#   '배드',
#   '작자',
#   '버그',
#   '풍선',
#   '버그',
#   '개월전',
#   '이제야',
#   '로벅',
#   '돈탕',
#   '배드',
#   '워',
#   '태',
#   '핑',
#   '핵',
#   '축직법',
#   '어이',
#   '키트',
#   '무과',
#   '금은',
#   '댕',
#   '사기',
#   '밸런스',
#   '시작',
#   '팀',
#   '다나',
#   '혼자',
#   '솔',
#   '플하',
#   '순위',
#   '렄블',
#   '온',
#   '창',
#   '낫',
#   '불빠따',
#   '로블',
#   '배드',
#   '워',
#   '핵',
#   '댕',
#   '핑높',
#   '팀',
#   '버그',
#   '바이브',
#   '설명',
#   '댕',
#   '잼민',
#   '샘',
#   '로블',
#   '시작',
#   '알',
#   '잼민',
#   '바이브',
#   '완벽',
#   '별'],
#  ['곡'],
#  ['화면', '버그', '점프', '버그', '별'],
#  ['뻥'],
#  ['기프트카드', '벅스'],
#  ['랙'],
#  ['재미', '버그', '놈', '버그', '제일', '제일', '문제', '옷', '빚', '속마음', '흥', '현질'],
#  ['사람', '킹', '레시', '피블', '어감', '부탁'],
#  ['괘'],
#  ['컨텐츠', '현질', '유도'],
#  ['광고', '컴', '버그'],
#  ['나락나락', '안드로이드', '맵', '안드로이드', '차별', '세상', '제일', '똥', '찌끄레기', '한게임', '캌퉤'],
#  ['업뎃', '화면', '삼성', '업뎃', '뭐시기', '로블', '화면'],
#  ['유저',
#   '샾이안떠',
#   '욕',
#   '갈대',
#   '랙',
#   '핸드폰',
#   '랙때문',
#   '외국',
#   '정리',
#   '장점',
#   '단점',
#   '외국',
#   '핸드폰',
#   '먹통',
#   '욕',
#   '욕',
#   '샾',
#   '맛'],
#  ['재미'],
#  ['모든'],
#  ['제일'],
#  ['버그', '벅스'],
#  ['유저',
#   '입양',
#   '아시',
#   '입양',
#   '거래',
#   '렉',
#   '서버',
#   '득',
#   '거래',
#   '고양이',
#   '상대방',
#   '나비',
#   '하하',
#   '고양이',
#   '재산',
#   '욥',
#   '로블',
#   '장점',
#   '렉',
#   '렉',
#   '로블',
#   '사람',
#   '이용',
#   '죵',
#   '당',
#   '렉',
#   '사용',
#   '더욱',
#   '잣'],
#  ...]

# %%
from gensim.models.ldamodel import LdaModel
from gensim.models.callbacks import CoherenceMetric
from gensim import corpora
from gensim.models.callbacks import PerplexityMetric

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
dictionary = corpora.Dictionary(processed_data)
dictionary.filter_extremes(no_below=2, no_above=0.5)
# Out:
# 2022-08-29 17:08:08,788 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2022-08-29 17:08:08,846 : INFO : adding document #10000 to Dictionary(7447 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:08,903 : INFO : adding document #20000 to Dictionary(11286 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:08,955 : INFO : adding document #30000 to Dictionary(14339 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,009 : INFO : adding document #40000 to Dictionary(16745 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,064 : INFO : adding document #50000 to Dictionary(19129 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,120 : INFO : adding document #60000 to Dictionary(21281 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,173 : INFO : adding document #70000 to Dictionary(23387 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,225 : INFO : adding document #80000 to Dictionary(25227 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,275 : INFO : adding document #90000 to Dictionary(27093 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,325 : INFO : adding document #100000 to Dictionary(28842 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,372 : INFO : adding document #110000 to Dictionary(30461 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,419 : INFO : adding document #120000 to Dictionary(32008 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,462 : INFO : adding document #130000 to Dictionary(33537 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,503 : INFO : adding document #140000 to Dictionary(35054 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,545 : INFO : adding document #150000 to Dictionary(36485 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,588 : INFO : adding document #160000 to Dictionary(37851 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)
# 2022-08-29 17:08:09,595 : INFO : built Dictionary(38039 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...) from 161539 documents (total 750743 corpus positions)
# 2022-08-29 17:08:09,595 : INFO : Dictionary lifecycle event {'msg': "built Dictionary(38039 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...) from 161539 documents (total 750743 corpus positions)", 'datetime': '2022-08-29T17:08:09.595165', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'created'}
# 2022-08-29 17:08:09,619 : INFO : discarding 23363 tokens: [('유소', 1), ('진짜캬', 1), ('지렬다', 1), ('죽쥬', 1), ('디펜더', 1), ('킴취', 1), ('와잌', 1), ('제맜', 1), ('채텡', 1), ('내가면', 1)]...
# 2022-08-29 17:08:09,619 : INFO : keeping 14676 tokens which were in no less than 2 and no more than 80769 (=50.0%) documents
# 2022-08-29 17:08:09,633 : INFO : resulting dictionary: Dictionary(14676 unique tokens: ['펫시뮬', '가장', '끼', '년', '데이']...)

# %%
corpus = [dictionary.doc2bow(text) for text in processed_data]

# %%
# -*- coding: utf-8 -*-
from konlpy.tag import Mecab
from tqdm import tqdm
import re
from gensim.models.ldamodel import LdaModel
from gensim.models.callbacks import CoherenceMetric
from gensim import corpora
from gensim.models.callbacks import PerplexityMetric
import logging
import pickle
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

coherence_values = []
perpexities_values = []
model_list = []


def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=1):
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        perpexities_values.append(model.log_perplexity(corpus))

    return model_list, coherence_values, perpexities_values


def find_optimal_number_of_topics(dictionary, corpus, processed_data):
    limit = 11;
    start = 2;
    step = 1;

    model_list, coherence_values, perpexities_values = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=processed_data, start=start, limit=limit, step=step)

    x = range(start, limit, step)
    plt.plot(x, coherence_values)
    plt.xlabel("Num Topics")
    plt.ylabel("Coherence score")
    plt.legend(("coherence_values"), loc='best')
    plt.show()
    
    x = range(start, limit, step)
    plt.plot(x, perpexities_values)
    plt.xlabel("Num Topics")
    plt.ylabel("perpexities_values")
    plt.legend(("perpexities_values"), loc='best')
    plt.show()

if __name__ == '__main__':
    
    print('Number of unique tokens: %d' % len(dictionary))
    print('Number of documents: %d' % len(corpus))

    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
: INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=14676, num_topics=6, decay=0.5, chunksize=2000) in 11.65s', 'datetime': '2022-08-29T20:13:47.169947', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'created'}
# 2022-08-29 20:13:47,171 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2022-08-29 20:14:11,419 : INFO : 15 accumulators retrieved from output queue
# 2022-08-29 20:14:11,447 : INFO : accumulated word occurrence stats for 114732 virtual documents
# 2022-08-29 20:14:24,282 : INFO : -7.595 per-word bound, 193.4 perplexity estimate based on a held-out corpus of 161539 documents with 726752 words
# 2022-08-29 20:14:24,282 : INFO : using symmetric alpha at 0.14285714285714285
# 2022-08-29 20:14:24,283 : INFO : using symmetric eta at 0.14285714285714285
# 2022-08-29 20:14:24,284 : INFO : using serial LDA version on this node
# 2022-08-29 20:14:24,290 : INFO : running online (single-pass) LDA training, 7 topics, 1 passes over the supplied corpus of 161539 documents, updating model once every 2000 documents, evaluating perplexity every 20000 documents, iterating 50x with a convergence threshold of 0.001000
# 2022-08-29 20:14:24,291 : INFO : PROGRESS: pass 0, at document #2000/161539
# 2022-08-29 20:14:24,558 : INFO : merging changes from 2000 documents into a model of 161539 documents
# 2022-08-29 20:14:24,562 : INFO : topic #6 (0.143): 0.027*"단점" + 0.023*"장점" + 0.019*"말" + 0.019*"버그" + 0.018*"사람" + 0.016*"업데이트" + 0.015*"유저" + 0.013*"욕" + 0.012*"검열" + 0.012*"친구"
# 2022-08-29 20:14:24,562 : INFO : topic #0 (0.143): 0.038*"현질" + 0.031*"사람" + 0.021*"맵" + 0.019*"캐릭터" + 0.019*"옷" + 0.017*"벅스" + 0.014*"유저" + 0.012*"문제" + 0.011*"추천" + 0.010*"입양"
# 2022-08-29 20:14:24,563 : INFO : topic #3 (0.143): 0.032*"현질" + 0.027*"사람" + 0.023*"로벅" + 0.023*"점프" + 0.022*"맵" + 0.018*"핵" + 0.018*"벅스" + 0.015*"버그" + 0.015*"입양" + 0.015*"업데이트"
# 2022-08-29 20:14:24,563 : INFO : topic #5 (0.143): 0.056*"버그" + 0.048*"벅스" + 0.029*"유저" + 0.028*"친구" + 0.028*"렉" + 0.020*"로블" + 0.015*"현질" + 0.013*"별" + 0.012*"해킹" + 0.011*"단점"
# 2022-08-29 20:14:24,563 : INFO : topic #4 (0.143): 0.043*"버그" + 0.037*"재미" + 0.035*"로블" + 0.035*"화면" + 0.023*"광고" + 0.020*"벅스" + 0.017*"단점" + 0.017*"렉" + 0.015*"입양" + 0.015*"유저"
# 2022-08-29 20:14:24,564 : INFO : topic diff=8.577397, rho=1.000000
# 2022-08-29 20:14:24,564 : INFO : PROGRESS: pass 0, at document #4000/161539
# 2022-08-29 20:14:24,752 : INFO : merging changes from 2000 documents into a model of 161539 documents
# 2022-08-29 20
# 2022-08-29 20:14:25,828 : INFO : topic #6 (0.143): 0.046*"단점" + 0.042*"장점" + 0.040*"말" + 0.034*"킹" + 0.030*"욕" + 0.029*"피스" + 0.027*"업데이트" + 0.024*"사람" + 0.014*"숫자" + 0.014*"유저"
# 2022-08-29 20:14:25,829 : INFO : topic #5 (0.143): 0.088*"벅스" + 0.073*"렉" + 0.046*"버그" + 0.041*"친구" + 0.029*"유저" + 0.025*"해킹" + 0.025*"별" + 0.024*"현질" + 0.015*"무료" + 0.014*"서버"
# 2022-08-29 20:14:25,829 : INFO : topic #4 (0.143): 0.168*"버그" + 0.069*"재미" + 0.056*"화면" + 0.051*"로블" + 0.032*"광고" + 0.025*"렉" + 0.022*"모바일" + 0.013*"유저" + 0.011*"입양" + 0.011*"제작자"
# 2022-08-29 20:14:25,829 : INFO : topic diff=0.245897, rho=0.353553
# 2022-08-29 20:14:25,830 : INFO : PROGRESS: pass 0, at document #18000/161539
# 2022-08-29 20:14:25,979 : INFO : merging changes from 2000 documents into a model of 161539 documents
# 2022-08-29 20:14:25,983 : INFO : topic #4 (0.143): 0.164*"버그" + 0.077*"재미" + 0.062*"화면" + 0.049*"로블" + 0.031*"광고" + 0.025*"렉" + 0.023*"모바일" + 0.013*"유저" + 0.012*"제작자" + 0.010*"채팅"
# 2022-08-29 20:14:25,983 : INFO : topic #1 (0.143): 0.081*"계정" + 0.035*"로그인" + 0.029*"서버" + 0.027*"돈" + 0.019*"해킹" + 0.017*"비밀번호" + 0.016*"신고" + 0.016*"가입" + 0.015*"로블" + 0.015*"비번"
# 2022-08-29 20:14:25,984 : INFO : topic #5 (0.143): 0.087*"벅스" + 0.076*"렉" + 0.040*"친구" + 0.037*"버그" + 0.031*"유저" + 0.026*"별" + 0.025*"해킹" + 0.022*"현질" + 0.015*"옷" + 0.015*"제작자"
# 2022-08-29 20:14:25,984 : INFO : topic #6 (0.143): 0.044*"단점" + 0.041*"장점" + 0.039*"말" + 0.033*"욕" + 0.032*"킹" + 0.029*"업데이트" + 0.027*"피스" + 0.025*"사람" + 0.015*"유저" + 0.013*"숫자"
# 2022-08-29 20:14:25,985 : INFO : topic #3 (0.143): 0.042*"맵" + 0.036*"사람" + 0.035*"점프" + 0.024*"로벅" + 0.023*"핵" + 0.022*"망겜" + 0.019*"바이브" + 0.019*"입양" + 0.018*"현질" + 0.018*"스킨"
# 2022-08-29 20:14:25,985 : INFO : topic diff=0.210691, rho=0.333333

# %%
j=0
for i in range(len(coherence_values)):
    print(j+2," coherence_value: ",coherence_values[i])
    print(j+2, " perpexities_values: ", perpexities_values[i])
    j+=1

# %%
num_topics = 5

temp = dictionary[0]
id2word = dictionary.id2token

model = model_List[num_topics-2]

top_topics = model.top_topics(corpus) #, num_words=20)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)

# %%
import pickle
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

# %%
lda_visualization = gensimvis.prepare(model, corpus, dictionary, sort_topics=True)
pyLDAvis.save_html(lda_visualization, 'output/roblox_topic_modeling_topic5_0828.html')
