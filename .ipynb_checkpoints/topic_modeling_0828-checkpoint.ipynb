# %%
from konlpy.tag import Okt
from tqdm import tqdm
import re
import pickle
import csv
import pandas as pd
from pandas import DataFrame 
import numpy as np
import warnings
from nltk.corpus import stopwords

warnings.filterwarnings(action='ignore')

# %%
title='zepeto.csv'
word_list =set(['이','앱','폰','개','저','요','제발','뭐','하나','그냥','해','데','못','때문','그것','게','지금','내','걸','나','위','로','캐','이안','고','처럼','밑','스','방금','제','다시','왜','안','갑자기','처음','전','줄','한번','오늘','아예','해도','원래','번','만','하라','때','그거','심해','가끔','피하','하나요','욤','튕기','뭘','약간','렉좀','인','옆','것','그','또','꼭','명','건','부분','자주','글','수가','분','곳','경우','바로','자꾸','용','여','터','오','튕겨','어쩌','더','수','조금','짱','음','등','해주시','함','등등','찍','일단','자기','생기','일리','후','뒤','이번','이후','가기','중이','오지','땜','응','장공','보고','너','듯','세','배','무엇','게속','안나','그레','전혀','다가','놀수','정말','별로','굿','벌','색','제패','토','새','쫌','염','것좀','강추','멩','정도','번','기','거의','살','달','좀','거','진짜','저기','밌','이나','주','안눌려','재','완전','최고','이건','임','애','막','슴','개도','주기도','여기','무','영','고요','니','영','아주','생각','생','맘','구','산','버','화가','혐기','주시','물','피','다른','리지','계속','무슨','잘못','뭔가','실망','욤','난','답','일이','자체','끼리','다음','습','계속','가요','보','최악','잠깐','이상','몇번','며칠','어디','가지','직접','눈','업','날','끝','뎅','하니','혹시','건가','네','요즘','도','를','이제','좋더','얼마','언제','대박','거기','된거','그대로','주심','예전','제대로','분명','시','제페토'])
word_list
# Out:
# {'가기',
#  '가끔',
#  '가요',
#  '가지',
#  '갑자기',
#  '강추',
#  '개',
#  '개도',
#  '거',
#  '거기',
#  '거의',
#  '건',
#  '건가',
#  '걸',
#  '것',
#  '것좀',
#  '게',
#  '게속',
#  '경우',
#  '계속',
#  '고',
#  '고요',
#  '곳',
#  '구',
#  '굿',
#  '그',
#  '그거',
#  '그것',
#  '그냥',
#  '그대로',
#  '그레',
#  '글',
#  '기',
#  '꼭',
#  '끝',
#  '끼리',
#  '나',
#  '난',
#  '날',
#  '내',
#  '너',
#  '네',
#  '놀수',
#  '눈',
#  '니',
#  '다가',
#  '다른',
#  '다시',
#  '다음',
#  '달',
#  '답',
#  '대박',
#  '더',
#  '데',
#  '뎅',
#  '도',
#  '된거',
#  '뒤',
#  '듯',
#  '등',
#  '등등',
#  '때',
#  '때문',
#  '땜',
#  '또',
#  '렉좀',
#  '로',
#  '를',
#  '리지',
#  '막',
#  '만',
#  '맘',
#  '멩',
#  '며칠',
#  '명',
#  '몇번',
#  '못',
#  '무',
#  '무슨',
#  '무엇',
#  '물',
#  '뭐',
#  '뭔가',
#  '뭘',
#  '밌',
#  '밑',
#  '바로',
#  '방금',
#  '배',
#  '버',
#  '번',
#  '벌',
#  '별로',
#  '보',
#  '보고',
#  '부분',
#  '분',
#  '분명',
#  '산',
#  '살',
#  '새',
#  '색',
#  '생',
#  '생각',
#  '생기',
#  '세',
#  '수',
#  '수가',
#  '스',
#  '슴',
#  '습',
#  '시',
#  '실망',
#  '심해',
#  '아예',
#  '아주',
#  '안',
#  '안나',
#  '안눌려',
#  '애',
#  '앱',
#  '약간',
#  '어디',
#  '어쩌',
#  '언제',
#  '얼마',
#  '업',
#  '여',
#  '여기',
#  '염',
#  '영',
#  '옆',
#  '예전',
#  '오',
#  '오늘',
#  '오지',
#  '완전',
#  '왜',
#  '요',
#  '요즘',
#  '욤',
#  '용',
#  '원래',
#  '위',
#  '음',
#  '응',
#  '이',
#  '이건',
#  '이나',
#  '이번',
#  '이상',
#  '이안',
#  '이제',
#  '이후',
#  '인',
#  '일단',
#  '일리',
#  '일이',
#  '임',
#  '자기',
#  '자꾸',
#  '자주',
#  '자체',
#  '잘못',
#  '잠깐',
#  '장공',
#  '재',
#  '저',
#  '저기',
#  '전',
#  '전혀',
#  '정도',
#  '정말',
#  '제',
#  '제대로',
#  '제발',
#  '제패',
#  '제페토',
#  '조금',
#  '좀',
#  '좋더',
#  '주',
#  '주기도',
#  '주시',
#  '주심',
#  '줄',
#  '중이',
#  '지금',
#  '직접',
#  '진짜',
#  '짱',
#  '쫌',
#  '찍',
#  '처럼',
#  '처음',
#  '최고',
#  '최악',
#  '캐',
#  '터',
#  '토',
#  '튕겨',
#  '튕기',
#  '폰',
#  '피',
#  '피하',
#  '하나',
#  '하나요',
#  '하니',
#  '하라',
#  '한번',
#  '함',
#  '해',
#  '해도',
#  '해주시',
#  '혐기',
#  '혹시',
#  '화가',
#  '후'}

# %%
def clean_text(text):
    text = text.replace(".", "").strip()
    text = text.replace("·", " ").strip()
    pattern = '[^ ㄱ-ㅣ가-힣|0-9]+'
    text = re.sub(pattern=pattern, repl='', string=text)
    return text

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

# %%
def get_nouns(tokenizer, sentence):
    nouns=tokenizer.nouns(sentence)
    for word in word_list: 
        nouns=remove_values_from_list(nouns,word)
    return nouns

def tokenize(df):
    tokenizer = Okt()
    processed_data = [] 
    for sent in tqdm(df['content']):
        sentence = clean_text(str(sent).replace("\n", "").strip())
        processed_data.append(get_nouns(tokenizer, sentence))
    return processed_data

# %%
def save_processed_data(processed_data):
    with open("output/tokenized_data_"+title, 'w', newline="", encoding='utf-8') as f:
        writer = csv.writer(f)
        for data in processed_data:
            writer.writerow(data)
            
if __name__ == '__main__':
    tdf = pd.read_csv("data/zepeto.csv")
    df=tdf[['userName','at','content','score','thumbsUpCount']]
    df.dropna(subset = ['content'])
    processed_data = tokenize(df)
    save_processed_data(processed_data)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 52550/52550 [03:07<00:00, 279.93it/s]

# %%
processed_data = [sent.strip().split(",") for sent in tqdm(open("output/tokenized_data_"+title,'r',encoding='utf-8').readlines())]
processed_data = DataFrame(processed_data)
processed_data[0] = processed_data[0].replace("", np.nan)
processed_data = processed_data[processed_data[0].notnull()]
processed_data = processed_data.values.tolist()
processed_data2=[]
for i in processed_data:
    i = list(filter(None, i))
    processed_data2.append(i)
processed_data = processed_data2
processed_data
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 52550/52550 [00:00<00:00, 130691.96it/s]
# [['사용성', '개선', '오히려', '월드', '기능', '마비', '사용성', '호환', '문제'],
#  ['퀘스트',
#   '스크래치',
#   '광고',
#   '퀘스트',
#   '카드',
#   '완료',
#   '방치',
#   '일',
#   '광고',
#   '콜라보',
#   '정신',
#   '유저',
#   '속눈썹',
#   '착용',
#   '모자',
#   '파트',
#   '모자',
#   '머리핀',
#   '해결',
#   '중복',
#   '착용',
#   '앞머리',
#   '착용',
#   '붙임머리',
#   '포니테일',
#   '선택',
#   '붙임머리',
#   '앞머리',
#   '선택',
#   '문제',
#   '아래',
#   '문제',
#   '은',
#   '중복',
#   '착용',
#   '허용',
#   '해결'],
#  ['체제', '읍'],
#  ['캐릭터',
#   '소통',
#   '단점',
#   '첫',
#   '자신',
#   '캐릭터',
#   '사진',
#   '있었르',
#   '현질',
#   '면서',
#   '캐릭터',
#   '추가',
#   '이유',
#   '남',
#   '캐릭터',
#   '사진',
#   '젬',
#   '꽤',
#   '레벨',
#   '플레이',
#   '젬',
#   '기분',
#   '나머지'],
#  ['케릭', '키', '조절', '예', '식', '얼굴', '몸', '팔다리', '신체', '조절'],
#  ['스크래치', '기분', '중단', '젠', '접속', '피해', '피해', '신고', '접지', '최대한', '점', '별', '별'],
#  ['게임'],
#  ['업데이트',
#   '업데이트',
#   '월드',
#   '방',
#   '검색',
#   '기능',
#   '방',
#   '검색',
#   '기능',
#   '월드',
#   '갈수',
#   '그게',
#   '재미'],
#  ['퍼즐', '스파이', '미션', '잼'],
#  ['아유'],
#  ['아이', '세면', '요별'],
#  ['동영상', '게시', '동영상', '동영상', '업로드', '동영상', '길이'],
#  ['마디',
#   '코인',
#   '출석',
#   '젬',
#   '노가다',
#   '현질',
#   '단점',
#   '아이템',
#   '코인',
#   '비교',
#   '마지막',
#   '템플릿',
#   '사용',
#   '월드',
#   '접속',
#   '오류로',
#   '마지막',
#   '방',
#   '만들기',
#   '일시',
#   '오류'],
#  ['캐릭터', '춤'],
#  ['꿀잼'],
#  ['민물고기', '선택'],
#  ['무료', '가스', '경로', '추가'],
#  ['안드로이드', '설문조사', '아이폰', '친구', '젬', '획득', '미션', '설문조사'],
#  ['테마', '테마'],
#  ['별빛', '초가'],
#  ['아바타',
#   '젬',
#   '젬',
#   '설문조사',
#   '지급',
#   '이벤트',
#   '젬',
#   '이벤트',
#   '미션',
#   '점프',
#   '맵',
#   '렉',
#   '똑바로',
#   '게임',
#   '와이파이',
#   '문제',
#   '이점',
#   '젬',
#   '지급',
#   '플레이어',
#   '말',
#   '교실',
#   '월드',
#   '욕',
#   '성희롱',
#   '신고',
#   '정지'],
#  ['특정',
#   '형식',
#   '광고',
#   '강제',
#   '종료',
#   '이유',
#   '일일',
#   '미션',
#   '완료',
#   '보상',
#   '광고',
#   '추가',
#   '보상',
#   '해결'],
#  ['아바타', '광고', '퀘스트', '월드', '로블', '점프', '젬', '젬'],
#  ['스타', '일링', '무릎', '모습'],
#  ['요전', '은설', '게임', '옛날', '스킨', '배경'],
#  ['광고', '보기', '취소', '몇', '일전', '체크'],
#  ['사람', '젬', '젬', '쪼금', '수정'],
#  ['업데이트'],
#  ['시제', '페로', '설치'],
#  ['캐릭터'],
#  ['채팅', '보석', '는걸', '채팅', '보석', '사람', '벼텼어'],
#  ['설치', '오류', '오류', '안떳으'],
#  ['오류', '버그'],
#  ['자밌어', '게임'],
#  ['욥'],
#  ['누가', '랙', '별'],
#  ['개시', '삭제', '버그'],
#  ['점프', '마스터'],
#  ['시작', '코인', '젬', '시작', '젬', '젬'],
#  ['광고', '스크래치', '글쎄', '광고', '표시', '스크래치', '배경화면', '요하', '스크래치'],
#  ['캐릭터', '옷', '헤어', '장식등'],
#  ['사람', '근대', '젚속', '영어', '띠', '면서', '젚속'],
#  ['시작'],
#  ['광고'],
#  ['맵애', '코인'],
#  ['나이', '상관'],
#  ['푹',
#   '즐겜',
#   '유저',
#   '젬얻는',
#   '방법',
#   '선물',
#   '크리',
#   '템',
#   '선물',
#   '점',
#   '렉',
#   '미션',
#   '코인',
#   '그게',
#   '광고',
#   '건너',
#   '건너',
#   '클릭',
#   '버퍼링',
#   '광고',
#   '건너',
#   '클릭',
#   '점',
#   '점',
#   '코인',
#   '퍼',
#   '반대',
#   '젬',
#   '주네',
#   '스크레치',
#   '뽑기',
#   '확률',
#   '조작',
#   '점',
#   '코인',
#   '템',
#   '크리',
#   '템',
#   '가격',
#   '코인',
#   '출시',
#   '코인',
#   '가격',
#   '출시',
#   '젬',
#   '젬',
#   '스크래치',
#   '확률',
#   '조작',
#   '꼭꼭',
#   '코',
#   '스크래치',
#   '번은'],
#  ['크루', '케릭', '마음'],
#  ['캐릭터'],
#  ['업데이트', '일부러'],
#  ['코인', '삭제'],
#  ['옷'],
#  ['광고'],
#  ['게임', '놀이'],
#  ['기프트', '카드', '코인', '구매', '거절', '잼', '버그'],
#  ['겜', '다른사람', '팔로우', '곶', '영상', '겜'],
#  ['크리에이터', '템', '젬', '코인', '선물', '기능'],
#  ['중독', '성도', '재미', '오류', '날때', '수정'],
#  ['월드'],
#  ['시작', '유저', '게시', '삭제', '삭제', '설', '라이브', '일반인', '한텐'],
#  ['게임', '렉'],
#  ['러브', '다이브', '포토', '부스'],
#  ['게임', '정지', '계정', '삭제', '방법', '신고'],
#  ['미션',
#   '통해',
#   '젬',
#   '코인',
#   '장점',
#   '광고',
#   '터치',
#   '얼굴',
#   '장점',
#   '카메라',
#   '모드',
#   '제스쳐',
#   '렉',
#   '지장',
#   '기능',
#   '제각각',
#   '무과금러',
#   '현질',
#   '크리에이터',
#   '상점',
#   '머리카락',
#   '평균',
#   '젬이',
#   '미션',
#   '완료',
#   '미션',
#   '미션',
#   '난이도',
#   '친구',
#   '선물',
#   '줄때',
#   '크리에이터',
#   '상품',
#   '선물',
#   '크리에이터',
#   '상품',
#   '위시',
#   '리스트',
#   '크리에이터',
#   '상품',
#   '위시',
#   '단점',
#   '방면',
#   '게임'],
#  ['유저', '옷', '머리카락', '한가지', '점', '동안', '얼굴', '저장', '저장', '저절로'],
#  ['현질', '비', '현질', '유저'],
#  ['진짜진짜', '점', '젬', '청', '젬', '미션', '제공', '미션', '보상', '점'],
#  ['루피', '가입'],
#  ['깜직'],
#  ['폰트', '사람', '안돠', '사람'],
#  ['힘'],
#  ['홒'],
#  ['랙', '게시', '고정', '기능'],
#  ['젬좀', '무료젬', '노가다', '보상', '실패'],
#  ['와우'],
#  ['리뷰', '선물', '기능', '젬', '코인', '순', '젬', '선물', '크리에이터', '상품', '선물'],
#  ['부탁', '캐릭터', '상태', '옷', '캐릭터', '생김새', '표정', '제스처'],
#  ['점', '다른사람', '게임', '채팅', '점', '점', '알림'],
#  ['업데이트'],
#  ['변태'],
#  ['크리에이터', '아이템', '선물', '젬'],
#  ['재미', '친구', '게임'],
#  ['건의',
#   '유저',
#   '현질',
#   '젬',
#   '크리에이터',
#   '옷',
#   '옷',
#   '옷',
#   '엕',
#   '오류로',
#   '안보',
#   '옷',
#   '옷',
#   '코디',
#   '저장',
#   '해논',
#   '세트',
#   '옷',
#   '옷',
#   '사람',
#   '젬',
#   '다시젬'],
#  ['프리미엄', '결제', '취소'],
#  ['김유민'],
#  ['생일', '인증'],
#  ['영상', '숨기', '기도'],
#  ['젬', '뿌리', '코인'],
#  ['젠',
#   '젬',
#   '현질',
#   '젬',
#   '선물',
#   '캐릭터',
#   '리샷코',
#   '젬',
#   '마찬가지',
#   '피해',
#   '욕',
#   '사람',
#   '이유',
#   '워낙',
#   '코인',
#   '시작',
#   '몇개',
#   '젬',
#   '빨',
#   '리안',
#   '소문',
#   '공감',
#   '계정',
#   '검색',
#   '이름',
#   '옷',
#   '심각',
#   '현질',
#   '옷',
#   '젬',
#   '별',
#   '옷',
#   '돈',
#   '젬',
#   '엊는데',
#   '점점',
#   '돈',
#   '젬'],
#  ['관리자',
#   '김똥꼬',
#   '닉네임',
#   '개월',
#   '활동',
#   '포토',
#   '부스',
#   '촬영',
#   '로딩',
#   '그때',
#   '렉',
#   '가격',
#   '겨우',
#   '젬',
#   '사려',
#   '이득',
#   '사람',
#   '젬',
#   '배려'],
#  ['찜', '친구', '선물', '안보', '여요'],
#  ['회원', '가입', '선물', '회원', '가입', '똑바로', '젬좀'],
#  ['게시', '물이', '시간', '삭제'],
#  ['와우'],
#  ['메타', '쓰레기', '거품', '이용', '어려움', '사람', '다운', '사람', '어딧'],
#  ['퀘스트', '젬', '광고', '미션', '건너', '화면', '장난', '젬'],
#  ['게시'],
#  ['개인정보', '저가', '로블보다싢음'],
#  ['게임',
#   '강력',
#   '추천',
#   '월드',
#   '친구',
#   '채팅',
#   '마이크',
#   '키',
#   '크리',
#   '템',
#   '젬일까',
#   '코인',
#   '추가',
#   '단점',
#   '업데이트',
#   '메롱이',
#   '볼',
#   '빵빵',
#   '액션',
#   '모드',
#   '업뎃',
#   '아이폰',
#   '삼성',
#   '반올림',
#   '삼성',
#   '반올림',
#   '이점',
#   '수정',
#   '별',
#   '별',
#   '문제'],
#  ['친구', '좀비', '맵', '젬', '젬'],
#  ['메뉴'],
#  ['느낌', '헤어스타일'],
#  ['진짜진짜',
#   '누군가',
#   '그림',
#   '캐릭터',
#   '저격',
#   '말',
#   '사람',
#   '알',
#   '팔로우',
#   '거나',
#   '선물',
#   '신고',
#   '제제'],
#  ['강'],
#  ['개시', '삭'],
#  ['젬'],
#  ['어플',
#   '친구',
#   '슈가',
#   '버그',
#   '젬',
#   '아이템',
#   '구매',
#   '점',
#   '버그',
#   '악용',
#   '이기',
#   '슈가',
#   '계정',
#   '정지',
#   '회수'],
#  ['프리', '젬', '기본', '미션', '완료', '보상', '주네', '어제'],
#  ['맵', '문제'],
#  ['단점'],
#  ['꿀잼임'],
#  ['젬', '하루', '룰렛', '젬', '추가', '점프', '마스터', '월드', '게임', '월드'],
#  ['캐릭터', '볼때', '게임', '애기', '게임', '듷', '기분', '전환', '게임', '게임'],
#  ['게임', '젬', '코인', '성인', '인증', '필요'],
#  ['항상', '란', '게임', '파티', '게임', '돈', '게시', '삭제'],
#  ['리', '워드', '다해', '주지', '총', '젬', '안주'],
#  ['개인',
#   '정보',
#   '마냥',
#   '생년',
#   '월일',
#   '보호자',
#   '개인정보',
#   '닙',
#   '감사',
#   '생년',
#   '월',
#   '일만',
#   '보호자',
#   '이름',
#   '은',
#   '욕설',
#   '폭력',
#   '사람',
#   '강제',
#   '삭제',
#   '부탁'],
#  ['캐릭터', '초기', '앺', '신고'],
#  ['젬',
#   '코인',
#   '기도',
#   '상의',
#   '하의',
#   '헤어',
#   '사람',
#   '대화',
#   '말다툼',
#   '욕',
#   '저격',
#   '험담',
#   '지네',
#   '애기',
#   '싸움',
#   '사람',
#   '계정',
#   '탈퇴',
#   '사람',
#   '경험',
#   '요가',
#   '문제',
#   '점프',
#   '맵',
#   '힐때',
#   '렉',
#   '버그',
#   '튕',
#   '먹통',
#   '별',
#   '십지',
#   '게임',
#   '훨신',
#   '처',
#   '망겜망겜',
#   '신비',
#   '아파트',
#   '욕',
#   '기억',
#   '생생',
#   '하내',
#   '망겜',
#   '욕',
#   '사람',
#   '무시'],
#  ['부터',
#   '사기',
#   '게임',
#   '평가',
#   '단점',
#   '장점',
#   '그게',
#   '면',
#   '장점',
#   '친구',
#   '궈',
#   '님',
#   '친구',
#   '친구',
#   '장점',
#   '게다가',
#   '실제',
#   '목소리',
#   '장점',
#   '로그인',
#   '따위',
#   '안해',
#   '장점',
#   '단점',
#   '장점',
#   '로그인',
#   '면',
#   '친구',
#   '채팅',
#   '안해',
#   '재미',
#   '이랗',
#   '단점',
#   '돈',
#   '현질',
#   '단점',
#   '캐릭터',
#   '머리카락',
#   '의상',
#   '마음',
#   '단점',
#   '평가',
#   '별',
#   '자',
#   '평가',
#   '식'],
#  ['얘전', '몰래', '모자', '꽤', '친한친구', '상황', '극도', '학교'],
#  ['젬', '설문조사', '이용', '아이폰', '친구', '설문조사', '삼성', '친구'],
#  ['별', '점주', '려고', '햇', '점', '현질', '유도', '번제', '오류', '튕길때'],
#  ['퀘', '버그', '림', '어텋게', '광고', '수작', '광고', '안넘', '가짐'],
#  ['잼'],
#  ['캐릭터',
#   '현질',
#   '유도',
#   '잼',
#   '방법',
#   '렉',
#   '종종',
#   '선물',
#   '크리',
#   '템',
#   '다른사람',
#   '선물',
#   '기능',
#   '꽤',
#   '유저',
#   '잼',
#   '방법',
#   '코인',
#   '템'],
#  ['다른사람', '이야기', '상극', '도하', '월드', '좀튕겨', '플레이'],
#  ['업데이트',
#   '전보',
#   '업데이트',
#   '광고',
#   '속도',
#   '신고',
#   '시간',
#   '젶메',
#   '처리',
#   '어케',
#   '말',
#   '오해',
#   '사람'],
#  ['배터리', '발열', '버벅거림', '리그'],
#  ['게임', '개인정보', '전화번호', '키즈'],
#  ['렉'],
#  ['허헣', '게시', '삭제', '젶메', '크루', '쨋', '이거쫌'],
#  ['돈'],
#  ['아이템', '환불', '기능'],
#  ['별빛', '초', '재미'],
#  ['아바타'],
#  ['추천'],
#  ['피노키오'],
#  ['아바타', '커스터', '마이', '징', '눌리', '살짝', '표현'],
#  ['젬', '얻지', '크리', '템', '공식', '옷', '젬', '코인', '할인'],
#  ['스킨', '미기', '좀더'],
#  ['옜날', '좀비', '젔', '드림'],
#  ['겜', '점'],
#  ['인생게임', '버그', '오류', '꽤', '편'],
#  ['업데이트'],
#  ['문제',
#   '게시',
#   '삭재',
#   '태그',
#   '삭재',
#   '자꾸만',
#   '상태',
#   '메시지',
#   '상태',
#   '메시지',
#   '일시',
#   '오류',
#   '좀비',
#   '게임',
#   '파티',
#   '게임',
#   '월드'],
#  ['게임', '짓', '컨셉', '면서', '인터넷', '세상'],
#  ['메타',
#   '버스',
#   '게임',
#   '장르',
#   '마음',
#   '옷',
#   '스텀',
#   '플레이',
#   '방법',
#   '더욱',
#   '크레이터',
#   '크레이터',
#   '재미',
#   '추천',
#   '추천',
#   '프리미엄',
#   '혜택',
#   '와르르',
#   '르',
#   '추천',
#   '추천',
#   '자신',
#   '모습',
#   '스텀',
#   '혜택',
#   '프리미엄',
#   '크리에이터',
#   '점프',
#   '맵',
#   '아이템',
#   '크리에이터',
#   '별',
#   '크리에이터',
#   '아이템',
#   '사서',
#   '코디',
#   '후회',
#   '안해',
#   '추천',
#   '크리에이터',
#   '젬',
#   '아이템',
#   '후회',
#   '한적',
#   '게임',
#   '대해',
#   '관심',
#   '당장',
#   '설치',
#   '인기',
#   '스타',
#   '추천',
#   '팔로워',
#   '상승',
#   '템플릿',
#   '사용'],
#  ['젬', '신상', '매번', '젬', '젬', '현질', '유도', '메롱', '액션', '모드', '메롱이', '유저'],
#  ['발전'],
#  ['미음'],
#  ['무제'],
#  ['캐시', '삭제', '랙', '결제', '돈', '충전', '잔액', '부족', '결제', '오류'],
#  ['사람', '젬모으기', '크리에이터', '옷', '사람', '선물', '항상'],
#  ['보호자', '동의', '점'],
#  ['강', '추강', '추'],
#  ['설치'],
#  ['마마마'],
#  ['서버', '게임', '추천', '해염'],
#  ['젬', '젬', '가격'],
#  ['젬', '쩍', '하다보닌까', '젬', '코인', '넘적게쫌', '젬'],
#  ['젬', '쉬움'],
#  ['젬'],
#  ['옷', '삭제'],
#  ['영상', '파란', '버튼', '영상', '사람'],
#  ['근대', '사람', '잼', '미니'],
#  ['사용', '유저', '메세지', '친구', '모자', '사진', '전화번호', '무시', '다행'],
#  ['렉'],
#  ['바', '당황', '게시', '삭제', '가안'],
#  ['옷', '머리카락', '다젬', '현질', '유도', '설문조사', '젬', '젠', '설문조사', '젬'],
#  ['다운로드', '마'],
#  ['게임',
#   '그림',
#   '이모티콘',
#   '소통',
#   '이모티콘',
#   '다만',
#   '광고',
#   '알람',
#   '울림',
#   '사람',
#   '메세지',
#   '여러분',
#   '참여'],
#  ['겁나잼쎠'],
#  ['가이거', '리뷰', '문제', '회원', '가입', '선물', '회원', '가입'],
#  ['재미'],
#  ['월드', '렉'],
#  ['사용',
#   '핵꿀잼재패토',
#   '추천',
#   '추천',
#   '앞',
#   '로그인',
#   '돼지',
#   '캐릭터',
#   '친구',
#   '월드',
#   '팔로우',
#   '재패',
#   '토라',
#   '게임',
#   '신분',
#   '진심',
#   '감사'],
#  ['아이템'],
#  ['젬'],
#  ['현재',
#   '이용',
#   '유저',
#   '설치',
#   '말',
#   '고민',
#   '리뷰',
#   '오신',
#   '설치',
#   '사람',
#   '호불호',
#   '콘텐츠',
#   '관리',
#   '업데이트',
#   '관리자',
#   '보완',
#   '개선',
#   '점',
#   '말',
#   '첫',
#   '아래',
#   '스셨',
#   '다시피',
#   '게시',
#   '삭제',
#   '문제',
#   '둘째',
#   '현재',
#   '아이템',
#   '아이템',
#   '우선',
#   '보이',
#   '정렬순서',
#   '기능',
#   '고정',
#   '기능',
#   '관리자',
#   '이점',
#   '아아',
#   '세번',
#   '수정',
#   '알림',
#   '자신',
#   '팔로우',
#   '사람',
#   '알림',
#   '설정',
#   '사람',
#   '아이템',
#   '출시',
#   '알림',
#   '기능',
#   '추가',
#   '감'],
#  ['게임', '중독', '성도', '버전', '겁', '버전'],
#  ['로그인'],
#  ['크리에이터', '제품', '부스', '사진', '월드', '사진', '공중', '현상', '땅', '현상'],
#  ['렉', '게임', '휴대폰', '작동'],
#  ['잼', '추천'],
#  ['스트레스', '확'],
#  ['오류', '단점', '컨텐츠'],
#  ['점점', '돈'],
#  ['잼', '출석', '잼', '돨것'],
#  ['추천', '추천', '추천', '랜덤', '구별', '추천'],
#  ['젬', '게시', '물이', '삭제', '점', '좀더', '신경'],
#  ['아이탬'],
#  ['꽃미남'],
#  ['게임', '게임', '절대'],
#  ['실수', '계정', '탈퇴', '계정', '찿'],
#  ['조작', '꿍시'],
#  ['와이파이', '로딩', '빨'],
#  ['오류',
#   '템플릿',
#   '사용',
#   '마다',
#   '첫',
#   '화면',
#   '바',
#   '움직',
#   '노래',
#   '재생',
#   '결과',
#   '리기',
#   '캐릭터',
#   '흰색',
#   '빛',
#   '보이지'],
#  ['유저',
#   '우선',
#   '옷',
#   '그다음',
#   '친구',
#   '월드',
#   '기도',
#   '접속',
#   '팔로워',
#   '취소',
#   '팔로잉',
#   '점',
#   '오류'],
#  ['핸드폰', '로그인'],
#  ['유저',
#   '상점',
#   '캐릭터',
#   '포즈',
#   '취하',
#   '움직',
#   '업데이트',
#   '캐릭터',
#   '마네킹',
#   '리뷰',
#   '윰직이',
#   '포즈',
#   '취하',
#   '옷',
#   '리뷰',
#   '의견',
#   '반영'],
#  ['잼', '대게', '게임'],
#  ['한지', '사람', '포토', '부스', '영상', '저장', '렉', '점'],
#  ['감사', '유나'],
#  ['유저', '랍니', '팔로워', '관리', '기능', '팔로워', '관리'],
#  ['스타일', '의상', '표시'],
#  ['캐릭터'],
#  ['단점', '최애', '게임'],
#  ['럭키', '박스'],
#  ['좀비'],
#  ['댓글', '친구', '알림', '보지', '댓글', '거게', '답글', '욕설', '로그아웃', '해킹'],
#  ['군뎅', '저장', '공간', '도둑'],
#  ['광고'],
#  ['업데이트', '업데이트', '개시', '물이', '삭제', '개시', '물이', '삭제', '점'],
#  ['캐릭터', '실감', '네모', '바이러스'],
#  ['젬', '현질', '유도', '젬', '무료', '젬', '년'],
#  ['살짝', '점', '아이폰', '기능'],
#  ['스텀', '설문조사', '걱정', '젬', '하루', '체크', '젬'],
#  ['표정', '표정', '무표정', '랄'],
#  ['유저',
#   '저번',
#   '토요일',
#   '코인',
#   '구매',
#   '환불',
#   '신청',
#   '실수',
#   '환불',
#   '문의',
#   '정지',
#   '오늘이',
#   '정지'],
#  ['업데이트', '게시', '삭제'],
#  ['유저', '친구', '스트레스', '기분', '게시', '캐릭터', '캐릭터', '게임', '추천'],
#  ['최애', '게임', '참고', '이름', '김솔힛'],
#  ['보상', '광고', '튕', '카메라', '사진', '미션', '업데이트', '방법', '방법', '보상'],
#  ['게임',
#   '사람',
#   '저가',
#   '테블릿',
#   '게임',
#   '을해',
#   '카톡',
#   '전화',
#   '전호',
#   '방법',
#   '저희',
#   '엄마',
#   '로그인',
#   '방법'],
#  ['틱톡', '사람', '틱톡', '욕', '자제'],
#  ['크리에이터', '제품', '선물', '가능'],
#  ['개꿀잼', '알림', '옴', '옷', '캐릭', '캐릭', '선택', '꿀잼', '옷', '개꿀띠', '강추임'],
#  ['월드', '점프', '키', '방향', '조절', '키', '오른손잡이', '게임'],
#  ['본계', '로그인', '일시', '에러', '때메', '동안'],
#  ['칼퇴',
#   '비밀번호',
#   '전화',
#   '번호',
#   '생일',
#   '비밀번호',
#   '생일',
#   '전화번호',
#   '칼퇴',
#   '사람',
#   '평점',
#   '점',
#   '비밀번호',
#   '자동'],
#  ['현', '답장', '게시', '삭제', '삭제', '게시', '숨기', '기도', '점', '지우', '게시'],
#  ['옷'],
#  ['게시', '삭제', '교', '다행'],
#  ['게임', '젬', '사려', '현질', '월드', '버그', '추천', '욥'],
#  ['좀비런', '추가', '좀비', '런', '게임'],
#  ['겜임', '오류', '인터넷', '업뎃', '겜'],
#  ['오류'],
#  ['마이크', '동영상', '녹화', '나중', '목소리', '매번', '기계', '녹음', '방', '친구', '땐', '녹화'],
#  ['선물', '제한', '상태', '메세지', '보기', '전이', '달라', '아이디', '날짜', '업뎃'],
#  ['푸시',
#   '알람',
#   '즐겨찾기',
#   '추가',
#   '계정',
#   '모에',
#   '어케',
#   '설정',
#   '터치',
#   '민감',
#   '그르',
#   '아이템',
#   '보기'],
#  ['잼', '퀘스트', '퀘스트'],
#  ['유저',
#   '안준',
#   '이유',
#   '우선',
#   '업그레이드',
#   '안해',
#   '게시',
#   '삭제',
#   '삭제',
#   '신고',
#   '사람',
#   '일주일',
#   '동안',
#   '격리',
#   '와이파이',
#   '와이파이',
#   '게임'],
#  ['환불'],
#  ['게시', '삭제', '버튼', '눌림', '보삼'],
#  ['모든', '단점', '몇', '젬', '젬', '옷', '스크래치', '확률', '게임', '적', '모든'],
#  ['젬', '안주', '젬', '기도'],
#  ['개발', '선생님', '게시', '리기', '게시', '삭제'],
#  ['일', '유전', '단점', '보이지'],
#  ['아빠',
#   '계정',
#   '젬',
#   '젬',
#   '현질',
#   '게시',
#   '삭제',
#   '윙크',
#   '아이폰',
#   '삼성',
#   '보너스',
#   '아이템',
#   '환불',
#   '기능'],
#  ['지난번',
#   '남겻는데',
#   '두번째',
#   '젬얻기',
#   '개인',
#   '정이',
#   '고객',
#   '센터',
#   '연락',
#   '렉',
#   '데이터',
#   '삭제',
#   '렉',
#   '달라',
#   '요청',
#   '은방',
#   '렉',
#   '상식',
#   '렉',
#   '소통',
#   '사람',
#   '상황',
#   '극도',
#   '렉',
#   '외',
#   '문제점',
#   '렉',
#   '문제',
#   '렉',
#   '사람',
#   '렉',
#   '소통',
#   '메시',
#   '지방',
#   '크루',
#   '월드',
#   '마이크',
#   '아이템',
#   '월드',
#   '렉',
#   '도저히',
#   '방',
#   '렉',
#   '모이',
#   '렉',
#   '전원',
#   '기도',
#   '요렉',
#   '사람',
#   '피해',
#   '익명'],
#  ['한가지',
#   '단점',
#   '면',
#   '메이크업',
#   '머리',
#   '메이크업',
#   '종류',
#   '귀걸이',
#   '그다음',
#   '확대',
#   '위로',
#   '차라리',
#   '낫',
#   '수정'],
#  ['의견'],
#  ['재미', '유행'],
#  ['회원',
#   '가입',
#   '선물',
#   '부계',
#   '본계',
#   '본계',
#   '가입',
#   '본계',
#   '코인',
#   '부계',
#   '코인',
#   '본계',
#   '선물',
#   '가입',
#   '지나',
#   '가입',
#   '한지',
#   '선물',
#   '일출',
#   '보상',
#   '선물',
#   '선물'],
#  ['영상', '삭제'],
#  ['랙'],
#  ['굿굿'],
#  ['캐릭', '시작', '돈', '별', '입다'],
#  ['파란', '딱지', '사람', '라이브', '키'],
#  ['가입', '절차', '포기', '가입', '절차'],
#  ['영상', '건너'],
#  ['유저', '아무', '문제', '최근', '게시', '삭제', '문제', '지속', '게시', '정리', '단순', '오류'],
#  ['캐릭터', '초기', '저절로', '버그', '종종', '젬', '뽑기', '쨋뜬', '게임', '네오'],
#  ['사회', '및', '모든', '사람', '모습'],
#  ['가슴', '엄첨', '게임', '여야'],
#  ['젬많'],
#  ['단점', '옷', '젬', '옷', '음해'],
#  ['캐릭터', '옷', '구매', '포즈', '머리', '보이', '얼굴'],
#  ['기성세대', '입장', '세대'],
#  ['플레이',
#   '유저',
#   '플레이',
#   '월드',
#   '한국',
#   '월드',
#   '현재',
#   '캐나다',
#   '거주',
#   '한국',
#   '월드',
#   '한국',
#   '월드',
#   '변경'],
#  ['캐릭터',
#   '자신',
#   '스타일',
#   '게임',
#   '편집',
#   '실력',
#   '게임',
#   '예의',
#   '욕',
#   '차단',
#   '신고',
#   '점',
#   '감동',
#   '실시간',
#   '추천',
#   '피드',
#   '하루',
#   '미션',
#   '코인',
#   '게임',
#   '포토',
#   '부스',
#   '자신',
#   '게시',
#   '템플릿',
#   '사용',
#   '월드'],
#  ['영상', '삭제', '렉', '젬얻는'],
#  ['삭제'],
#  ['이메일', '크리에이터', '이메일', '쪼금', '현질', '안해', '게시', '삭데', '외', '최곤것'],
#  ['드디엉', '재미'],
#  ['계시', '물이', '삭제', '곤', '치면'],
#  ['업데이트', '옷', '자세', '표정', '자연'],
#  ['게임', '유저', '흑역사', '업로드', '삭제', '태그', '사용', '아애', '처', '사람'],
#  ['로고', '도하', '뎁'],
#  ['재패토', '유저', '게다', '팔로우'],
#  ['욕', '별', '아이템'],
#  ['만족', '쇼핑'],
#  ['업데이트', '화면', '아바타', '포즈', '업데이트', '포즈', '젠', '기도', '순', '점'],
#  ['계시', '영상', '영상', '별', '가능'],
#  ['유저', '다이아', '게임', '보상', '관리자', '신경'],
#  ['현질',
#   '유도',
#   '초보자',
#   '크리',
#   '템',
#   '헤어',
#   '사지',
#   '상황',
#   '아이폰',
#   '게시',
#   '로딩',
#   '최대한',
#   '게임',
#   '가입',
#   '최소',
#   '젬씩',
#   '별'],
#  ['유저',
#   '무료',
#   '젬',
#   '퀘스트',
#   '프레이',
#   '사전예약',
#   '전번',
#   '입력',
#   '완료',
#   '창',
#   '확인',
#   '젬',
#   '리뷰'],
#  ['캐릭터'],
#  ['팔로워', '제페터', '접속'],
#  ['밋'],
#  ['피드', '삭제'],
#  ['업뎃', '게시', '삭제', '점좀'],
#  ['템',
#   '다만',
#   '안드로이드',
#   '플레이',
#   '중',
#   '퀘스트',
#   '카메라',
#   '관련',
#   '퀘스트',
#   '대로',
#   '평상시',
#   '사진',
#   '완료',
#   '건너',
#   '중',
#   '문제',
#   '지속'],
#  ['속눈썹', '마음', '패션', '눈동자', '속눈썹', '적용', '눈동자', '속눈썹', '적용', '적용', '해결'],
#  ['접속', '데이터', '퍼', '코인', '잼', '금식', '줌', '제일', '게시', '삭제', '게임', '게임'],
#  ['좀비', '게임'],
#  ['비밀번호', '이메일', '이메일'],
#  ['유저', '렉', '친구', '튕', '기고', '옷장', '분류', '분류'],
#  ['중독',
#   '손',
#   '아바타',
#   '게다가',
#   '젬',
#   '변경',
#   '신경',
#   '수정',
#   '업데이트',
#   '오류',
#   '액션',
#   '캠',
#   '아이폰',
#   '업데이트',
#   '게시',
#   '삭제',
#   '문제',
#   '정부',
#   '호불호',
#   '템플릿',
#   '사용',
#   '틀',
#   '갠',
#   '사용',
#   '오류',
#   '덜',
#   '사람',
#   '스텀',
#   '포즈',
#   '버튼',
#   '광고',
#   '선택',
#   '업데이트',
#   '오류',
#   '신경'],
#  ['제퍼토',
#   '사용',
#   '유저',
#   '게시',
#   '삭제',
#   '젬',
#   '요요',
#   '젬',
#   '게임',
#   '플레이',
#   '말',
#   '퍼토',
#   '그게',
#   '무료',
#   '젬',
#   '답변'],
#  ['현실', '유도', '게시', '삭제', '테그', '삭제'],
#  ['게시', '삭제', '일', '친', '개별', '업뎃땜'],
#  ['영상', '버그'],
#  ['업뎃되', '게시', '크리', '템', '선물', '크리', '템', '선물'],
#  ['게임', '버그', '게시', '삭제', '태그', '삭제', '이점', '별', '삭제', '삭제'],
#  ['로블',
#   '면',
#   '기준',
#   '현질',
#   '유도',
#   '꼽주거',
#   '남',
#   '막말',
#   '젬',
#   '코인',
#   '젬',
#   '코인',
#   '확률',
#   '가격',
#   '마지막',
#   '초보자',
#   '스텀',
#   '마찬가지'],
#  ['점', '주기', '보호자', '동의', '부모님', '깉', '이보', '로그인'],
#  ['게시', '삭제', '숨', '기기'],
#  ['현질', '게시', '삭제', '가안', '관리자'],
#  ['프로필', '사진', '건줄', '알', '게시', '삭제', '업데이트', '알', '최대한', '하루'],
#  ['와우', '로딩'],
#  ['게시', '삭제'],
#  ['게시', '삭제', '수정'],
#  ['사용',
#   '젶토',
#   '유저',
#   '게임',
#   '먼저',
#   '점',
#   '로그인',
#   '이용',
#   '라이브',
#   '월드',
#   '아바타',
#   '소통',
#   '아이템',
#   '미니게임',
#   '크루',
#   '스타일',
#   '채팅',
#   '욕설',
#   '버그',
#   '도용',
#   '업데이트',
#   '게시',
#   '삭제',
#   '삭제',
#   '버튼',
#   '버튼',
#   '삭제',
#   '몇몇',
#   '현재',
#   '게시',
#   '삭제',
#   '신고',
#   '버튼',
#   '의견',
#   '증거',
#   '제출',
#   '신고',
#   '목록',
#   '도용',
#   '미니게임',
#   '중',
#   '좀비',
#   '게임',
#   '캐릭터',
#   '얼굴',
#   '얼굴',
#   '눈알',
#   '형태',
#   '스텀',
#   '잇몸',
#   '종종',
#   '버튼',
#   '움직임',
#   '불구',
#   '캐릭터',
#   '앞',
#   '제자리',
#   '게임',
#   '발전',
#   '응원'],
#  ['게시',
#   '삭제',
#   '기능',
#   '게시',
#   '기능',
#   '업데이트',
#   '월드',
#   '아이템',
#   '개수',
#   '게시',
#   '게시',
#   '물이',
#   '버그',
#   '수정',
#   '점',
#   '차례대로',
#   '말',
#   '옷장',
#   '편리',
#   '기능',
#   '옷장',
#   '전체',
#   '상의',
#   '하의',
#   '헤어',
#   '신발',
#   '기타',
#   '식',
#   '옷',
#   '찾기',
#   '악세사리',
#   '상의',
#   '하의',
#   '헤어',
#   '신발',
#   '원피스',
#   '드레스',
#   '포함',
#   '몸',
#   '식',
#   '젬',
#   '현질',
#   '사람',
#   '사람',
#   '젬',
#   '말',
#   '매일',
#   '접속',
#   '일보',
#   '젬',
#   '의견'],
#  ['점점', '발전'],
#  ['게임', '게시', '삭제', '헤헤', '점', '외', '게임'],
#  ['페톡', '캐릭터', '확실', '페톡', '대신', '롤', '록스'],
#  ['게시', '삭제', '삭제', '법', '삭제', '몆', '일간', '삭제', '게시'],
#  ['크리에이터', '옷', '선물', '월드', '옷', '화장'],
#  ['개월',
#   '쭉',
#   '사용',
#   '유저',
#   '장점',
#   '말',
#   '본인',
#   '스타일',
#   '스타일',
#   '사람',
#   '공유',
#   '소통',
#   '스텀',
#   '스텀',
#   '연습',
#   '동물',
#   '단점',
#   '말',
#   '아이폰',
#   '기능',
#   '업뎃',
#   '삼성',
#   '게시',
#   '리기',
#   '기능',
#   '오류',
#   '수정',
#   '과도',
#   '검열',
#   '호불호',
#   '갈릴',
#   '수도',
#   '개인',
#   '병',
#   '욕',
#   '검열',
#   '대표',
#   '장단점',
#   '정리',
#   '리뷰',
#   '현질',
#   '유도',
#   '개념',
#   '잼민',
#   '소리',
#   '젬',
#   '아이템',
#   '가격',
#   '확',
#   '사실',
#   '노력',
#   '잼민',
#   '회사',
#   '문제',
#   '무시',
#   '차단',
#   '화이팅'],
#  ['컾터'],
#  ['게임', '재미', '재미', '랙어청거례', '와이파이'],
#  ['오류', '종종', '게시', '삭제', '수정', '오류', '프로필', '상메', '오류', '채팅', '오류', '오류'],
#  ['업뎃', '카메라', '기능', '기능', '닥'],
#  ['의', '친구', '악플'],
#  ['좀비',
#   '게임',
#   '하',
#   '입장',
#   '무한',
#   '대기',
#   '상태',
#   '어제',
#   '시도',
#   '중',
#   '리뷰',
#   '업데이트',
#   '좀비',
#   '게임',
#   '플레이어',
#   '중',
#   '도대체'],
#  ['업뎃',
#   '매우',
#   '점',
#   '아이패드',
#   '이용',
#   '아이패드',
#   '최신',
#   '가로',
#   '모드',
#   '문제',
#   '이용',
#   '중',
#   '업뎃',
#   '강제',
#   '세로',
#   '모드',
#   '픽셀',
#   '현상',
#   '아이패드',
#   '가로',
#   '모드',
#   '세로',
#   '회전',
#   '월드',
#   '옛날',
#   '오락',
#   '화면',
#   '화질',
#   '비율',
#   '피드상',
#   '윗',
#   '아이패드',
#   '이용',
#   '업뎃',
#   '옷',
#   '힐',
#   '아바타',
#   '움직임',
#   '자세',
#   '왜케',
#   '바보',
#   '고개',
#   '한쪽',
#   '기우',
#   '문의',
#   '여러',
#   '첨부파일',
#   '보시',
#   '개선',
#   '바람',
#   '메일',
#   '답장',
#   '내용',
#   '전달',
#   '이용'],
#  ['유저',
#   '업데이트',
#   '삭제',
#   '업뎃',
#   '게시',
#   '물이',
#   '태그',
#   '삭제',
#   '오류',
#   '유저',
#   '업뎃때문',
#   '피해',
#   '상황'],
#  ['유저',
#   '한가지',
#   '말',
#   '부계',
#   '게임',
#   '동안',
#   '로그아웃',
#   '로그인',
#   '비정상',
#   '로그인',
#   '로그인',
#   '핸드폰',
#   '인증',
#   '스트레스'],
#  ['게시', '삭제'],
#  ['파토', '맵', '유저', '파토', '마음대로', '친구', '남친', '마음대로', '캐릭터', '리뷰'],
#  ['유저', '사용', '어제', '게시', '물이', '삭제', '아이폰', '유저', '문제', '게임'],
#  ['유저', '업뎃', '게시', '물이', '오류', '발생', '작성', '업뎃', '오류'],
#  ['리뷰',
#   '차단',
#   '단체',
#   '메세지',
#   '초대',
#   '현질',
#   '유도',
#   '사람',
#   '현질',
#   '유도',
#   '현질',
#   '카',
#   '사람',
#   '보기',
#   '변',
#   '변',
#   '이름',
#   '피해',
#   '제작자',
#   '두시',
#   '리뷰',
#   '폭망'],
#  ['업뎃', '게시', '삭제', '태그', '옛날', '젶', '젬'],
#  ['유저',
#   '렉',
#   '오류',
#   '리뷰',
#   '이유',
#   '첫',
#   '크루',
#   '사용',
#   '단어',
#   '크루',
#   '지나',
#   '신고',
#   '대해',
#   '문의',
#   '두번째',
#   '이유',
#   '아이폰',
#   '메롱',
#   '삼성',
#   '현질',
#   '메롱',
#   '아이템',
#   '아이폰',
#   '공짜',
#   '삼성',
#   '돈',
#   '사라',
#   '변태',
#   '념',
#   '신고',
#   '저희',
#   '피해'],
#  ['유저',
#   '최신',
#   '업데이트',
#   '이유',
#   '게시',
#   '삭제',
#   '게시',
#   '숨',
#   '기기',
#   '게시',
#   '삭제',
#   '게시',
#   '숨',
#   '기기',
#   '게시',
#   '흑역사',
#   '리뷰',
#   '만약',
#   '게시',
#   '삭제',
#   '물숨',
#   '기기',
#   '별',
#   '월드',
#   '점프',
#   '마스터',
#   '젬',
#   '그다음',
#   '젬',
#   '점프',
#   '마스터',
#   '트레이닝',
#   '룸',
#   '미션',
#   '얼랜',
#   '젬',
#   '코인',
#   '살짝',
#   '코인',
#   '젬이',
#   '젬',
#   '트레이닝',
#   '룸',
#   '미션',
#   '젬이',
#   '게시',
#   '삭제',
#   '게시',
#   '트레이닝',
#   '룸',
#   '미션',
#   '젬',
#   '게시',
#   '삭제',
#   '게시',
#   '숨기'],
#  ['게시', '삭제'],
#  ['월동',
#   '팔로우',
#   '보유',
#   '사람',
#   '젬',
#   '찬스',
#   '설문',
#   '젬',
#   '말',
#   '게시',
#   '숨기',
#   '기와',
#   '개시',
#   '삭제'],
#  ['최신',
#   '업데이트',
#   '난후',
#   '게시',
#   '삭제',
#   '게시',
#   '기능',
#   '종종',
#   '퀘스트',
#   '광고',
#   '광고',
#   '종료',
#   '광고'],
#  ['부모님', '어이', '겜', '절때'],
#  ['크리에이터',
#   '아이템',
#   '미리보기',
#   '렌즈',
#   '귀걸이',
#   '화면',
#   '확인',
#   '부디',
#   '얼굴',
#   '버튼',
#   '방도',
#   '마련',
#   '삭제',
#   '오류',
#   '수정'],
#  ['업데이트', '게시', '삭제'],
#  ['옷',
#   '역',
#   '추천',
#   '업데이트',
#   '콜라보',
#   '옷',
#   '보기',
#   '마음',
#   '점',
#   '업데이트',
#   '업데이트',
#   '전과',
#   '업데이트',
#   '후의',
#   '얼굴',
#   '개인',
#   '의견',
#   '업데이트',
#   '얼굴',
#   '마음',
#   '업데이트',
#   '땡글',
#   '해지',
#   '동글동글',
#   '얼굴',
#   '스텀',
#   '업데이트',
#   '얼굴'],
#  ['월드', '영상', '라이브', '볼', '요하', '젬', '현질', '중간', '중간', '게시', '삭제'],
#  ['다만',
#   '문의',
#   '샾뜨고',
#   '욕',
#   '샾',
#   '처리',
#   '차라리',
#   '욕',
#   '런지쨋',
#   '렉',
#   '월드',
#   '가면',
#   '렉',
#   '이점'],
#  ['일제', '삭제', '숨기', '기안'],
#  ['즐겜', '유저', '게시', '삭제'],
#  ['게시', '삭제', '게시', '숨기', '기도'],
#  ['게시', '소리', '음악', '게시'],
#  ['업데이트', '게시', '삭제'],
#  ['리뷰',
#   '작성',
#   '삭제',
#   '네모',
#   '스킨',
#   '월드',
#   '오니',
#   '캐릭터',
#   '스텀',
#   '초기',
#   '네모',
#   '스킨',
#   '나중',
#   '옷',
#   '착용',
#   '저장',
#   '스텀',
#   '초기',
#   '컬러',
#   '스텀',
#   '사시',
#   '앞',
#   '상황',
#   '악화',
#   '네모',
#   '스킨',
#   '끼',
#   '로그아웃',
#   '로그인',
#   '전원',
#   '켜',
#   '어젯밤',
#   '이글',
#   '욕',
#   '순'],
#  ['캐릭'],
#  ['어플', '삭제', '게시', '삭제', '문의', '대답'],
#  ['게시', '삭제', '반응'],
#  ['업데이트', '게시', '삭제', '문제', '해결', '젬', '선물', '기능'],
#  ['유저', '게시', '삭제', '및', '숨기', '수정'],
#  ['템플릿'],
#  ['게시', '삭제', '수정'],
#  ['크루', '오류', '버그', '게시', '삭제'],
#  ['게시', '삭제'],
#  ['유저',
#   '한명인',
#   '건의',
#   '건의',
#   '툰',
#   '만화',
#   '콜북',
#   '기능',
#   '앨범',
#   '기능',
#   '반영',
#   '보지',
#   '툰',
#   '사람',
#   '기능',
#   '추가',
#   '시리즈',
#   '클릭',
#   '장점',
#   '사람',
#   '편안함',
#   '건의',
#   '또한',
#   '소통',
#   '앞',
#   '오래오래'],
#  ['젶토', '삭제'],
#  ['업뎃',
#   '아이폰',
#   '문제',
#   '잘만',
#   '계삭',
#   '계숨',
#   '삼성',
#   '계삭',
#   '계숨',
#   '업뎃',
#   '자동',
#   '업뎃이되',
#   '굳이',
#   '아이폰',
#   '계삭',
#   '계숨',
#   '삼성',
#   '계삭',
#   '계숨'],
#  ['여진', '젶토', '오류', '어제', '게시', '삭제', '버튼', '삭제'],
#  ['게시', '버그', '일부러', '쨋'],
#  ['재밋구', '게시', '삭제', '별', '드림', '덩'],
#  ['업뎃', '오류', '게시', '삭제'],
#  ['게시', '삭제', '숨', '기기'],
#  ['업뎃', '기전', '현질', '유도', '젬', '업뎃', '게시', '삭제', '때매', '사람', '고통', '오류'],
#  ['게시', '삭제', '및', '기능', '저장', '공간', '관리', '데이터', '삭제', '삭제'],
#  ['업데이트', '게시', '기능', '게시', '삭제', '얼른'],
#  ['스텀', '실수', '변경'],
#  ['로그인',
#   '복구',
#   '비밀번호',
#   '비밀번호',
#   '요청',
#   '이메일',
#   '똑바로',
#   '비밀번호',
#   '하루',
#   '삼일',
#   '동안',
#   '세번',
#   '요청',
#   '현질',
#   '계정',
#   '마음',
#   '당황'],
#  ['렉', '금도', '게시', '삭제', '룰', '수정'],
#  ['정면', '사진', '렉', '복구'],
#  ['현질', '돈', '잔액', '부족', '게임', '정상', '렉', '점도', '영상', '화질', '노래', '불편햐'],
#  ['친구', '소통', '점프', '맵', '일상', '맵', '맵'],
#  ['유저', '한지', '꽤', '최근', '게시', '물이', '삭제'],
#  ['역시'],
#  ['게시', '삭제', '현질', '사람', '젬', '아이템', '사지', '말', '듯이', '젬', '이점'],
#  ['영상', '삭제'],
#  ['활동', '유저', '말', '여태', '사용', '게임', '도대체', '상황', '업데이트', '영상'],
#  ['공식',
#   '계정',
#   '선물',
#   '줄때',
#   '옷',
#   '옷',
#   '삭제',
#   '기능',
#   '선물',
#   '자신',
#   '구매',
#   '돈',
#   '매우',
#   '옷',
#   '삭제',
#   '기능',
#   '대신',
#   '옷',
#   '삭제',
#   '옷',
#   '삭제',
#   '칸',
#   '시간',
#   '지난',
#   '방식'],
#  ['플레이',
#   '과금',
#   '유저',
#   '젬',
#   '플레이',
#   '크리에이터',
#   '아이템',
#   '선물',
#   '이유',
#   '크리에이터',
#   '아이템',
#   '선물',
#   '삼성',
#   '유저',
#   '메롱'],
#  ['태그',
#   '삭제',
#   '정',
#   '람',
#   '태그',
#   '태그',
#   '삭제',
#   '팔로워',
#   '오류',
#   '상태',
#   '메시지',
#   '편집',
#   '힐때',
#   '젶메',
#   '오류',
#   '시간',
#   '게시',
#   '삭제',
#   '얼공',
#   '거나',
#   '흑역사',
#   '삭제',
#   '삭제',
#   '자신',
#   '팔로우',
#   '사람',
#   '자신',
#   '흑역사',
#   '얼굴',
#   '누가',
#   '지고',
#   '내용',
#   '사진',
#   '계석',
#   '불쾨'],
#  ['영상', '화살표'],
#  ['프리미엄', '취소'],
#  ['최근', '업데이트', '렉', '태그', '삭제', '업그레이드', '렉'],
#  ['아아', '저먼', '게시', '삭제', '큰일', '헬로월드', '게시', '삭제'],
#  ['캐릭터', '상의', '티', '로만'],
#  ['젶토',
#   '업뎃',
#   '삼성',
#   '게삭',
#   '진심',
#   '차별',
#   '기분',
#   '저번',
#   '메롱',
#   '아이폰',
#   '일',
#   '메타',
#   '버스',
#   '효과',
#   '금방',
#   '버그',
#   '렉',
#   '업뎃',
#   '점',
#   '마도',
#   '하양색',
#   '현질',
#   '유도',
#   '참고',
#   '한계'],
#  ['게시',
#   '물이',
#   '삭제',
#   '점',
#   '게임',
#   '광고',
#   '단점',
#   '단점',
#   '월드',
#   '별',
#   '개입',
#   '게임',
#   '게임',
#   '재미',
#   '이해',
#   '게임'],
#  ['업데이트', '게시', '삭제', '비', '공도', '크루', '맞팔', '구해', '맞팔', '말'],
#  ['현질', '유도', '코인', '젬', '방식', '젬'],
#  ['영상', '삭제'],
#  ['옷', '월드', '크리', '이티', '선물', '크리', '이티', '옷', '사려', '젬', '젬', '계정', '사지'],
#  ['본론',
#   '말',
#   '일',
#   '녜',
#   '삼성',
#   '유저',
#   '게시',
#   '삭제',
#   '태그',
#   '삭제',
#   '게시',
#   '크레이터',
#   '아이템',
#   '맵',
#   '프리미엄',
#   '결제',
#   '젬',
#   '아이폰',
#   '유저',
#   '업뎃'],
#  ['렉', '게시', '삭제', '종종', '신상', '잼', '아이템', '잼', '과금', '유저', '잼템', '살수', '처'],
#  ['게시', '물이', '삭제'],
#  ['게시', '삭제', '삭', '은영', '사오', '지고', '숨기', '기도'],
#  ['게임', '렉', '튕기네'],
#  ['게시', '삭제', '메시지', '작동', '부탁'],
#  ['템', '추천'],
#  ['작년',
#   '유저',
#   '단점',
#   '예기',
#   '렉',
#   '버그',
#   '상확',
#   '월드',
#   '오류',
#   '미니게임',
#   '현질',
#   '강요',
#   '이야기',
#   '젬',
#   '레',
#   '젬',
#   '레',
#   '젬이있',
#   '나머지',
#   '지고',
#   '나은'],
#  ['수정',
#   '포즈',
#   '잠수',
#   '패치',
#   '업데이트',
#   '오류로',
#   '게시',
#   '태그',
#   '수정',
#   '게시',
#   '삭제',
#   '프리미엄',
#   '결제',
#   '일',
#   '예정일',
#   '돈',
#   '프리미엄',
#   '해택',
#   '차이',
#   '하루',
#   '일',
#   '이지',
#   '부연',
#   '설명',
#   '업데이트',
#   '오류',
#   '전통',
#   '일반',
#   '플레이',
#   '지장',
#   '프리미엄',
#   '결제',
#   '택',
#   '빼',
#   '문제',
#   '차라리',
#   '러시',
#   '예정일',
#   '빼',
#   '사항',
#   '무료',
#   '잼',
#   '광고',
#   '숫자',
#   '잼',
#   '십만',
#   '잼',
#   '숫자',
#   '잼',
#   '버그',
#   '악용',
#   '유저',
#   '확인',
#   '동안',
#   '운영',
#   '진',
#   '발견',
#   '말'],
#  ['오류', '월드', '다운로드'],
#  ['퀄리티',
#   '한가지',
#   '업데이트',
#   '젬',
#   '코인',
#   '젬',
#   '기능',
#   '좋을겄',
#   '업데이트',
#   '게시',
#   '삭제',
#   '아이템',
#   '환불',
#   '기능'],
#  ['게시', '삭제', '게시', '숨', '기기', '오류', '발생', '문제', '월', '일', '문제', '시일'],
#  ['발', '게시', '물이'],
#  ['업뎃', '게시', '물이', '삭제', '삭제', '람', '레'],
#  ['잼', '잼', '보상'],
#  ['선물', '려고', '달이', '게시', '숨기', '기와', '삭제', '삭제'],
#  ['업뎃후', '게시', '삭제', '젬', '현질', '게임', '첨'],
#  ['버그', '월드', '옷', '체형', '마스크'],
#  ['무료',
#   '광고',
#   '보기',
#   '겨우',
#   '젬',
#   '심지어',
#   '무료',
#   '돈',
#   '겨우',
#   '돈',
#   '게임',
#   '게임',
#   '일',
#   '애기',
#   '친구',
#   '틱톡',
#   '돈때매',
#   '별',
#   '실제'],
#  ['안녕',
#   '유저',
#   '선물',
#   '크레이터',
#   '선물',
#   '렉',
#   '게시',
#   '물이',
#   '월드',
#   '월드',
#   '검은색',
#   '테블릿',
#   '사용',
#   '돼지',
#   '노래',
#   '춤',
#   '거좀',
#   '만약',
#   '크레이터',
#   '선물',
#   '게시',
#   '물이'],
#  ['크리에이터',
#   '기술',
#   '연령',
#   '옷',
#   '크리에이터',
#   '기술',
#   '나니',
#   '옷',
#   '거나',
#   '어린이',
#   '옷',
#   '이상인',
#   '어린이',
#   '메타',
#   '버스',
#   '옷',
#   '판매',
#   '수정',
#   '사람',
#   '활동',
#   '맵',
#   '맵',
#   '사용',
#   '앞',
#   '맵',
#   '말',
#   '점',
#   '수정'],
#  ['팔로워', '충전', '총', '금액', '업데이트', '삭제', '숨', '기기', '게시', '사람', '해결', '책'],
#  ['삭제', '삭제'],
#  ['잼', '현질', '구래', '잼'],
#  ['재미', '젬', '일주일', '젬', '식'],
#  ['업데이트',
#   '업데이트',
#   '캐릭터',
#   '무표정',
#   '포즈',
#   '캐릭터',
#   '포즈',
#   '캐릭터',
#   '드',
#   '팔이',
#   '개구리',
#   '포즈',
#   '반',
#   '꺽',
#   '친구',
#   '캐릭터',
#   '껏',
#   '친구',
#   '껏',
#   '친구',
#   '불만',
#   '업데이트',
#   '현질',
#   '유저',
#   '로써',
#   '캐릭터',
#   '어색',
#   '포즈'],
#  ['업뎃', '게시', '삭제', '게시', '태그', '삭제'],
#  ['업뎃', '오류', '게시', '삭제'],
#  ['광고',
#   '돈',
#   '광고',
#   '매일',
#   '오백',
#   '캐시',
#   '어제',
#   '도안',
#   '것좀꼭',
#   '게임',
#   '렉',
#   '만구',
#   '광고',
#   '돈',
#   '안주',
#   '추천',
#   '그다지'],
#  ['젶'],
#  ['네이버', '개인', '정보', '적', '무차별', '통신', '정보', '조회', '수용'],
#  ['아이템', '젬', '젬', '젬', '젬', '젬', '가지가지', '업뎃', '게시', '삭제'],
#  ['출시',
#   '아이탬',
#   '빛',
#   '게시',
#   '물이',
#   '삭제',
#   '조',
#   '플레이어',
#   '아이',
#   '탬',
#   '위시',
#   '저장',
#   '변태',
#   '밴시',
#   '변태',
#   '많슴니'],
#  ['업데이트', '게시', '숨기', '기와', '삭제'],
#  ['게시', '삭제', '게시', '삭제', '버그'],
#  ['재미'],
#  ['업데이트', '개시'],
#  ['갤럭시', '게시', '숨기', '기와', '삭제', '액션', '기능', '아이템', '산걸', '환불', '기능'],
#  ['게시', '삭제'],
#  ['최근',
#   '업데이트',
#   '버그',
#   '일어나고',
#   '심지어',
#   '게시',
#   '삭제',
#   '태그',
#   '삭제',
#   '사람',
#   '불만',
#   '영상',
#   '최소',
#   '점',
#   '플레이',
#   '얘기'],
#  ['친구', '모험'],
#  ['광고', '재생'],
#  ['게시', '삭제', '막태', '삭제', '개선'],
#  ['관리', '흰색', '바탕', '화면', '혈압'],
#  ['가상',
#   '디테',
#   '단점',
#   '젬',
#   '핑크색',
#   '보석',
#   '체형',
#   '키',
#   '크게',
#   '월드',
#   '렉',
#   '라이브',
#   '권한',
#   '사람',
#   '선물',
#   '구걸',
#   '반박',
#   '하트',
#   '구걸',
#   '앞',
#   '듯이',
#   '젬',
#   '에드',
#   '옷',
#   '그게',
#   '유저',
#   '핸드폰',
#   '가입',
#   '계정',
#   '계정',
#   '그게',
#   '어이',
#   '저번',
#   '아바타',
#   '젬',
#   '젬짜리',
#   '옷',
#   '사람',
#   '홍보',
#   '옷',
#   '홍보',
#   '해주',
#   '젬',
#   '스크래치',
#   '당첨',
#   '사람',
#   '일상',
#   '알리',
#   '라이브',
#   '다른사람'],
#  ['별', '빵', '리뷰', '별'],
#  ['업데이트',
#   '장점',
#   '개시',
#   '삭제',
#   '리뷰',
#   '안달',
#   '고도',
#   '점',
#   '이벤트',
#   '열거',
#   '질문',
#   '나중',
#   '삭제',
#   '삭제',
#   '유저',
#   '삭제',
#   '삭제'],
#  ['직자', '크리', '템', '선물', '크리', '템', '현질', '살수', '현질'],
#  ['최애',
#   '게임',
#   '업뎃',
#   '게시',
#   '삭제',
#   '게시',
#   '삭제',
#   '계시',
#   '게시',
#   '삭제',
#   '업뎃',
#   '삭제',
#   '당황',
#   '갤럭시',
#   '게시',
#   '게시',
#   '삭제',
#   '기능'],
#  ['게시', '삭제', '태그', '삭제'],
#  ['캐릭터', '사진', '코인', '당첨', '마다', '튕기네'],
#  ['엡뎃',
#   '게시',
#   '삭제',
#   '숨',
#   '기기',
#   '미션',
#   '게임',
#   '요소',
#   '유저',
#   '의지',
#   '이용자',
#   '사이버범죄',
#   '대한',
#   '가이드라인',
#   '성희롱',
#   '이용자',
#   '방해',
#   '사이버',
#   '폭력',
#   '대한',
#   '대응',
#   '매우',
#   '무분별',
#   '복수',
#   '아이디',
#   '대해',
#   '대책',
#   '음성',
#   '답변',
#   '자사',
#   '이용자',
#   '징계',
#   '제제',
#   '매우',
#   '랜덤',
#   '기준',
#   '미비',
#   '환불',
#   '정책',
#   '사이월드',
#   '절차',
#   '답습',
#   '느낌',
#   '갈수',
#   '개선',
#   '바람',
#   '사이버',
#   '범죄',
#   '대한',
#   '대응',
#   '가장',
#   '중요'],
#  ['게시', '삭제', '해결'],
#  ['업데이트', '게시', '삭제'],
#  ['케릭', '안보', '여요'],
#  ['업뎃', '본캐', '비번', '바', '게임', '팔'],
#  ['팔로워',
#   '삭제',
#   '기능',
#   '지인',
#   '계정',
#   '돈',
#   '차라리',
#   '팔로우',
#   '취소',
#   '이름',
#   '싹',
#   '팔로워',
#   '삭제',
#   '기능',
#   '추가'],
#  ['업데이트', '피드', '수정', '삭제', '숨', '기기', '불가능', '태그', '상태', '돠었습니', '노트', '사용자'],
#  ['최근', '업데이트', '게시', '삭제', '숨', '기기', '이점'],
#  ['영상', '허용'],
#  ['게시', '리기'],
#  ['게시', '삭제', '게시', '비', '공도'],
#  ['기능',
#   '사람',
#   '게시',
#   '삭제',
#   '게시',
#   '삭제',
#   '금도',
#   '유저',
#   '스트레스',
#   '원인',
#   '게시',
#   '전체',
#   '삭제',
#   '기능'],
#  ['게시', '삭제', '렉'],
#  ['게시', '물이', '삭제', '버튼', '사람'],
#  ['피드', '삭제', '및', '기능'],
#  ['게시', '삭제', '가안'],
#  ['젶토',
#   '삼성',
#   '차별',
#   '논란',
#   '최근',
#   '삼성',
#   '차별',
#   '논란',
#   '메롱',
#   '유저',
#   '중',
#   '유저',
#   '메롱이',
#   '린지',
#   '참여',
#   '최근',
#   '업데이트',
#   '게시',
#   '삭제',
#   '불가능',
#   '유저',
#   '불편',
#   '세번',
#   '태그',
#   '삭제',
#   '막태',
#   '피해',
#   '유저',
#   '정',
#   '태',
#   '팔취',
#   '상태',
#   '메시지',
#   '보기',
#   '기능',
#   '볼',
#   '옛날',
#   '아마',
#   '모든',
#   '제페터',
#   '예상',
#   '코디',
#   '기능',
#   '뉴스',
#   '워니',
#   '게시',
#   '제보',
#   '업데이트',
#   '사실',
#   '참고'],
#  ['점프', '마스터', '설정', '업데이트', '속도', '로딩', '시간'],
#  ['크리에이터',
#   '템',
#   '영향',
#   '젠',
#   '렌즈',
#   '유저',
#   '만드나',
#   '게임',
#   '이면',
#   '유저',
#   '템',
#   '꼴',
#   '난건'],
#  ['핫', '현질', '유도', '불평', '이벤트', '겜'],
#  ['업데이트', '삼성', '게시', '삭제', '상메', '글씨', '보기', '해결'],
#  ['개발자', '게시', '삭제', '연락처', '쩌', '업데이트'],
#  ['월드', '입장', '시간', '젬', '젬'],
#  ['최근',
#   '업뎃',
#   '갤럭시',
#   '기종은',
#   '게시',
#   '삭제',
#   '및',
#   '수정',
#   '기능',
#   '불가',
#   '현재',
#   '아이폰',
#   '사실',
#   '또한',
#   '게시',
#   '공지',
#   '칸',
#   '크리',
#   '템',
#   '기능',
#   '옷',
#   '월드',
#   '렉',
#   '렉',
#   '방',
#   '기준',
#   '준정',
#   '점',
#   '사람',
#   '대처',
#   '유저',
#   '업뎃',
#   '유저',
#   '피드백',
#   '수용',
#   '유저',
#   '의견',
#   '담'],
#  ['대부분', '월드', '접속', '문제'],
#  ['삭제', '한국', '랴', '외국인'],
#  ['게임', '무료', '젬', '설문조사', '게시', '삭제', '점'],
#  ['업댓',
#   '갤럭시',
#   '게시',
#   '삭제',
#   '메롱',
#   '아이폰',
#   '크리에이터',
#   '아이템',
#   '선물',
#   '젬',
#   '아이폰',
#   '갤럭시',
#   '크리',
#   '아이템',
#   '선물',
#   '젬',
#   '개월',
#   '번은'],
#  ['업데이트', '게시', '게시', '삭제'],
#  ['업뎃', '게시', '삭제', '시일'],
#  ['업데이트', '영상', '삭제', '거나', '개선'],
#  ['기능', '버그', '게시', '물이', '삭제', '숨기', '수정', '버튼', '몇몇', '점'],
#  ['친구', '혼자', '시간', '모름', '업데이트', '게시', '숨', '기기', '삭제'],
#  ['업데이트',
#   '부터',
#   '게시',
#   '물이',
#   '액션',
#   '화질',
#   '상',
#   '보기',
#   '현질',
#   '유도',
#   '옷',
#   '젬',
#   '사람',
#   '변태',
#   '욕',
#   '남',
#   '비난',
#   '사람',
#   '상처',
#   '점'],
#  ['삼성', '유저', '업데이트', '게시', '물이', '삭제'],
#  ['게시', '삭제', '버튼', '삭제'],
#  ['업뎃', '게시', '삭제', '댜'],
#  ['업데이트', '핸드폰', '테블릿', '게시', '비공', '수정', '공유', '삭제', '비', '공이', '갤럭시'],
#  ['실수', '게시', '삭제', '삭제', '버튼', '삭제', '욕', '제작자', '사과'],
#  ['렉', '추천'],
#  ['계정', '게시', '물이', '삭제', '상황'],
#  ['항상',
#   '즐겜',
#   '유저',
#   '크루',
#   '화면',
#   '게시',
#   '삭제',
#   '점',
#   '문의',
#   '옷장',
#   '아이템',
#   '분류',
#   '기능',
#   '예',
#   '렌즈',
#   '팔다리',
#   '헤어',
#   '장식',
#   '양말',
#   '볼',
#   '기능',
#   '외'],
#  ['게시', '물이', '수정', '식제'],
#  ['님들', '만우절', '월드', '오류'],
#  ['편', '잼', '단점', '옷', '만원', '가격', '벽'],
#  ['계시', '삭제'],
#  ['캐릭터', '렉'],
#  ['업뎃오류땜', '계시', '삭제', '욘'],
#  ['모두',
#   '업데이트',
#   '숨기',
#   '기와',
#   '삭제',
#   '최신',
#   '업데이트',
#   '발생',
#   '오류',
#   '수정',
#   '뿐',
#   '사람',
#   '수정'],
#  ['캐릭터', '다른사람', '소통', '다만', '게시', '삭제', '삭제', '버튼', '눌려', '게시', '시일'],
#  ['젬'],
#  ['최근', '게시', '삭제', '삭제', '버튼', '게시', '버튼', '도저히', '이해'],
#  ['사람', '소통', '선교', '맞팔', '반모', '오류', '게시', '물이', '사람', '업데이트', '업데이트', '버튼'],
#  ['한지',
#   '지난',
#   '페터',
#   '어제',
#   '저녁',
#   '업데이트',
#   '게시',
#   '삭제',
#   '게시',
#   '숨',
#   '기기',
#   '추가',
#   '메세지',
#   '이름',
#   '정',
#   '기능',
#   '추가',
#   '메세지',
#   '젬',
#   '기능',
#   '추가',
#   '과금',
#   '유저',
#   '젬'],
#  ['업뎃', '게시', '삭제'],
#  ['게시', '물이', '업데이트'],
#  ['친구', '사람', '자심', '감', '게임', '게임', '옷', '비교', '역시', '짱짱'],
#  ['오류', '계시', '삭제'],
#  ['어제',
#   '작',
#   '사람',
#   '캐릭터',
#   '게시',
#   '노래',
#   '게시',
#   '게시',
#   '물이',
#   '게시',
#   '숨기',
#   '기도',
#   '눌렸는데'],
#  ['계정', '파고', '닉', '드', '일시', '오류'],
#  ['업데이트', '유저', '개시', '물이', '삭제', '매일', '광고', '광고', '안주', '광고', '낼름'],
#  ['옷', '신발', '미기'],
#  ['게시',
#   '삭제',
#   '태그',
#   '삭제',
#   '게시',
#   '숨기',
#   '기도',
#   '오류',
#   '게임',
#   '플레이',
#   '게시',
#   '업로드',
#   '코스튬',
#   '저장',
#   '상태',
#   '간',
#   '적도',
#   '저장',
#   '공간',
#   '오류'],
#  ['렉',
#   '리뷰',
#   '첫',
#   '월드',
#   '네모',
#   '이벤트',
#   '월드',
#   '가면',
#   '살짝',
#   '버전',
#   '달라',
#   '초대',
#   '월드',
#   '사람',
#   '또한',
#   '게시',
#   '삭제',
#   '렉',
#   '피해',
#   '부탁',
#   '유저',
#   '란',
#   '게임'],
#  ['네모', '네모', '바이러스', '만우절', '게임'],
#  ['게시', '삭제', '태그', '삭제'],
#  ['점프', '마스터', '저건', '젬', '는걸', '업뎃하', '게시', '삭제', '처'],
#  ['아바타',
#   '사람',
#   '소통',
#   '방',
#   '사람',
#   '키',
#   '사이',
#   '거리',
#   '일명',
#   '망둥',
#   '오류',
#   '업데이트',
#   '게시',
#   '삭제',
#   '버튼',
#   '눌리',
#   '해결'],
#  ['게시', '삭제', '숨기'],
#  ['무료', '젬', '어케', '해결', '현질', '무료', '젬', '서비스', '약관', '위반', '점'],
#  ['추가',
#   '점',
#   '젬',
#   '기능',
#   '누가',
#   '자신',
#   '크리',
#   '템',
#   '사면',
#   '젬',
#   '자신',
#   '젬',
#   '업데이트',
#   '유저',
#   '몆분',
#   '게시',
#   '삭제',
#   '대해',
#   '공지',
#   '월드',
#   '월드',
#   '월드',
#   '젬',
#   '현질',
#   '젬',
#   '현질',
#   '사이',
#   '현질',
#   '가격',
#   '예',
#   '젬',
#   '젬',
#   '맞팔',
#   '서로',
#   '팔로우',
#   '사람',
#   '한눈',
#   '볼',
#   '변태',
#   '악플러',
#   '닉',
#   '사용',
#   '유저',
#   '즉시',
#   '처리',
#   '해킹',
#   '범',
#   '옷',
#   '가격',
#   '젬',
#   '크리',
#   '템',
#   '중',
#   '헤어',
#   '실제',
#   '제작자',
#   '팔로워'],
#  ['젬', '렉'],
#  ['영상', '영상', '업데이트', '영상'],
#  ['캐릭터',
#   '자신',
#   '스타일',
#   '수도',
#   '방법',
#   '젬',
#   '아이템',
#   '젬',
#   '방법',
#   '캐릭터',
#   '귀',
#   '스텀',
#   '표정',
#   '스텀',
#   '별'],
#  ['업데이트', '게시', '삭제'],
#  ['계시', '물이', '삭제'],
#  ['업뎃', '게시', '삭제', '킹', '삭제', '진심', '불편', '삭제', '바'],
#  ['렉'],
#  ['업뎃', '게시', '삭제', '거나', '팔'],
#  ['업데이트',
#   '게시',
#   '삭제',
#   '게시',
#   '숨기',
#   '기도',
#   '아이폰',
#   '앱삭',
#   '삼성',
#   '앱삭',
#   '말',
#   '말씀',
#   '이신'],
#  ['게임', '추천', '옷', '자기만족', '친구', '오류', '관리자', '리뷰', '답글'],
#  ['게시', '삭제', '전원'],
#  ['게시'],
#  ['저번', '업데이트', '게시', '삭제', '삭제'],
#  ['업데이트', '계시', '계시', '삭제', '사람', '말로', '삼성', '계발', '자', '어서'],
#  ['캐릭터', '개성', '업뎃', '게시', '삭제', '업뎃할때', '현질', '유도', '가격'],
#  ['이용',
#   '삼성',
#   '유저',
#   '게임',
#   '요하',
#   '버전',
#   '업데이트',
#   '점도',
#   '추가',
#   '포함',
#   '아이폰',
#   '몇몇',
#   '종',
#   '게시',
#   '삭제',
#   '게시',
#   '버튼',
#   '삼성',
#   '액션',
#   '모드',
#   '메롱이',
#   '점도',
#   '이점',
#   '모두',
#   '게임',
#   '게시',
#   '삭제',
#   '기능'],
#  ['모든', '캐릭터', '얼굴', '왼쪽', '거린', '상태', '수정'],
#  ['재미', '게임', '욥'],
#  ['다이아몬드', '반품', '젬', '젬됬어'],
#  ['버전', '초대', '업데이트', '이따', '구로', '설정'],
#  ['레템', '선물'],
#  ['게시', '물이', '삭제', '숨', '기기', '터치'],
#  ['유저',
#   '첫',
#   '오류',
#   '패드',
#   '두번째',
#   '젬',
#   '현질',
#   '다행',
#   '현',
#   '젬',
#   '템',
#   '사기',
#   '세번',
#   '이번업뎃',
#   '게시',
#   '삭제',
#   '가안'],
#  ['업데이트', '게시', '삭제', '카메라', '메롱', '삼성', '아이폰', '업뎃', '카메라', '메롱'],
#  ['계정', '위해', '로그아웃', '로그아웃', '포토', '부스', '아이디', '저장', '오류', '게시', '삭제'],
#  ['점프',
#   '맵',
#   '잼',
#   '차라리',
#   '말',
#   '마',
#   '쿠폰',
#   '출석',
#   '잼',
#   '반년',
#   '유전',
#   '저번',
#   '잼',
#   '얼른'],
#  ['게시', '물이', '삭제'],
#  ['게임', '유저', '게시', '버튼', '업뎃', '삼성', '아이폰', '리기', '제일', '선물', '거나'],
#  ['게시', '삭제', '삭제', '커녕', '게시', '점'],
#  ['닥', '다이쇼', '업데이트', '갤럭시', '게시', '물이'],
#  ['코디',
#   '슬롯',
#   '구매',
#   '제한',
#   '캐릭터',
#   '슬롯',
#   '캐릭터',
#   '복제',
#   '템',
#   '얼마나',
#   '구매',
#   '코디',
#   '슬롯',
#   '고작',
#   '옷',
#   '구매',
#   '저장',
#   '제한',
#   '돈'],
#  ['게시', '삭제'],
#  ['게임', '옷', '여러가지', '포토', '부스', '맵', '여러가지'],
#  ['게시', '삭제', '됫으'],
#  ['게시', '삭제', '삭제', '버튼', '짐'],
#  ['근대',
#   '문제',
#   '게시',
#   '삭제',
#   '근대',
#   '잼',
#   '무료',
#   '캐스트',
#   '팔로우',
#   '달성',
#   '잼',
#   '팔로우',
#   '잼',
#   '잼',
#   '사람',
#   '버그'],
#  ['친구', '찾기', '기능', '없엤으'],
#  ['다운'],
#  ['업데이트', '게시', '삭제'],
#  ['미션', '게임'],
#  ['업댓',
#   '게시',
#   '삭제',
#   '태그',
#   '삭제',
#   '젬',
#   '젬',
#   '점프',
#   '맵',
#   '랜덤',
#   '가까이',
#   '젬',
#   '일반',
#   '유저',
#   '젬',
#   '아이템',
#   '환불',
#   '점'],
#  ['게임', '게임', '업뎃', '게시', '삭제', '게시', '삼성', '유저', '게시', '삭제', '당장'],
#  ['게시', '삭제', '업데이트', '유저', '게시', '물이', '애플', '유저', '젶메', '영상'],
#  ['친구',
#   '추천',
#   '현질',
#   '백일',
#   '큐',
#   '중독',
#   '휴대폰',
#   '시간',
#   '설치',
#   '중독',
#   '업뎃했다',
#   '게시',
#   '물이',
#   '삭제',
#   '처리'],
#  ['게시', '삭제', '숨', '기기', '삭제'],
#  ['젬', '굉고'],
#  ['계시', '물이', '삭제', '최대한', '개선'],
#  ['엡뎃', '때매', '버그', '생경'],
#  ['캐릭터',
#   '퀘스트',
#   '다',
#   '보상',
#   '게임',
#   '게임',
#   '블록',
#   '스랑',
#   '로블록스',
#   '에븐예쁜',
#   '캐릭터',
#   '수도',
#   '여러가지',
#   '게임',
#   '느낌',
#   '군데',
#   '점도',
#   '버그',
#   '게임',
#   '나기',
#   '월',
#   '게임',
#   '버그',
#   '수도',
#   '게임',
#   '버그',
#   '점',
#   '없엉',
#   '버그',
#   '별',
#   '드'],
#  ['가까이', '유저', '로써', '별롭니', '계정', '문제', '게시', '삭제'],
#  ['업뎃', '업뎃', '계시', '삭제', '계시', '신고', '태', '삭제', '렉', '사람', '젶토'],
#  ['젬얻기', '게시', '삭제', '업뎃'],
#  ['젬', '업데이트', '게시', '물이', '삭제', '게시', '삭제'],
#  ['해킹', '젬', '젬', '쭐', '코인', '코인', '코인', '복구'],
#  ['오로라',
#   '업데이트',
#   '업데이트',
#   '태그',
#   '삭제',
#   '게시',
#   '삭제',
#   '게시',
#   '먹통',
#   '뿐',
#   '사람',
#   '오류',
#   '버그',
#   '정',
#   '팔로워',
#   '팔로잉',
#   '정리',
#   '팔로잉',
#   '여야',
#   '팔로잉',
#   '명도',
#   '팔로잉',
#   '고상',
#   '메',
#   '접기',
#   '상',
#   '메',
#   '안뜰',
#   '시도',
#   '일시',
#   '오류'],
#  ['업뎃', '게시', '삭제', '게시', '또한', '월드', '속도'],
#  ['업데이트', '계시', '삭제', '버그', '별', '버그', '쥬', '세용'],
#  ['현재',
#   '사용',
#   '유저',
#   '현질',
#   '유도',
#   '코인',
#   '미션',
#   '었을수',
#   '젬같',
#   '미션',
#   '을해',
#   '었',
#   '려면',
#   '현질',
#   '었을수',
#   '었을수',
#   '코인',
#   '젬',
#   '교환',
#   '시스템'],
#  ['영상', '렉', '렉', '채팅', '창', '튕기는', '렉', '고치', '게임'],
#  ['최근', '업뎃이후', '삼성', '계시', '삭제'],
#  ['장점', '이친', '사람', '점', '광고', '가안', '젬도었', '업데이트', '개시', '물삭', '점', '추천'],
#  ['업데이트', '게시', '태그', '삭제', '상태', '메시지'],
#  ['게시', '삭제'],
#  ['게시', '물이', '삭제', '버그', '유저', '개선'],
#  ['난리',
#   '업뎃',
#   '아이폰',
#   '젶메',
#   '사진',
#   '게시',
#   '삼성',
#   '게시',
#   '사람',
#   '난리',
#   '업뎃',
#   '오오',
#   '식',
#   '최대한'],
#  ['월드', '옷', '법', '월드', '옷', '법'],
#  ['업데이트',
#   '카메라',
#   '의상',
#   '게시',
#   '삭제',
#   '태그',
#   '삭제',
#   '게시',
#   '기도',
#   '상태',
#   '메시지',
#   '보기',
#   '란',
#   '카메라',
#   '기능',
#   '문제',
#   '삭제',
#   '공식',
#   '맵',
#   '짓'],
#  ['게시',
#   '삭제',
#   '삭제',
#   '버튼',
#   '눌렸는데',
#   '삭제',
#   '게시',
#   '숨',
#   '김기도',
#   '눌렸는데',
#   '자쯩나네',
#   '버그'],
#  ['점',
#   '젬',
#   '현질',
#   '을해',
#   '스텀',
#   '유지',
#   '악플',
#   '스팸처리랄까',
#   '악플',
#   '삭제',
#   '게시',
#   '삭제',
#   '숨',
#   '기기'],
#  ['점',
#   '업뎃',
#   '삼성',
#   '게시',
#   '애플',
#   '게시',
#   '메세지',
#   '사진',
#   '난리',
#   '입',
#   '변',
#   '싸이',
#   '사람',
#   '누구',
#   '차단',
#   '이유',
#   '차단',
#   '라서',
#   '젬',
#   '대부분',
#   '아이템',
#   '젬',
#   '젬',
#   '안주시',
#   '이유',
#   '점',
#   '재미'],
#  ['업데이트', '게시', '물이', '삭제', '매우', '점', '외', '오류', '점'],
#  ['기능',
#   '추가',
#   '환불',
#   '기능',
#   '이유',
#   '스텀',
#   '렌즈',
#   '옷',
#   '스텀',
#   '팔로우',
#   '취소',
#   '기능',
#   '팔로우',
#   '취소',
#   '피해',
#   '팔취범',
#   '기능',
#   '꿀잼'],
#  ['업뎃', '하', '게시', '삭제', '숨', '기기'],
#  ['업데이트', '게시', '삭제'],
#  ['게임',
#   '현질',
#   '유저',
#   '망겜임',
#   '차라리',
#   '크리에이터',
#   '몇',
#   '고용',
#   '임뷰',
#   '체계',
#   '게임',
#   '움',
#   '현질',
#   '유도',
#   '유저',
#   '문제',
#   '이미지',
#   '갱생',
#   '불가능'],
#  ['업데이트', '계시', '삭제', '렉'],
#  ['사용',
#   '유저',
#   '가상',
#   '캐릭터',
#   '옷',
#   '현질',
#   '유도',
#   '현질',
#   '최근',
#   '업데이트',
#   '상',
#   '메더',
#   '보기',
#   '게시',
#   '삭제',
#   '그게',
#   '상',
#   '메더',
#   '보기',
#   '보기',
#   '젶메',
#   '삭제',
#   '젶메',
#   '코드',
#   '하진',
#   '대신',
#   '추천',
#   '피드',
#   '인기',
#   '팔로잉',
#   '초심',
#   '초심',
#   '반면',
#   '점',
#   '사기꾼',
#   '사람',
#   '더욱',
#   '월드',
#   '교실',
#   '맵',
#   '현실',
#   '교실',
#   '느낌',
#   '구합',
#   '친구',
#   '선물',
#   '교환',
#   '기념일',
#   '주기',
#   '점',
#   '점'],
#  ['자동', '업데이트', '게시', '삭데', '게시', '숨기', '기도'],
#  ['업데이트',
#   '게시',
#   '물이',
#   '삭제',
#   '게시',
#   '숨',
#   '기기',
#   '아이폰',
#   '업데이트',
#   '게시',
#   '물이',
#   '메세지',
#   '사진',
#   '삼성',
#   '게시',
#   '물이',
#   '업데이트',
#   '업데이트',
#   '업데이트'],
#  ['업데이트', '게시', '삭제', '삼성', '업뎃하', '영상', '게시', '안눌리', '던데'],
#  ['월드'],
#  ['하자', '마자', '회원', '가입', '비밀번호', '일일', '이점', '감스'],
#  ['게임', '점', '젬', '우기', '게임', '주지', '무조건', '매일', '젬', '게임', '게임', '처'],
#  ['영상', '삭제'],
#  ['업뎃',
#   '버그',
#   '개선',
#   '버그',
#   '게시',
#   '삭제',
#   '숨기',
#   '기도',
#   '업뎃',
#   '애초',
#   '최대한',
#   '시일',
#   '게시',
#   '물이',
#   '삭제',
#   '버그',
#   '심각',
#   '관리자',
#   '문제',
#   '항상',
#   '버그',
#   '외',
#   '불만',
#   '별'],
#  ['유저', '얼굴', '현질', '유도', '젬', '안주', '코인'],
#  ['현질', '유도', '쪼', '오금', '젬', '이벤트'],
#  ['업데이트', '게시', '삭재', '태그', '삭재', '이점', '얼른'],
#  ['현질', '유도', '겜', '버전', '업데이트', '게시', '물이'],
#  ['개인', '캐릭터', '전부', '요하', '코인', '젬', '게시', '업데이트'],
#  ['우선',
#   '업데이트',
#   '게시',
#   '물이',
#   '젶메',
#   '랙',
#   '설문조사',
#   '젬',
#   '현질',
#   '출석',
#   '젬',
#   '주기',
#   '업뎃이후'],
#  ['월드', '사용', '업뎃', '오류', '일부러', '업데이트', '게시', '삭제', '업데이트', '자동', '업데이트'],
#  ['업데이트', '아이폰', '사람', '게시', '물이', '삭제', '아이폰', '동영상'],
#  ['별', '준', '이유', '옛날', '영상', '삭제', '삭제', '버튼', '비공개', '공유', '삭제'],
#  ['꿈', '코로나', '싹'],
#  ['노가다', '게임'],
#  ['게임', '아바타', '사용', '별하나', '이유', '런가', '월드', '접속', '렉', '닷'],
#  ['스트레스'],
#  ['업뎃', '게시', '삭제'],
#  ['업데이트', '게시', '상', '오류', '재미', '아이폰', '갤럭시', '삼성', '게시', '삭제', '차라리', '삭제'],
#  ['파티', '게임', '월드', '로딩', '화면', '쨍', '보라색', '업데이트'],
#  ['로그아웃', '한적', '그때', '로그인', '계정', '현질'],
#  ['미션', '클리어', '미션', '태', '미션', '깨', '미션'],
#  ['프리미엄',
#   '현질',
#   '유저',
#   '위화',
#   '감',
#   '시작',
#   '젬',
#   '의상',
#   '헤어',
#   '착용',
#   '개인',
#   '정상',
#   '현질'],
#  ['관리자', '건의', '드릴'],
#  ['플레이',
#   '유저',
#   '리뷰',
#   '이유',
#   '어제',
#   '그때',
#   '업데이트',
#   '버그',
#   '게시',
#   '삭제',
#   '숨',
#   '기기',
#   '점'],
#  ['법'],
#  ['개성',
#   '최근',
#   '업데이트',
#   '오류',
#   '게시',
#   '삭제',
#   '계정',
#   '탈퇴',
#   '태그',
#   '삭제',
#   '숨',
#   '기기',
#   '나머지',
#   '다만',
#   '이점',
#   '게임',
#   '오류',
#   '사람',
#   '사람',
#   '사람',
#   '대부분',
#   '말씀',
#   '해결'],
#  ['업뎃', '태그', '삭제', '동영상'],
#  ['현질', '최대', '일', '기간', '다사', '그때', '아이템', '즐'],
#  ['업데이트', '몇몇', '유저', '팔로우', '업데이트', '확인', '게임', '앞', '게임', '코드', '보상'],
#  ['삭제', '작동', '신고', '악플', '관리자', '신경안', '계정', '정지'],
#  ['젬', '사람', '피드', '음원', '린지', '음원', '쓰기'],
#  ['옷', '변신'],
#  ['젬', '코인', '젬', '게임', '편이', '점프', '맵'],
#  ['게시', '삭제'],
#  ['게시', '삭제', '숨', '기기', '어플', '삭제'],
#  ['게시', '삭제', '다른사람', '업데이트', '라면', '기능', '버그'],
#  ['게시', '삭제'],
#  ['젬', '별', '개에욤', '젬', '확정'],
#  ['업데이트',
#   '갤럭시',
#   '게시',
#   '삭제',
#   '태그',
#   '삭제',
#   '비',
#   '공이',
#   '갤럭시',
#   '메롱',
#   '아이폰',
#   '갤럭시',
#   '에이',
#   '아이템',
#   '선물',
#   '젬',
#   '미션',
#   '년',
#   '현질',
#   '을해',
#   '젬이상',
#   '아이템',
#   '살수',
#   '월드',
#   '진상',
#   '사람',
#   '사람',
#   '방',
#   '방장',
#   '차단',
#   '기능',
#   '방장',
#   '별명',
#   '별명',
#   '준',
#   '사람',
#   '튕',
#   '기기',
#   '렉',
#   '버그'],
#  ['하마지', '로그인', '헸', '묘아', '힝', '구리', '퐁퐁', '티임'],
#  ['최근',
#   '업데이트',
#   '게시',
#   '삭제',
#   '기능',
#   '점',
#   '업데이트',
#   '접',
#   '게시',
#   '숨기',
#   '기와',
#   '삭제',
#   '점',
#   '가장',
#   '해결',
#   '월드'],
#  ['노잼', '겜'],
#  ['이메일', '로그인', '이메일', '삭제', '복구'],
#  ['갤럭시', '메롱', '젬'],
#  ['긴장', '시작'],
#  ['겜',
#   '봄',
#   '캐릭터',
#   '잼민',
#   '놀이터',
#   '스텀',
#   '기능',
#   '현실',
#   '개성',
#   '짐',
#   '젬',
#   '내야',
#   '공식',
#   '아이템',
#   '꽤',
#   '상관',
#   '추천',
#   '은근',
#   '어른',
#   '여러',
#   '나이',
#   '사람',
#   '꽤'],
#  ['렉', '버그', '도움', '도움'],
#  ['욥', '돈', '옷', '순', '옷', '옷', '젬', '금민', '젬', '옷', '가구', '엽', '좋아엽'],
#  ['재미'],
#  ['현질', '유도'],
#  ['업데이트',
#   '스텀',
#   '눈썹',
#   '위치',
#   '게시',
#   '삭제',
#   '및',
#   '숨',
#   '기기',
#   '여러가지',
#   '오류',
#   '갤럭시',
#   '메롱',
#   '매우',
#   '불만'],
#  ['설이님'],
#  ['현질', '완벽', '한게임'],
#  ['무료',
#   '코인',
#   '준',
#   '다해',
#   '번만',
#   '젬얻기',
#   '젬',
#   '게임',
#   '현질',
#   '사람',
#   '대부분',
#   '이크',
#   '세트',
#   '개월',
#   '반',
#   '동안'],
#  ['저장', '저장', '는걸'],
#  ['광고', '코인', '주니', '친찬해'],
#  ['계정', '사람', '업데이트', '점', '업데이트', '게시', '삭제', '만약', '보시', '답장', '시기'],
#  ['그레이', '옷', '입', '자세'],
#  ['저항'],
#  ['설치'],
#  ['젬좀', '퀘스트', '땐', '현질'],
#  ['그다음', '옛날', '예', '옷', '현질', '다이야', '옷', '사면', '옷', '지네'],
#  ['잼', '코인', '로그인', '단점', '크리에이터', '템', '선물', '점', '계정'],
#  ['코디', '판', '코인'],
#  ['사람',
#   '강퇴',
#   '기능',
#   '방',
#   '욕',
#   '거나',
#   '버그',
#   '방',
#   '사람',
#   '신고',
#   '차단',
#   '한계',
#   '방장',
#   '강퇴',
#   '기능'],
#  ['곧', '현질', '예정'],
#  ['옷', '가격', '젬', '구히', '방법', '완벽'],
#  ['게임',
#   '프리미엄',
#   '하루',
#   '말',
#   '결제',
#   '보상',
#   '주네',
#   '보상',
#   '보상',
#   '프리미엄',
#   '하루',
#   '말',
#   '결제',
#   '돈',
#   '고객',
#   '센터',
#   '문의',
#   '구매',
#   '역',
#   '보상',
#   '역도',
#   '결제',
#   '마음대로',
#   '역',
#   '문의'],
#  ['해킹'],
#  ['아유', '유'],
#  ['신고', '젬', '렉'],
#  ['봄', '신발'],
#  ['젬', '코인', '젬', '과금', '유도라', '부담', '무료', '젬'],
#  ['크리에이터', '아이템', '선물'],
#  ['현', '처리', '젬', '젬', '돈'],
#  ['꿀잼'],
#  ['선물', '크리', '템', '선물', '단점', '크리', '템', '선물'],
#  ['젬',
#   '문상',
#   '현질',
#   '젬',
#   '누군가',
#   '개성',
#   '게임',
#   '사람',
#   '소통',
#   '자신',
#   '크리에이터',
#   '가입',
#   '아이템',
#   '러',
#   '이브',
#   '방송',
#   '자신',
#   '캐릭터',
#   '춤',
#   '맵',
#   '친구',
#   '놀',
#   '평화',
#   '대규모',
#   '이벤트',
#   '라이브',
#   '방송',
#   '점점',
#   '발전',
#   '사람',
#   '라이브',
#   '방송',
#   '캐릭터',
#   '게임',
#   '랙',
#   '금방',
#   '추천',
#   '광고'],
#  ['광고',
#   '아무',
#   '보상',
#   '확률',
#   '공개',
#   '주변',
#   '레',
#   '건데',
#   '느낌',
#   '어린이',
#   '여러분',
#   '게임',
#   '블록'],
#  ['노잼', '축하', '점도', '축하', '노잼', '노잼'],
#  ['댓', '하진', '공', '소통', '런데', '게시', '삭제', '댓', '오류', '오류'],
#  ['업데이트', '루', '게시', '삭제', '가안'],
#  ['사용',
#   '한지',
#   '유저',
#   '점',
#   '수정',
#   '아이템',
#   '반품',
#   '기능',
#   '아이템',
#   '반품',
#   '기능',
#   '아이템',
#   '팔고',
#   '예',
#   '그게',
#   '젬',
#   '라면',
#   '젬',
#   '월드',
#   '렉',
#   '월드',
#   '렉',
#   '젬',
#   '현',
#   '젬',
#   '젬',
#   '점',
#   '점도'],
#  ['티비'],
#  ['대로', '캐릭터', '가상', '세계', '현실', '대신'],
#  ['다운로드'],
#  ['게임'],
#  ['업데이트', '게시', '삭제', '게시', '숨', '기기', '작동', '개선'],
#  ['옷', '친구', '영상'],
#  ['업데이트', '삭제', '게시', '숨기', '삭제', '게시'],
#  ['접속', '시간', '겨우', '크리에이터', '선물'],
#  ['마이', '하우스', '밥', '접시', '설거지'],
#  ['젬', '겜', '레벨', '젬', '점'],
#  ['젬', '초창', '유저', '발전', '동시', '현질', '유도', '외'],
#  ['말', '얼굴', '초', '귀화', '킹'],
#  ['음성', '깜짝'],
#  ['캐릭'],
#  ['렉',
#   '버그',
#   '점',
#   '월드',
#   '앱삭',
#   '꽤',
#   '중독',
#   '뮤비',
#   '편집',
#   '주가',
#   '젬',
#   '기도',
#   '크리',
#   '템',
#   '선물',
#   '아이템'],
#  ['무제', '미네'],
#  ['게임', '월드', '일시', '오류로', '참가', '불가'],
#  ['저번', '현질', '옷', '하진', '게임', '점도', '주기', '환불', '요하'],
#  ['연령',
#   '성별',
#   '지역',
#   '직업',
#   '친구',
#   '캐릭터',
#   '재미',
#   '다만',
#   '팔로잉',
#   '친구',
#   '메모',
#   '기능',
#   '만난',
#   '친구',
#   '닉네임',
#   '누',
#   '질'],
#  ['모', '엄마', '도하', '댘', '대요'],
#  ['업데이트', '로그인', '비밀번호', '찾기', '해듀', '임시', '비밀번호', '당황'],
#  ['말', '젬', '확률'],
#  ['가막', '맵', '지고', '사람', '렉', '젬', '게임', '직전'],
#  ['젬', '젬', '옷', '젬', '젬가격', '옷', '코인', '출시', '젬', '무료', '법도'],
#  ['신나요'],
#  ['개인', '저번', '플레이', '중', '코인', '옷', '기본', '만요', '젬'],
#  ['추천'],
#  ['선물', '회원', '가입', '오류', '이점', '차별', '라이브'],
#  ['말',
#   '현실',
#   '그게',
#   '누가',
#   '더팔워',
#   '이름',
#   '이름',
#   '달라',
#   '뭐낮',
#   '베드',
#   '잼',
#   '현질',
#   '게임',
#   '뀌',
#   '전반'],
#  ['젬', '무료'],
#  ['아이탬', '맵', '오류', '간다', '광고', '오류', '처', '상', '편안'],
#  ['크루', '사용', '단어', '포함', '친구', '아무나', '사용', '단어'],
#  ['젬', '코인', '맵', '유저', '해요젬', '코인', '추가', '모드'],
#  ['게임', '심심', '풀이', '게임', '게임', '사람', '추천', '짱짱'],
#  ['점프', '맵', '별'],
#  ['음원', '추출', '때랙', '기능', '이제일', '랙'],
#  ['남친',
#   '가족',
#   '꿀잼',
#   '가다가',
#   '아이템',
#   '발견',
#   '구매',
#   '무조건',
#   '요안',
#   '손해',
#   '손해',
#   '개발자',
#   '꼭답'],
#  ['현질', '저격', '사람', '계정', '정지', '시간', '완벽'],
#  ['렉', '믾', '로딩', '게임'],
#  ['소통', '모든', '한가지', '아무', '사람', '팔로우', '팔로우', '중', '팔로우', '생활'],
#  ['데이터'],
#  ['유저', '틱톡', '점령', '틱톡', '외', '게임'],
#  ['크루', '일', '월드', '중'],
#  ['게임', '영어', '최대한', '처리', '점', '점'],
#  ['캐릭터',
#   '템플릿',
#   '아이',
#   '텀',
#   '한가지',
#   '단점',
#   '라이브',
#   '못키',
#   '공식',
#   '계정',
#   '일반',
#   '계정은',
#   '라이브',
#   '못키',
#   '앞'],
#  ['옷'],
#  ['챗', '능', '라이브', '젬', '현질', '유도'],
#  ['점', '캐릭', '이뽀'],
#  ['마음'],
#  ['게임'],
#  ['컴퓨터', '태블릿', '정식', '제출', '시해', '전화번호', '인증', '번호'],
#  ['젬내놔', '마음', '쓰레기', '게임', '용량'],
#  ['단점',
#   '젬',
#   '젬',
#   '랜덤',
#   '점프',
#   '맵',
#   '점프',
#   '마스터',
#   '랜덤',
#   '젬',
#   '코인',
#   '아이템',
#   '사기',
#   '옷',
#   '취향',
#   '아이템',
#   '대부분',
#   '젬',
#   '코인',
#   '단점'],
#  ['졸라', '무서움', '꿈', '공포', '겜'],
#  ['코인', '젬', '젬'],
#  ['무료', '젬', '설문조사', '젬', '나락', '나락', '설문조사', '셈'],
#  ['여자'],
#  ['곤데', '초기', '초기', '렉'],
#  ['로그인', '어려움', '인증', '번호', '가장', '어려움', '인증', '번호', '그다음'],
#  ['자신', '아이템', '공짜', '크리어', '아이템', '코인', '젬'],
#  ['최근',
#   '페터',
#   '추천',
#   '다만',
#   '별',
#   '이유',
#   '이유',
#   '첫째',
#   '메시지',
#   '삭제',
#   '삭제',
#   '두번째',
#   '달내',
#   '음식',
#   '끼',
#   '젬',
#   '만원',
#   '젬이라뇨',
#   '가격',
#   '매번',
#   '후회',
#   '만원',
#   '젬정',
#   '만원',
#   '젬',
#   '루비',
#   '이유',
#   '가격',
#   '현질',
#   '유도',
#   '고치',
#   '나은',
#   '현질',
#   '돈',
#   '젬코인수',
#   '답장'],
#  ['슬', '라임', '뭐시기', '월드', '친구'],
#  ['방', '키', '신청', '유튭', '방', '신청', '공모전', '매달'],
#  ['게임', '옷', '마음대로', '구매', '장점', '단점', '젶토', '캐릭터', '현질', '계정', '점'],
#  ['유저',
#   '점도',
#   '점',
#   '첫',
#   '젬입니',
#   '젬',
#   '하늘',
#   '별',
#   '젬',
#   '옷',
#   '현질',
#   '두번째',
#   '렉',
#   '먹통',
#   '배터리',
#   '렉',
#   '젬',
#   '코인',
#   '코인',
#   '게임',
#   '몇몇',
#   '점',
#   '플레이'],
#  ['젬찬스', '설문조사', '보이지', '젬', '현질'],
#  ['별',
#   '준',
#   '이유',
#   '단점',
#   '젬',
#   '단점',
#   '환불',
#   '크리에이터',
#   '아이템',
#   '선물',
#   '환불',
#   '기능',
#   '젬',
#   '젬',
#   '퀘스트',
#   '미션',
#   '젬',
#   '요별'],
#  ['시작', '유저', '캐릭터', '돈', '내야', '미만', '청소년', '부모님', '동의', '캐릭터', '돈'],
#  ['보석', '쪼끔', '현질', '현질', '제작자', '칭찬'],
#  ['계정', '계정'],
#  ['인증', '번호', '문자'],
#  ['광고'],
#  ['굉소', '전부'],
#  ['여러분', '별', '왜냐면', '악플러'],
#  ['보호자', '동의', '확인', '옛날', '구글', '계정', '회원', '가입', '집', '부모님'],
#  ['개발자', '님', '선물', '채팅', '플레이어', '얼굴', '사진', '부계', '신고', '계정', '정지', '정지'],
#  ['가상현실'],
#  ['사람', '짜증', '점프', '맵', '시기'],
#  ['틱톡', '점령', '마', '제바', '류'],
#  ['시작', '기본', '매우', '첫날'],
#  ['캐릭터', '현질', '게임', '방', '데이터', '랙', '애러', '현질', '현질', '현질'],
#  ['월드', '돌림', '판', '젬', '잼', '확률', '월드', '갑사', '광고', '랙'],
#  ['유저', '잼', '무료', '잼', '잼', '그게', '헛수', '드릴'],
#  ['코로나', '공공', '장소', '게임', '다만', '맵', '시간', '점'],
#  ['잼민', '보석'],
#  ['갤럭시', '탭', '사용', '데이터', '다운로드', '실행', '접속', '강제', '종료', '확인', '부탁'],
#  ['위시',
#   '아이템',
#   '삭제',
#   '선물',
#   '위시',
#   '아이템',
#   '아이템',
#   '구경',
#   '저장',
#   '템',
#   '위시',
#   '리스트',
#   '발견',
#   '거꾸로',
#   '삭제'],
#  ['크루', '단어', '포함', '신고', '아이돌', '모집', '크루', '다른사람', '신고', '최대한', '답장'],
#  ['월드', '시간'],
#  ['유저', '별', '불편', '점', '친구', '선물', '크리에이터', '옷', '신발', '머리카락', '선물'],
#  ['실사', '발전'],
#  ['시간', '사람', '소통'],
#  ['개임', '광', '드럽갸'],
#  ['광고'],
#  ['돈'],
#  ['꿀잼', '컴텨'],
#  ['몇',
#   '단점',
#   '장점',
#   '캐릭터',
#   '스텀',
#   '크루',
#   '사람과',
#   '여러',
#   '크리에이터',
#   '템',
#   '콜라보',
#   '템',
#   '단점',
#   '유무',
#   '차별',
#   '무명',
#   '추천',
#   '현질',
#   '젬',
#   '크리에이터',
#   '템',
#   '컬러',
#   '선물',
#   '점',
#   '체형',
#   '스텀',
#   '리뷰',
#   '즐겨찾기',
#   '알림',
#   '단점',
#   '장점',
#   '둘',
#   '추천'],
#  ['랙', '오징어', '게임'],
#  ['잼', '몇', '로그인', '님들', '잠수', '타지'],
#  ['은근', '힐링', '소통', '응원', '진심', '힘'],
#  ['카톡', '계정', '유렌입니', '단점', '레', '정성', '별', '점'],
#  ['안전',
#   '면소',
#   '여러분',
#   '광고',
#   '만이',
#   '일',
#   '점주',
#   '기도',
#   '랙',
#   '만이',
#   '게임',
#   '매스',
#   '트래스',
#   '만세',
#   '여러분'],
#  ['데옷', '젬', '옷', '점', '깨', '돈', '기도', '게임', '중'],
#  ['설치', '아바타', '때영', '어가', '종료', '됫'],
#  ['재미', '사람'],
#  ['옛날', '과금', '유도'],
#  ['진짜진짜',
#   '친구',
#   '사회',
#   '상이',
#   '느낌',
#   '현실',
#   '라서',
#   '사이버',
#   '친구',
#   '목소리',
#   '키',
#   '단점',
#   '아이템',
#   '점',
#   '가격'],
#  ['재밋음'],
#  ['첨', '시작', '인증', '번호'],
#  ['옷', '스텀', '선물', '레', '옷', '선물', '위시', '레', '포토'],
#  ['맨', '앞', '비밀번호', '점'],
#  ['점'],
#  ['트라우마'],
#  ['월드',
#   '옷',
#   '살수',
#   '동영상',
#   '여러가지',
#   '하수',
#   '문제점',
#   '젬',
#   '방법',
#   '한마디',
#   '현질',
#   '쥐',
#   '코인',
#   '살수'],
#  ['렉'],
#  ['로그인', '로그인'],
#  ['게임'],
#  ['레', '다섯'],
#  ['코인', '업데이트'],
#  ['캐릭터', '체형', '어깨', '키', '애기', '체형', '착욕'],
#  ['모자', '욕', '말', '사용', '단어', '설정', '상처', '대부분', '욕', '폭력', '신고', '계정', '정지'],
#  ['게임', '안해'],
#  ['한가지', '아이템', '가격', '원가'],
#  ['버퍼링', '버퍼링', '로딩', '크리에이터', '돈', '달이', '무소식'],
#  ['광고', '실어'],
#  ['젬'],
#  ['현질', '요구', '겜'],
#  ['별', '다섯'],
#  ['게임', '추천', '친구', '사람', '일', '수도', '게임'],
#  ['마음', '파일', '노리'],
#  ['옷', '젬', '젬', '맵', '플레이', '화면', '점프', '점', '고치'],
#  ['회', '가입'],
#  ['사용'],
#  ['광고'],
#  ['현질',
#   '이메일',
#   '계정',
#   '이메일',
#   '고객',
#   '센터',
#   '보라',
#   '구매',
#   '영수증',
#   '계정',
#   '카드',
#   '현질',
#   '영수증',
#   '담당자',
#   '말'],
#  ['가입자', '전체', '적', '게임', '젬', '획득', '찬스', '젬', '패치'],
#  ['아이템', '착용'],
#  ['로그인', '전화번호', '인증', '번호'],
#  ['시작', '천', '코인', '캐릭', '턷', '미리', '계정', '초기', '돈', '천', '코인'],
#  ['버그'],
#  ['친구', '게임', '추천', '한가지', '퀘스트', '젬', '어더', '지지', '현질', '유도', '겉', '답글'],
#  ['동안',
#   '유저',
#   '노트북',
#   '노트북',
#   '녹스',
#   '로그인',
#   '약관',
#   '동의',
#   '영어',
#   '그동안',
#   '기록',
#   '코인',
#   '옷',
#   '핸드폰',
#   '월드',
#   '랙',
#   '문제',
#   '첫',
#   '문제',
#   '노트북',
#   '문제',
#   '두번째',
#   '문제',
#   '핸드폰',
#   '문제'],
#  ['점', '광고', '잼', '미가', '광고', '가게', '속', '점', '광고'],
#  ['리뷰', '오류'],
#  ['시작', '젬', '사고', '젬이'],
#  ['저밋다'],
#  ['유저',
#   '모든',
#   '소원',
#   '크리',
#   '템',
#   '선물',
#   '친구',
#   '크리',
#   '템',
#   '선물',
#   '친구',
#   '크리',
#   '템',
#   '욕',
#   '을해',
#   '크리',
#   '템',
#   '선물',
#   '감사',
#   '크리',
#   '템',
#   '선물',
#   '현질',
#   '유저'],
#  ['라이브', '사람', '허용'],
#  ['틱톡', '점령'],
#  ['월드'],
#  ['상황', '튕', '안부'],
#  ['영상', '음원', '월드', '마다', '월드', '입장', '버그', '수정'],
#  ['기도'],
#  ['생년', '월일', '적'],
#  ['의', '문제', '매일', '시어', '랙', '거려', '삭제', '랙', '랙좀'],
#  ['유저', '아이템', '머', '다만', '젬', '설문조사', '음해'],
#  ['친구', '점', '채팅', '가입'],
#  ['메타', '버스', '관련', '기도', '싸움', '현피', '사람'],
#  ['말',
#   '당황',
#   '상황',
#   '월드',
#   '데커',
#   '스텀',
#   '초기',
#   '아이템',
#   '인테리어',
#   '캐릭터',
#   '스텀',
#   '초기',
#   '당황',
#   '보상',
#   '보상'],
#  ['점', '자동', '로그아웃', '현질', '아이템', '일', '관리자'],
#  ['재미', '아싑아싑'],
#  ['라이브', '답변'],
#  ['돈', '옷', '점', '빼'],
#  ['몇개',
#   '월',
#   '맛',
#   '시작',
#   '아이템',
#   '레이',
#   '에터',
#   '템',
#   '퀄',
#   '템',
#   '크리',
#   '템',
#   '은',
#   '현질',
#   '현질',
#   '더욱',
#   '마지막',
#   '과금',
#   '젬',
#   '엏을수',
#   '방법',
#   '추가'],
#  ['컨트롤'],
#  ['아이템', '아이템', '돈', '만해', '코인', '아이템', '하루', '코인', '하루', '아침'],
#  ['게임', '고치'],
#  ['도중', '광고', '뽑기', '광고', '화면', '터치', '먹통', '코인', '보석', '조작'],
#  ['게임',
#   '동안',
#   '유저',
#   '도저히',
#   '리뷰',
#   '월드',
#   '비',
#   '섭',
#   '하',
#   '일시',
#   '오류',
#   '항상',
#   '비',
#   '섭'],
#  ['하이',
#   '떡',
#   '검',
#   '가업',
#   '데이트',
#   '계정',
#   '시작',
#   '월',
#   '계정',
#   '도안',
#   '리뷰',
#   '작성',
#   '게다가',
#   '실수',
#   '로그인',
#   '아웃',
#   '계정'],
#  ['크리', '템', '크리', '템', '널렸'],
#  ['튕', '기지'],
#  ['젬', '젬'],
#  ['추가',
#   '점프',
#   '마스터',
#   '퀘스트',
#   '랜덤',
#   '뽑기',
#   '확률',
#   '설문조사',
#   '젬',
#   '시스템',
#   '만들기',
#   '현질',
#   '로선',
#   '일주일',
#   '젬',
#   '헬로월드',
#   '누구',
#   '미션',
#   '점프',
#   '마스터',
#   '시간',
#   '크리에이터',
#   '템',
#   '선물',
#   '라이브',
#   '권한',
#   '참고',
#   '지원',
#   '지원',
#   '시간',
#   '오류',
#   '치기',
#   '리뷰',
#   '오류',
#   '인정',
#   '문의',
#   '해결'],
#  ['꿀잼'],
#  ['젬', '하늘', '별', '추천'],
#  ['젬', '왤케', '현', '무과', '금은', '점'],
#  ['송', '푸른'],
#  ['와이파이', '데이터', '오류', '동생', '슬', '라임', '파티', '동생', '월드', '동샹', '슬라임'],
#  ['유저', '광고', '의견'],
#  ['팔도', '늘'],
#  ['투자', '데페', '잔액', '돈', '현질', '네트워크', '난액', '액', '돈'],
#  ['틱톡', '항상', '악의', '허위', '사실', '렉'],
#  ['겜',
#   '렉',
#   '튕',
#   '기구',
#   '심지어',
#   '부계',
#   '심지어',
#   '바이러스',
#   '광고',
#   '퀘스트',
#   '건너',
#   '광고',
#   '버튼',
#   '렉',
#   '젶토',
#   '공감'],
#  ['사람', '틱톡', '에세', '욕', '을'],
#  ['재밋어'],
#  ['유저', '젶토', '채팅', '팔로', '덕', '부모', '인증', '로그인', '미성년', '자라', '몰래'],
#  ['소통', '소통', '제페도', '사람', '익명', '뮤비', '중학생'],
#  ['현재',
#   '이용',
#   '사용자',
#   '별',
#   '이유',
#   '젬',
#   '점프',
#   '맵',
#   '상관',
#   '사람',
#   '선물',
#   '기간',
#   '가격',
#   '젬',
#   '가격',
#   '월드',
#   '랙',
#   '이점',
#   '개인',
#   '랙',
#   '현질',
#   '유도',
#   '젬',
#   '현질',
#   '캐릭터',
#   '슬롯',
#   '현질',
#   '이점',
#   '단점'],
#  ['랙', '별'],
#  ['재미'],
#  ['사람',
#   '렉페토',
#   '렉',
#   '데이터',
#   '저장',
#   '공간',
#   '관리',
#   '월드',
#   '장식품',
#   '렉',
#   '말',
#   '마이크',
#   '욕',
#   '채팅',
#   '욕',
#   '신고',
#   '증거',
#   '정지',
#   '정지'],
#  ['젬내놔'],
#  ['교',
#   '표',
#   '려',
#   '혗',
#   '햐',
#   '렫',
#   '려',
#   '갸',
#   '햧',
#   '뎦류',
#   '려',
#   '횴',
#   '펻호',
#   '곂',
#   '혀',
#   '규',
#   '혀',
#   '햐',
#   '뎣',
#   '향',
#   '혀',
#   '경'],
#  ['젬', '방법', '퀘스트', '젬', '퀘스트', '젬', '보상', '퀘스트'],
#  ['핵', '노잼', '저가', '점프', '맵', '설명', '도안', '점', '놈', '점주', '기도'],
#  ['로그인', '을제', '폐도', '보통', '랙', '폐도', '언어', '폭력', '욕', '사람', '스킨', '박티', '내면'],
#  ['장난', '과금', '정지', '문의', '답변', '장난', '팔', '돈'],
#  ['올해', '트랜드', '구매'],
#  ['말'],
#  ['친구', '어머니', '몰래', '계정', '삭제', '설치', '식', '설치', '별', '이유', '잼', '저희'],
#  ['로그인', '로그인'],
#  ['요강', '추', '문자', '계', '삭제', '로그인', '초기', '광고', '별', '점', '만점', '점'],
#  ['게임',
#   '절대',
#   '요절',
#   '대절',
#   '랙',
#   '삼세',
#   '게임',
#   '힐링',
#   '힐링',
#   '사람',
#   '즐거움',
#   '커녕',
#   '스트레스',
#   '게임',
#   '사실',
#   '반',
#   '평',
#   '주기',
#   '평'],
#  ['게임',
#   '유저',
#   '영상',
#   '추도',
#   '완',
#   '게임',
#   '돈',
#   '몼쓰',
#   '사람',
#   '현질',
#   '사람',
#   '다른사람',
#   '마음',
#   '다사',
#   '려면',
#   '만원',
#   '돈',
#   '잼',
#   '운',
#   '돈',
#   '잼',
#   '선물',
#   '뽑기',
#   '잼',
#   '확률'],
#  ['시작', '여자', '시작', '겜'],
#  ['자동', '삭제', '복귀'],
#  ['어재미', '편집', '뿐', '젠', '옛날', '특유', '외계인', '겜'],
#  ['게임', '남캐옷', '사람', '가면', '살짝', '렉'],
#  ['잼'],
#  ['진',
#   '인어공주',
#   '머리카락',
#   '코인',
#   '코인',
#   '인어공주',
#   '스킨',
#   '코인',
#   '벤트',
#   '점',
#   '드릴',
#   '태',
#   '잼',
#   '출석',
#   '체크',
#   '캐시',
#   '잼',
#   '료',
#   '하루'],
#  ['캐릭터'],
#  ['멋', '짜증'],
#  ['밌어'],
#  ['한가지', '젬', '무료', '하루', '출석', '젬', '젬'],
#  ['삭제'],
#  ['옛날', '해봣는데', '렉', '현질', '광고', '게임', '여러분', '후회'],
#  ['광고'],
#  ['잼'],
#  ['퀘스트', '건너', '광고', '점'],
#  ['게임', '로그인', '을해', '하드', '삐폰', '그땐', '로그인', '드', '러', '드', '로그인'],
#  ['돈', '월드'],
#  ['친구', '소통', '게시', '구경'],
#  ['게임', '로그인', '망겜'],
#  ['유저', '젬', '환불', '말씀', '약'],
#  ['광고'],
#  ['월드', '랙', '젬'],
#  ['사랑'],
#  ['게임',
#   '에러',
#   '포즈',
#   '화면',
#   '시간',
#   '점도',
#   '주기',
#   '시간',
#   '이면',
#   '유튜브',
#   '한편',
#   '볼',
#   '배터리',
#   '프로',
#   '비',
#   '추천'],
#  ['월드', '친구', '팔로워', '친구', '월드', '월드', '친구', '침', '게시'],
#  ['슬', '라임', '게임', '젬'],
#  ['대체', '문의', '답장'],
#  ['멍', '유로'],
#  ['메타', '버스'],
#  ['별'],
#  ['추가',
#   '욥',
#   '뮤비',
#   '노래',
#   '노래',
#   '검색',
#   '기능',
#   '욥',
#   '체형',
#   '스텀',
#   '체형',
#   '체형',
#   '스텀',
#   '개성',
#   '퀘스트',
#   '젬',
#   '추가',
#   '과금',
#   '젬',
#   '퀘스트',
#   '젬',
#   '추가',
#   '업데이트',
#   '욥'],
#  ['뮤비'],
#  ['월드', '버그', '월드', '채팅'],
#  ['설명', '젬', '아쉬움'],
#  ['젬', '예의'],
#  ['구글', '계정', '게임', '게임', '버벅거려', '게임', '계정', '해결'],
#  ['개똥폰', '차별', '월드'],
#  ['로그인'],
#  ['계발',
#   '자',
#   '부탁',
#   '계정',
#   '사람',
#   '패',
#   '드립',
#   '욕',
#   '모자',
#   '협박',
#   '모욕',
#   '말',
#   '욕',
#   '신고',
#   '계정',
#   '정지',
#   '계정'],
#  ['항상', '크루', '젬나눔', '크루', '활동', '정지', '여자아이', '옷'],
#  ['마메', '마쿠', '태누머캐', '뉴바', '붘커누마캐누너컽'],
#  ['타워'],
#  ['월드', '맵', '의상', '밀리터리', '의상'],
#  ['서버', '튕깁니', '서비스', '안정화'],
#  ['사기',
#   '기본',
#   '편집',
#   '영상',
#   '똥',
#   '욕',
#   '처리',
#   '도안',
#   '버그',
#   '차지',
#   '똥겜',
#   '별하나',
#   '현질',
#   '유도'],
#  ['젬',
#   '퀘스트',
#   '젬그래브',
#   '게임',
#   '레벨',
#   '달성',
#   '젬',
#   '다운',
#   '레벨',
#   '달성',
#   '미션',
#   '레벨',
#   '달성',
#   '이유',
#   '젬',
#   '돈',
#   '돈',
#   '쓰기',
#   '사람',
#   '사람',
#   '배려',
#   '새벽',
#   '레벨',
#   '달성',
#   '미션',
#   '게임',
#   '운지',
#   '년',
#   '동안',
#   '젭',
#   '월드'],
#  ['렉', '초기', '월드', '욕', '오류', '명중', '인생', '살짝', '게임', '졈', '개입'],
#  ['튕'],
#  ['크리에이터', '옷', '젬', '무료', '현질', '재밋는데', '랙', '젬'],
#  ['크루',
#   '렉',
#   '아이템',
#   '환불',
#   '기능',
#   '크리',
#   '템',
#   '젬',
#   '현금',
#   '아이템',
#   '환불',
#   '젬',
#   '환불',
#   '시스템',
#   '차라리'],
#  ['계', '정보'],
#  ['돈', '안내', '게임', '은줄', '아빠'],
#  ['리뷰',
#   '현질',
#   '링',
#   '유저',
#   '허위',
#   '신고',
#   '계정',
#   '영구',
#   '정지',
#   '유저',
#   '말',
#   '피해자',
#   '말',
#   '현질',
#   '유도',
#   '게임',
#   '잼',
#   '방법'],
#  ['만하', '오류', '응답', '난리'],
#  ['젬', '캐릭터', '별', '드릴'],
#  ['앞', '설명', '어려움'],
#  ['안녕', '해초', '여자', '로그인', '아이디', '글자', '숫자', '계정', '비밀번호', '이메일', '전이', '메일'],
#  ['켸릭터', '돈', '템', '사기', '맵', '주의'],
#  ['아바타',
#   '친추',
#   '점',
#   '옷',
#   '돈',
#   '겜',
#   '한지',
#   '돼지',
#   '비디오',
#   '사람',
#   '바꾸죵',
#   '우선',
#   '같아욯',
#   '별',
#   '준',
#   '이유',
#   '방',
#   '방',
#   '방이',
#   '인기',
#   '점프',
#   '맵',
#   '체크',
#   '포인트',
#   '설치',
#   '게임',
#   '추천'],
#  ['광고', '덕지덕지'],
#  ['렉'],
#  ['젬'],
#  ['매일', '돈', '맵', '갈수', '있엊'],
#  ['돈', '보석', '젬', '현질', '추천', '옷', '머리', '아보'],
#  ['렉'],
#  ['세상'],
#  ['기억', '젬', '선물'],
#  ['살이', '혼자', '인증', '번호', '동의', '인증'],
#  ['젬'],
#  ['문제',
#   '꽤',
#   '사실',
#   '꽤',
#   '오류로',
#   '광고',
#   '볼',
#   '오류로',
#   '옷',
#   '신상',
#   '옷',
#   '상점',
#   '버퍼링',
#   '시작',
#   '버퍼링',
#   '버퍼링',
#   '옷',
#   '심지어',
#   '버퍼링',
#   '옷',
#   '얘기',
#   '로딩',
#   '옷',
#   '도대체',
#   '또한',
#   '월드',
#   '신세',
#   '친구',
#   '다',
#   '월드',
#   '오류',
#   '메시지',
#   '월드',
#   '입장',
#   '화면',
#   '도저히',
#   '친구',
#   '놀',
#   '다운',
#   '수정'],
#  ['별', '면제', '초딩', '현질', '젬', '젬', '젬', '옷', '머리', '못었', '젬', '이벤트'],
#  ['캐릭터', '기도'],
#  ['플레이', '유저', '옷', '계정', '남아', '옷', '판매', '닷'],
#  ['젬모으기', '카카오', '톡', '채널', '인스타', '팔로워', '유튜브', '구독'],
#  ['설치'],
#  ['상상', '아바타'],
#  ['유저',
#   '잼',
#   '현질',
#   '말',
#   '다애',
#   '엄마',
#   '아빠',
#   '태',
#   '잼',
#   '퀘스트',
#   '고작',
#   '말',
#   '잼',
#   '무료'],
#  ['친구', '캐릭터', '명일', '캐릭터', '친구', '캐릭터', '사진'],
#  ['게임', '젬', '오류', '어제', '화면', '흰색', '옷', '핸드폰', '전원', '버그'],
#  ['유저', '크리에이터', '옷', '편집', '하얀색', '배경'],
#  ['랙'],
#  ['잼', '가입', '잼', '안주', '총', '잼'],
#  ['다운', '동생'],
#  ['욕', '사람', '개념'],
#  ['게임',
#   '유저',
#   '무명',
#   '제밌',
#   '겜',
#   '유저',
#   '크리에이터',
#   '사람',
#   '코너',
#   '코너',
#   '사람',
#   '물건',
#   '사고',
#   '팔고',
#   '다만',
#   '코너',
#   '옷',
#   '현질',
#   '크리에이터',
#   '옷',
#   '선물',
#   '젬',
#   '사용',
#   '연령',
#   '노출',
#   '옷',
#   '하든',
#   '아이',
#   '법',
#   '코인',
#   '젬',
#   '선물',
#   '현질',
#   '유도',
#   '단점',
#   '접',
#   '일',
#   '나은',
#   '위해',
#   '업데이트',
#   '점',
#   '추가',
#   '단점',
#   '말',
#   '장점',
#   '단점',
#   '비교',
#   '최애',
#   '겜',
#   '단점',
#   '사용'],
#  ['돈', '얼'],
#  ['엄잘', '옛날', '계정', '저장', '돈', '보석'],
#  ['게임',
#   '사용',
#   '동안',
#   '결과',
#   '현질',
#   '젬',
#   '퀘스트',
#   '몇개',
#   '젬',
#   '가격',
#   '현',
#   '현질',
#   '현질',
#   '배려'],
#  ['유저', '광고', '단점', '젬얻기', '간다'],
#  ['출석', '보상', '젬', '하루', '젬', '젬', '사람', '겁', '코인', '젬', '훨'],
#  ['젬', '개입'],
#  ['사용', '점', '단점', '월드', '다운로드', '문제', '라면', '요긴', '빛', '소녀', '옷', '월드'],
#  ['친구', '게임', '아바타', '게임', '다만', '보석', '봄', '오래오래', '사시', '게임'],
#  ['컴퓨터', '떄', '영어', '여태', '안떳는데', '휴대폰', '컴퓨터', '게임', '영어'],
#  ['옷', '단점', '이구', '장점', '옷', '돈', '게임', '추천'],
#  ['계정',
#   '팔로우',
#   '로그아웃',
#   '계정',
#   '팔로우',
#   '계정',
#   '복구',
#   '임시',
#   '비번',
#   '임시',
#   '비번',
#   '하루',
#   '계정',
#   '해킹',
#   '관리자',
#   '계정',
#   '이름',
#   '아인'],
#  ['게임',
#   '단점',
#   '잼',
#   '점프',
#   '맵',
#   '잼',
#   '설문조사',
#   '겨우',
#   '듣기',
#   '설문조사',
#   '옷',
#   '모자',
#   '신발',
#   '머리카락',
#   '잼',
#   '춤',
#   '사진',
#   '머리카락',
#   '몸',
#   '간통'],
#  ['재미'],
#  ['카카오',
#   '톡',
#   '계정',
#   '카카오',
#   '톡',
#   '아이디',
#   '계정',
#   '옛날',
#   '카카오',
#   '톡',
#   '계정',
#   '남아',
#   '로그인'],
#  ['옛날', '돈'],
#  ['실행', '로고', '종료'],
#  ['우선', '과금', '유저', '젬모으기', '팔찌', '네일', '장갑', '중복', '크리', '템', '선물'],
#  ['북유럽', '사람', '대화', '방법'],
#  ['게임', '게임', '캐릭터', '이점', '고치시'],
#  ['게임', '미션', '완료', '잼'],
#  ['게임'],
#  ['최근', '업데이트', '돈'],
#  ['재밋', '잼', '코인', '코인', '광', '잼', '개임', '밋션', '폴발', '별', '폴발'],
#  ['스타일', '취소', '기능'],
#  ...]

# %%
from gensim.models.ldamodel import LdaModel
from gensim.models.callbacks import CoherenceMetric
from gensim import corpora
from gensim.models.callbacks import PerplexityMetric

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
dictionary = corpora.Dictionary(processed_data)
dictionary.filter_extremes(no_below=2, no_above=0.5)
# Out:
# 2022-08-29 17:03:15,810 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2022-08-29 17:03:15,881 : INFO : adding document #10000 to Dictionary(7294 unique tokens: ['개선', '기능', '마비', '문제', '사용성']...)
# 2022-08-29 17:03:15,948 : INFO : adding document #20000 to Dictionary(10992 unique tokens: ['개선', '기능', '마비', '문제', '사용성']...)
# 2022-08-29 17:03:16,000 : INFO : adding document #30000 to Dictionary(13375 unique tokens: ['개선', '기능', '마비', '문제', '사용성']...)
# 2022-08-29 17:03:16,053 : INFO : adding document #40000 to Dictionary(15435 unique tokens: ['개선', '기능', '마비', '문제', '사용성']...)
# 2022-08-29 17:03:16,075 : INFO : built Dictionary(15983 unique tokens: ['개선', '기능', '마비', '문제', '사용성']...) from 43925 documents (total 280551 corpus positions)
# 2022-08-29 17:03:16,075 : INFO : Dictionary lifecycle event {'msg': "built Dictionary(15983 unique tokens: ['개선', '기능', '마비', '문제', '사용성']...) from 43925 documents (total 280551 corpus positions)", 'datetime': '2022-08-29T17:03:16.075158', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'created'}
# 2022-08-29 17:03:16,086 : INFO : discarding 8928 tokens: [('붙임머리', 1), ('체제', 1), ('있었르', 1), ('민물고기', 1), ('가스', 1), ('시제', 1), ('벼텼어', 1), ('자밌어', 1), ('장식등', 1), ('젚속', 1)]...
# 2022-08-29 17:03:16,086 : INFO : keeping 7055 tokens which were in no less than 2 and no more than 21962 (=50.0%) documents
# 2022-08-29 17:03:16,092 : INFO : resulting dictionary: Dictionary(7055 unique tokens: ['개선', '기능', '마비', '문제', '사용성']...)

# %%
corpus = [dictionary.doc2bow(text) for text in processed_data]

# %%
# -*- coding: utf-8 -*-
from konlpy.tag import Mecab
from tqdm import tqdm
import re
from gensim.models.ldamodel import LdaModel
from gensim.models.callbacks import CoherenceMetric
from gensim import corpora
from gensim.models.callbacks import PerplexityMetric
import logging
import pickle
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

coherence_values = []
perpexities_values = []
model_list = []


def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=1):
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        perpexities_values.append(model.log_perplexity(corpus))

    return model_list, coherence_values, perpexities_values


def find_optimal_number_of_topics(dictionary, corpus, processed_data):
    limit = 11;
    start = 2;
    step = 1;

    model_list, coherence_values, perpexities_values = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=processed_data, start=start, limit=limit, step=step)

    x = range(start, limit, step)
    plt.plot(x, coherence_values)
    plt.xlabel("Num Topics")
    plt.ylabel("Coherence score")
    plt.legend(("coherence_values"), loc='best')
    plt.show()
    
    x = range(start, limit, step)
    plt.plot(x, perpexities_values)
    plt.xlabel("Num Topics")
    plt.ylabel("perpexities_values")
    plt.legend(("perpexities_values"), loc='best')
    plt.show()

if __name__ == '__main__':
    
    print('Number of unique tokens: %d' % len(dictionary))
    print('Number of documents: %d' % len(corpus))

    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

    #최적의 토픽 수 찾기
    find_optimal_number_of_topics(dictionary, corpus, processed_data)
# Out:
# 2022-08-29 17:03:16,246 : INFO : using symmetric alpha at 0.5
# 2022-08-29 17:03:16,246 : INFO : using symmetric eta at 0.5
# 2022-08-29 17:03:16,247 : INFO : using serial LDA version on this node
# 2022-08-29 17:03:16,249 : INFO : running online (single-pass) LDA training, 2 topics, 1 passes over the supplied corpus of
# 2022-08-29 17:03:22,105 : INFO : topic diff=0.250413, rho=0.218218
# 2022-08-29 17:03:22,344 : INFO : -6.713 per-word bound, 104.9 perplexity estimate based on a held-out corpus of 1925 documents with 9555 words
# 2022-08-29 17:03:22,344 : INFO : PROGRESS: pass 0, at document #43925/43925
# 2022-08-29 17:03:22,520 : INFO : merging changes from 1925 documents into a model of 43925 documents
# 2022-08-29 17:03:22,522 : INFO : topic #0 (0.500): 0.047*"옷" + 0.034*"캐릭터" + 0.033*"코인" + 0.021*"돈" + 0.018*"렉" + 0.017*"추가" + 0.016*"사진" + 0.015*"기능" + 0.013*"친구" + 0.012*"점"
# 2022-08-29 17:03:22,522 : INFO : topic #1 (0.500): 0.048*"게임" + 0.026*"계정" + 0.024*"렉" + 0.023*"로그인" + 0.022*"퀘스트" + 0.020*"틱톡" + 0.018*"돈" + 0.017*"광고" + 0.015*"화면" + 0.013*"업데이트"
# 2022-08-29 17:03:22,522 : INFO : topic diff=0.223625, rho=0.213201
# 2022-08-29 17:03:22,523 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=7055, num_topics=2, decay=0.5, chunksize=2000) in 6.27s', 'datetime': '2022-08-29T17:03:22.523638', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'created'}
# 2022-08-29 17:03:22,523 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2022-08-29 17:03:47,762 : INFO : 15 accumulators retrieved from output queue
# 2022-08-29 17:03:47,779 : INFO : accumulated word occurrence stats for 31217 virtual documents
# 2022-08-29 17:03:53,245 : INFO : -6.976 per-word bound, 125.9 perplexity estimate based on a held-out corpus of 43925 documents with 271360 words
# 2022-08-29 17:03:53,246 : INFO : using symmetric alpha at 0.3333333333333333
# 2022-08-29 17:03:53,246 : INFO : using symmetric eta at 0.3333333333333333
# 2022-08-29 17:03:53,247 : INFO : using serial LDA version on this node
# 2022-08-29 17:03:53,249 : INFO : running online (single-pass) LDA training, 3 topics, 1 passes over the supplied corpus of 43925 documents, updating model once every 2000 documents, evaluating perplexity every 20000 documents, iterating 50x with a convergence threshold of 0.001000
# 2022-08-29 17:03:53,250 : INFO : PROGRESS: pass 0, at document #2000/43925
# 2022-08-29 17:03:53,772 : INFO : merging changes from 2000 documents into a model of 43925 documents
# 2022-08-29 17:03:53,773 : INFO : topic #0 (0.333): 0.042*"게임" + 0.032*"젬" + 0.030*"게시" + 0.028*"삭제" + 0.017*"월드" + 0.017*"광고" + 0.015*"업데이트" + 0.014*"현질" + 0.013*"계정" + 0.013*"사람"
# 2022-08-29 17:03:53,774 : INFO : topic #1 (0.333): 0.027*"현질" + 0.019*"유저" + 0.018*"오류" + 0.018*"렉" + 0.017*"게임" + 0.017*"삭제" + 0.017*"게시" + 0.017*"젬" + 0.014*"옷" + 0.013*"월드"
# 2022-08-29 17:03:53,774 : INFO : topic #2 (0.333): 0.077*"젬" + 0.025*"옷" + 0.018*"게임" + 0.018*"사람" + 0.017*"점" + 0.017*"삭제" + 0.016*"유저" + 0.016*"캐릭터" + 0.015*"현질" + 0.013*"코인"
# 2022-08-29 17:03:53,774 : INFO : topic diff=4.236222, rho=1.000000
# 2022-08-29 17:03:53,775 : INFO : PROGRESS: pass 0, at document #4000/43925
# 2022-08-29 17:03:54,142 : INFO : merging changes from 2000 documents into a model of 43925 documents
# 2022-08-29 17:03
: INFO : merging changes from 2000 documents into a model of 43925 documents
# 2022-08-29 17:03:58,694 : INFO : topic #0 (0.333): 0.040*"계정" + 0.030*"업데이트" + 0.029*"게임" + 0.029*"로그인" + 0.020*"광고" + 0.019*"사진" + 0.015*"초기" + 0.015*"삭제" + 0.014*"이메일" + 0.013*"사람"
# 2022-08-29 17:03:58,695 : INFO : topic #1 (0.333): 0.074*"렉" + 0.045*"틱톡" + 0.024*"오류" + 0.023*"게임" + 0.017*"로딩" + 0.013*"별" + 0.012*"월드" + 0.011*"화면" + 0.011*"스트릿" + 0.010*"업뎃"
# 2022-08-29 17:03:58,695 : INFO : topic #2 (0.333): 0.069*"옷" + 0.049*"코인" + 0.047*"캐릭터" + 0.041*"돈" + 0.023*"퀘스트" + 0.022*"게임" + 0.020*"추가" + 0.017*"친구" + 0.016*"젬" + 0.014*"선물"
# 2022-08-29 17:03:58,696 : INFO : topic diff=0.242994, rho=0.218218
# 2022-08-29 17:03:58,945 : INFO : -6.794 per-word bound, 110.9 perplexity estimate based on a held-out corpus of 1925 documents with 9555 words
# 2022-08-29 17:03:58,946 : INFO : PROGRESS: pass 0, at document #43925/43925
# 2022-08-29 17:03:59,119 : INFO : merging changes from 1925 documents into a model of 43925 documents
# 2022-08-29 17:03:59,121 : INFO : topic #0 (0.333): 0.035*"계정" + 0.031*"게임" + 0.027*"로그인" + 0.025*"업데이트" + 0.021*"광고" + 0.021*"사진" + 0.015*"초기" + 0.015*"삭제" + 0.014*"이메일" + 0.014*"박스"
# 2022-08-29 17:03:59,121 : INFO : topic #1 (0.333): 0.075*"렉" + 0.036*"틱톡" + 0.027*"오류" + 0.026*"로딩" + 0.026*"게임" + 0.018*"화면" + 0.011*"별" + 0.010*"사람" + 0.010*"유저" + 0.010*"스트릿"
# 2022-08-29 17:03:59,122 : INFO : topic #2 (0.333): 0.067*"옷" + 0.050*"코인" + 0.048*"캐릭터" + 0.044*"돈" + 0.026*"퀘스트" + 0.023*"게임" + 0.021*"추가" + 0.017*"친구" + 0.014*"기능" + 0.013*"얼굴"
# 2022-08-29 17:03:59,122 : INFO : topic diff=0.218588, rho=0.213201
# 2022-08-29 17:03:59,122 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=7055, num_topics=3, decay=0.5, chunksize=2000) in 5.87s', 'datetime': '2022-08-29T17:03:59.122465', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'created'}
# 2022-08-29 17:03:59,123 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2022-08-29 17:04:24,092 : INFO : 15 accumulators retrieved from output queue
# 2022-08-29 17:04:24,109 : INFO : accumulated word occurrence stats for 34101 virtual documents
# 2022-08-29 17:04:29,495 : INFO : -6.992 per-word bound, 127.3 perplexity estimate based on a held-out corpus of 43925 documents with 271360 words
# 2022-08-29 17:04:29,496 : INFO : using symmetric alpha at 0.25
# 2022-08-29 17:04:29,496 : INFO : using symmetric eta at 0.25
# 2022-08-29 17:04:29,497 : INFO : using serial LDA version on this node
# 2022-08-29 17:04:29,499 : INFO : running online (single-pass) LDA training, 4 topics, 1 passes over the supplied corpus of 43925 documents, updating model once every 2000 documents, evaluating perplexity every 20000 documents, iterating 50x with a convergence threshold of 0.001000
# 
# 2022-08-29 17:08:07,864 : INFO : topic #4 (0.100): 0.084*"추가" + 0.071*"기능" + 0.070*"사진" + 0.043*"로딩" + 0.041*"선물" + 0.027*"친구" + 0.026*"옷" + 0.019*"설정" + 0.019*"꿀잼" + 0.017*"코드"
# 2022-08-29 17:08:07,865 : INFO : topic #3 (0.100): 0.089*"업데이트" + 0.069*"광고" + 0.064*"화면" + 0.048*"박스" + 0.037*"퀘스트" + 0.031*"버튼" + 0.025*"실행" + 0.021*"배경" + 0.020*"접속" + 0.020*"미니게임"
# 2022-08-29 17:08:07,865 : INFO : topic #6 (0.100): 0.123*"돈" + 0.063*"옷" + 0.040*"캐릭터" + 0.036*"재미" + 0.032*"인사" + 0.029*"설치" + 0.026*"사람" + 0.019*"팔로워" + 0.015*"수정" + 0.015*"스트릿"
# 2022-08-29 17:08:07,866 : INFO : topic #8 (0.100): 0.117*"렉" + 0.091*"캐릭터" + 0.055*"틱톡" + 0.038*"친구" + 0.036*"옷장" + 0.023*"월드" + 0.018*"파란" + 0.018*"점검" + 0.016*"사람" + 0.011*"서버"
# 2022-08-29 17:08:07,866 : INFO : topic #1 (0.100): 0.147*"옷" + 0.039*"현질" + 0.036*"코인" + 0.035*"돈" + 0.022*"아이템" + 0.022*"머리" + 0.019*"젬" + 0.016*"점" + 0.016*"유저" + 0.012*"가격"
# 2022-08-29 17:08:07,867 : INFO : topic diff=0.115704, rho=0.213201
# 2022-08-29 17:08:07,867 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=7055, num_topics=10, decay=0.5, chunksize=2000) in 5.04s', 'datetime': '2022-08-29T17:08:07.867776', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'created'}
# 2022-08-29 17:08:07,868 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2022-08-29 17:08:32,909 : INFO : 15 accumulators retrieved from output queue
# 2022-08-29 17:08:32,940 : INFO : accumulated word occurrence stats for 37596 virtual documents
# 2022-08-29 17:08:37,815 : INFO : -7.489 per-word bound, 179.7 perplexity estimate based on a held-out corpus of 43925 documents with 271360 words

# %%
j=0
for i in range(len(coherence_values)):
    print(j+2," coherence_value: ",coherence_values[i])
    print(j+2, " perpexities_values: ", perpexities_values[i])
    j+=1
# Out:
# 2  coherence_value:  0.320413277797152
# 2  perpexities_values:  -6.976177984332061
# 3  coherence_value:  0.3803132892799799
# 3  perpexities_values:  -6.992249629029393
# 4  coherence_value:  0.401075655175799
# 4  perpexities_values:  -7.03834344357059
# 5  coherence_value:  0.39586097367339723
# 5  perpexities_values:  -7.085854487371901
# 6  coherence_value:  0.3924914244404705
# 6  perpexities_values:  -7.112638020165829
# 7  coherence_value:  0.43647474778974793
# 7  perpexities_values:  -7.161544503784464
# 8  coherence_value:  0.4281028964861722
# 8  perpexities_values:  -7.1962220194567665
# 9  coherence_value:  0.43068683711186195
# 9  perpexities_values:  -7.324957315442566
# 10  coherence_value:  0.4076879639359771
# 10  perpexities_values:  -7.489474171504623

# %%
num_topics = 7
chunksize = 2000
passes = 20
iterations = 400
eval_every = None

temp = dictionary[0]
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every)

top_topics = model.top_topics(corpus) #, num_words=20)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# 2022-08-29 17:09:24,828 : INFO : topic #6 (0.218): 0.095*"옷" + 0.089*"코인" + 0.082*"돈" + 0.062*"게임" + 0.025*"퀘스트" + 0.022*"젬" + 0.019*"현질" + 0.013*"아이템" + 0.013*"추가" + 0.013*"구매"
# 2022-08-29 17:09:24,829 : INFO : topic diff=0.168793, rho=0.213201
# 2022-08-29 17:09:24,832 : INFO : PROGRESS: pass 1, at document #2000/43925
# 2022-08-29 17:09:25,002 : INFO : optimized alpha [0.18778074, 0.11817257, 0.12629071, 0.16397461, 0.1618162, 0.11570748, 0.22460938]
# 2022-08-29 17:09:25,004 : INFO : merging changes from 2000 documents into a model of 43925 documents
# 2022-08-29 17:09:25,007 : INFO : topic #5 (0.116): 0.075*"친구" + 0.032*"설치" + 0.024*"겜" + 0.024*"팔로우" + 0.020*"게임" + 0.019*"시작" + 0.016*"코드" + 0.013*"취소" + 0.013*"여자" + 0.012*"다운"
# 2022-08-29 17:09:25,007 : INFO : topic #1 (0.118): 0.095*"업데이트" + 0.081*"삭제" + 0.055*"게시" + 0.037*"오류" + 0.028*"업뎃" + 0.025*"버튼" + 0.021*"인사" + 0.021*"미니게임" + 0.018*"버그" + 0.018*"로그인"
# 2022-08-29 17:09:25,008 : INFO : topic #3 (0.164): 0.079*"캐릭터" + 0.076*"계정" + 0.050*"로그인" + 0.035*"초기" + 0.027*"이메일" + 0.022*"랙" + 0.022*"재미" + 0.020*"로그아웃" + 0.016*"게임" + 0.015*"삭제"
# 2022-08-29 17:09:25,008 : INFO : topic #0 (0.188): 0.110*"렉" + 0.039*"게임" + 0.034*"로딩" + 0.034*"월드" + 0.030*"점" + 0.022*"캐릭터" + 0.015*"시간" + 0.015*"별" + 0.014*"추천" + 0.013*"맵"
# 2022-08-29 17:09:25,008 : INFO : topic #6 (0.225): 0.077*"옷" + 0.071*"젬" + 0.071*"코인" + 0.060*"돈" + 0.058*"게임" + 0.032*"현질" + 0.019*"퀘스트" + 0.017*"아이템" + 0.010*"구매" + 0.010*"점"
# 2022-08-29 17:09:25,009 : INFO : topic diff=0.289169, rho=0.204284
# 2022-08-29 17:09:25,012 : INFO : PROGRESS: pass 1, at document #4000/43925
# 2022-08-29 17:09:25,177 : INFO : optimized alpha [0.192929, 0.11788145, 0.12830235, 0.16451102, 0.16151786, 0.11669078, 0.23262167]
# 2022-08-29 17:09:25,179 : INFO : merging changes from 2000 documents into a model of 43925 documents
# 2022-08-29 17:09:25,181 : INFO : topic #5 (0.117): 0.069*"친구" + 0.030*"설치" + 0.027*"겜" + 0.023*"팔로우" + 0.021*"게임" + 0.017*"시작" + 0.015*"인증" + 0.014*"다운로드" + 0.013*"코드" + 0.012*"번호"
# 2022-08-29 17:09:25,182 : INFO : topic #1 (0.118): 0.094*"업데이트" + 0.075*"삭제" + 0.049*"게시" + 0.040*"오류" + 0.026*"업뎃" + 0.025*"버튼" + 0.021*"버그" + 0.019*"미니게임" + 0.018*"인사" + 0.016*"로그인"
# 2022-08-29 17:09:25,182 : INFO : topic #3 (0.165): 0.078*"계정" + 0.073*"캐릭터" + 0.049*"로그인" + 0.031*"초기" + 0.024*"재미" + 0.024*"랙" + 0.022*"이메일" + 0.017*"로그아웃" + 0.017*"게임" + 0.014*"비밀번호"
# 2022-08-29 17:10:11,153 : INFO : topic diff=0.066990, rho=0.154372
# 2022-08-29 17:10:11,157 : INFO : PROGRESS: pass 19, at document #42000/43925
# 2022-08-29 17:10:11,236 : INFO : optimized alpha [1.5112536, 0.5157883, 0.5794969, 0.6014771, 1.0099095, 0.4882467, 1.3315916]
# 2022-08-29 17:10:11,238 : INFO : merging changes from 2000 documents into a model of 43925 documents
# 2022-08-29 17:10:11,240 : INFO : topic #5 (0.488): 0.120*"친구" + 0.036*"설치" + 0.030*"팔로워" + 0.029*"겜" + 0.026*"팔로우" + 0.020*"코드" + 0.018*"여자" + 0.015*"남자" + 0.014*"다운" + 0.012*"하트"
# 2022-08-29 17:10:11,240 : INFO : topic #1 (0.516): 0.142*"업데이트" + 0.090*"오류" + 0.065*"삭제" + 0.038*"버튼" + 0.034*"업뎃" + 0.032*"인사" + 0.024*"게시" + 0.023*"미니게임" + 0.018*"창" + 0.017*"결제"
# 2022-08-29 17:10:11,241 : INFO : topic #4 (1.010): 0.091*"틱톡" + 0.063*"사람" + 0.045*"추가" + 0.042*"사진" + 0.041*"기능" + 0.029*"유저" + 0.025*"말" + 0.023*"사용" + 0.022*"옷장" + 0.016*"점령"
# 2022-08-29 17:10:11,241 : INFO : topic #6 (1.332): 0.113*"옷" + 0.079*"코인" + 0.068*"돈" + 0.056*"젬" + 0.033*"현질" + 0.026*"선물" + 0.018*"아이템" + 0.014*"잼" + 0.012*"구매" + 0.011*"시작"
# 2022-08-29 17:10:11,241 : INFO : topic #0 (1.511): 0.110*"게임" + 0.088*"렉" + 0.077*"캐릭터" + 0.037*"월드" + 0.036*"점" + 0.028*"별" + 0.017*"로딩" + 0.014*"문제" + 0.013*"수정" + 0.013*"추천"
# 2022-08-29 17:10:11,242 : INFO : topic diff=0.069375, rho=0.154372
# 2022-08-29 17:10:11,245 : INFO : PROGRESS: pass 19, at document #43925/43925
# 2022-08-29 17:10:11,322 : INFO : optimized alpha [1.5178567, 0.51371926, 0.5940361, 0.6005532, 1.0064365, 0.48823997, 1.3254169]
# 2022-08-29 17:10:11,324 : INFO : merging changes from 1925 documents into a model of 43925 documents
# 2022-08-29 17:10:11,326 : INFO : topic #5 (0.488): 0.126*"친구" + 0.038*"설치" + 0.027*"팔로워" + 0.027*"겜" + 0.025*"팔로우" + 0.020*"코드" + 0.017*"여자" + 0.016*"다운" + 0.014*"남자" + 0.012*"다운로드"
# 2022-08-29 17:10:11,326 : INFO : topic #1 (0.514): 0.131*"업데이트" + 0.100*"오류" + 0.067*"삭제" + 0.039*"버튼" + 0.031*"업뎃" + 0.029*"인사" + 0.027*"미니게임" + 0.021*"게시" + 0.019*"창" + 0.017*"결제"
# 2022-08-29 17:10:11,327 : INFO : topic #4 (1.006): 0.078*"틱톡" + 0.063*"사람" + 0.049*"추가" + 0.047*"사진" + 0.046*"기능" + 0.029*"유저" + 0.024*"말" + 0.023*"사용" + 0.022*"옷장" + 0.014*"점령"
# 2022-08-29 17:10:11,327 : INFO : topic #6 (1.325): 0.115*"옷" + 0.084*"코인" + 0.076*"돈" + 0.049*"젬" + 0.030*"현질" + 0.025*"선물" + 0.018*"아이템" + 0.013*"잼" + 0.012*"시작" + 0.012*"방법"
# 2022-08-29 17:10:11,327 : INFO : topic #0 (1.518): 0.113*"게임" + 0.087*"렉" + 0.079*"캐릭터" + 0.036*"점" + 0.031*"월드" + 0.025*"로딩" + 0.025*"별" + 0.015*"시간" + 0.015*"수정" + 0.013*"문제"
# 2022-08-29 17:10:11,328 : INFO : topic diff=0.066489, rho=0.154372
# 2022-08-29 17:10:11,331 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=7055, num_topics=7, decay=0.5, chunksize=2000) in 50.82s', 'datetime': '2022-08-29T17:10:11.331472', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'created'}
# 2022-08-29 17:10:11,336 : INFO : CorpusAccumulator accumulated stats from 1000 documents
# 2022-08-29 17:10:11,339 : INFO : CorpusAccumulator accumulated stats from 2000 documents
# 2022-08-29 17:10:11,342 : INFO : CorpusAccumulator accumulated stats from 3000 documents
# 2022-08-29 17:10:11,345 : INFO : CorpusAccumulator accumulated stats from 4000 documents
# 2022-08-29 17:10:11,347 : INFO : CorpusAccumulator accumulated stats from 5000 documents
# 2022-08-29 17:10:11,350 : INFO : CorpusAccumulator accumulated stats from 6000 documents
# 2022-08-29 17:10:11,353 : INFO : CorpusAccumulator accumulated stats from 7000 documents
# 2022-08-29 17:10:11,356 : INFO : CorpusAccumulator accumulated stats from 8000 documents
# 2022-08-29 17:10:11,359 : INFO : CorpusAccumulator accumulated stats from 9000 documents
# 2022-08-29 17:10:11,362 : INFO : CorpusAccumulator accumulated stats from 10000 documents
# 2022-08-29 17:10:11,365 : INFO : CorpusAccumulator accumulated stats from 11000 documents
# 2022-08-29 17:10:11,368 : INFO : CorpusAccumulator accumulated stats from 12000 documents
# 2022-08-29 17:10:11,371 : INFO : CorpusAccumulator accumulated stats from 13000 documents
# 2022-08-29 17:10:11,374 : INFO : CorpusAccumulator accumulated stats from 14000 documents
# 2022-08-29 17:10:11,377 : INFO : CorpusAccumulator accumulated stats from 15000 documents
# 2022-08-29 17:10:11,380 : INFO : CorpusAccumulator accumulated stats from 16000 documents
# 2022-08-29 17:10:11,383 : INFO : CorpusAccumulator accumulated stats from 17000 documents
# 2022-08-29 17:10:11,386 : INFO : CorpusAccumulator accumulated stats from 18000 documents
# 2022-08-29 17:10:11,388 : INFO : CorpusAccumulator accumulated stats from 19000 documents
# 2022-08-29 17:10:11,391 : INFO : CorpusAccumulator accumulated stats from 20000 documents
# 2022-08-29 17:10:11,393 : INFO : CorpusAccumulator accumulated stats from 21000 documents
# 2022-08-29 17:10:11,396 : INFO : CorpusAccumulator accumulated stats from 22000 documents
# 2022-08-29 17:10:11,399 : INFO : CorpusAccumulator accumulated stats from 23000 documents
# 2022-08-29 17:10:11,401 : INFO : CorpusAccumulator accumulated stats from 24000 documents
# 2022-08-29 17:10:11,403 : INFO : CorpusAccumulator accumulated stats from 25000 documents
# 2022-08-29 17:10:11,406 : INFO : CorpusAccumulator accumulated stats from 26000 documents
# 2022-08-29 17:10:11,408 : INFO : CorpusAccumulator accumulated stats from 27000 documents
# 2022-08-29 17:10:11,411 : INFO : CorpusAccumulator accumulated stats from 28000 documents
# 2022-08-29 17:10:11,413 : INFO : CorpusAccumulator accumulated stats from 29000 documents
# 2022-08-29 17:10:11,415 : INFO : CorpusAccumulator accumulated stats from 30000 documents
# 2022-08-29 17:10:11,418 : INFO : CorpusAccumulator accumulated stats from 31000 documents
# 2022-08-29 17:10:11,420 : INFO : CorpusAccumulator accumulated stats from 32000 documents
# 2022-08-29 17:10:11,422 : INFO : CorpusAccumulator accumulated stats from 33000 documents
# 2022-08-29 17:10:11,425 : INFO : CorpusAccumulator accumulated stats from 34000 documents
# 2022-08-29 17:10:11,428 : INFO : CorpusAccumulator accumulated stats from 35000 documents
# 2022-08-29 17:10:11,430 : INFO : CorpusAccumulator accumulated stats from 36000 documents
# 2022-08-29 17:10:11,433 : INFO : CorpusAccumulator accumulated stats from 37000 documents
# 2022-08-29 17:10:11,436 : INFO : CorpusAccumulator accumulated stats from 38000 documents
# 2022-08-29 17:10:11,438 : INFO : CorpusAccumulator accumulated stats from 39000 documents
# 2022-08-29 17:10:11,441 : INFO : CorpusAccumulator accumulated stats from 40000 documents
# 2022-08-29 17:10:11,443 : INFO : CorpusAccumulator accumulated stats from 41000 documents
# 2022-08-29 17:10:11,446 : INFO : CorpusAccumulator accumulated stats from 42000 documents
# 2022-08-29 17:10:11,449 : INFO : CorpusAccumulator accumulated stats from 43000 documents
# Average topic coherence: -6.0963.
# [([(0.11513696, '옷'),
#    (0.083772935, '코인'),
#    (0.0755258, '돈'),
#    (0.049236994, '젬'),
#    (0.030099524, '현질'),
#    (0.025241, '선물'),
#    (0.018323045, '아이템'),
#    (0.012656019, '잼'),
#    (0.012276869, '시작'),
#    (0.012025597, '방법'),
#    (0.011860281, '구매'),
#    (0.011385021, '머리'),
#    (0.010056649, '하루'),
#    (0.008961872, '유도'),
#    (0.008866083, '가격'),
#    (0.007204111, '유저'),
#    (0.0070402827, '당첨'),
#    (0.0065627676, '헤어'),
#    (0.0063845417, '스크래치'),
#    (0.0058627687, '미션')],
#   -3.2883343689172015),
#  ([(0.11318257, '게임'),
#    (0.08703788, '렉'),
#    (0.07851174, '캐릭터'),
#    (0.035707176, '점'),
#    (0.03115935, '월드'),
#    (0.025026543, '로딩'),
#    (0.024808582, '별'),
#    (0.015403592, '시간'),
#    (0.014690339, '수정'),
#    (0.013467281, '문제'),
#    (0.012011482, '추천'),
#    (0.01104716, '플레이'),
#    (0.010050319, '접속'),
#    (0.0099749, '버그'),
#    (0.009659049, '개선'),
#    (0.008664476, '꿀잼'),
#    (0.008538599, '스트릿'),
#    (0.008377204, '리뷰'),
#    (0.00817123, '맵'),
#    (0.0071425484, '제작자')],
#   -4.49516259508111),
#  ([(0.078379184, '틱톡'),
#    (0.06265353, '사람'),
#    (0.04873582, '추가'),
#    (0.04704186, '사진'),
#    (0.046116654, '기능'),
#    (0.028980762, '유저'),
#    (0.023570655, '말'),
#    (0.023452647, '사용'),
#    (0.022439815, '옷장'),
#    (0.013911949, '점령'),
#    (0.013766404, '영상'),
#    (0.013432913, '욕'),
#    (0.011725918, '메세지'),
#    (0.011434569, '저장'),
#    (0.011086553, '배경'),
#    (0.009425502, '신고'),
#    (0.008232307, '부탁'),
#    (0.0073998407, '이모지'),
#    (0.007299845, '중'),
#    (0.0069262846, '어플')],
#   -4.891523384119991),
#  ([(0.10806663, '계정'),
#    (0.086637296, '로그인'),
#    (0.049010497, '초기'),
#    (0.039652426, '이메일'),
#    (0.032554753, '랙'),
#    (0.032086242, '재미'),
#    (0.028560167, '로그아웃'),
#    (0.026899096, '가입'),
#    (0.019892754, '비밀번호'),
#    (0.017859142, '복구'),
#    (0.015880935, '점검'),
#    (0.015442116, '이름'),
#    (0.013791597, '비번'),
#    (0.013068537, '만들기'),
#    (0.011979011, '회원'),
#    (0.010799353, '수리'),
#    (0.009464567, '로그'),
#    (0.009186038, '캐릭'),
#    (0.0077188346, '실수'),
#    (0.007379727, '페이스북')],
#   -5.517661253919484),
#  ([(0.10846067, '퀘스트'),
#    (0.07294826, '광고'),
#    (0.05740186, '화면'),
#    (0.048753083, '얼굴'),
#    (0.03525973, '박스'),
#    (0.019242428, '실행'),
#    (0.018252647, '해결'),
#    (0.014920084, '파란'),
#    (0.0139692705, '답변'),
#    (0.013824984, '확인'),
#    (0.012892272, '어제'),
#    (0.012046996, '크루'),
#    (0.01106116, '완료'),
#    (0.010535953, '상태'),
#    (0.00870359, '보상'),
#    (0.008266231, '보기'),
#    (0.008092596, '프로필'),
#    (0.008062615, '여혐'),
#    (0.007945331, '페북'),
#    (0.007847312, '럭키')],
#   -6.603631703413243),
#  ([(0.12566066, '친구'),
#    (0.03771606, '설치'),
#    (0.027267022, '팔로워'),
#    (0.027170252, '겜'),
#    (0.02513165, '팔로우'),
#    (0.020243526, '코드'),
#    (0.01728777, '여자'),
#    (0.01630462, '다운'),
#    (0.014232462, '남자'),
#    (0.012016197, '다운로드'),
#    (0.0116575975, '인증'),
#    (0.011336865, '알림'),
#    (0.010723383, '하트'),
#    (0.010294771, '표시'),
#    (0.009845041, '검색'),
#    (0.009527249, '팔로잉'),
#    (0.008995518, '취소'),
#    (0.008954915, '케릭'),
#    (0.008484635, '번호'),
#    (0.008426225, '욥')],
#   -8.623642695391386),
#  ([(0.13147336, '업데이트'),
#    (0.10044779, '오류'),
#    (0.067056, '삭제'),
#    (0.03894289, '버튼'),
#    (0.031363316, '업뎃'),
#    (0.028517216, '인사'),
#    (0.02707025, '미니게임'),
#    (0.02132223, '게시'),
#    (0.01889556, '창'),
#    (0.017186483, '결제'),
#    (0.013472331, '노잼'),
#    (0.011627499, '입력'),
#    (0.011623812, '사랑'),
#    (0.0100772, '스노우'),
#    (0.009611908, '안보'),
#    (0.009535012, '바'),
#    (0.008738584, '소개'),
#    (0.008685131, '파크'),
#    (0.008227041, '알람'),
#    (0.00756213, '저번')],
#   -9.254092513129569)]

# %%
import pickle
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

# %%
lda_visualization = gensimvis.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.save_html(lda_visualization, 'output/zepeto_topic_modeling_topic7_0828.html')
